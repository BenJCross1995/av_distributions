# %%
import sys
# Overwrite sys.argv so argparse in the script sees only what we want
sys.argv = [
    "run_masking_paraphrase_method.py",
    "--known_loc", "/Volumes/BCross/datasets/author_verification/test/Wiki/known_raw.jsonl",
    "--unknown_loc", "/Volumes/BCross/datasets/author_verification/test/Wiki/unknown_raw.jsonl",
    "--metadata_loc", "/Volumes/BCross/datasets/author_verification/test/metadata.rds",
    "--model_loc", "/Volumes/BCross/models/ModernBERT/ModernBERT-base",
    "--save_loc", "/Volumes/BCross/paraphrase examples masking/raw-ModernBERT-base",
    "--known_doc", "hodja_nasreddin_text_1",
    "--unknown_doc", "hodja_nasreddin_text_3",
    "--ngram_n", "2",
    "--lowercase"
]

# Now import and run
import run_masking_paraphrase_method
run_masking_paraphrase_method.main()
# Out:
# Working on problem: hodja_nasreddin_text_1 vs hodja_nasreddin_text_3
# Loading model
# Loading data
# Data loaded
# Getting common n-grams
# There are 12 n-grams in common!
# Generating paraphrases
#     Working on paraphrase: phrase_01
#     Working on paraphrase: phrase_02
#     Working on paraphrase: phrase_03
#     Working on paraphrase: phrase_04
#     Working on paraphrase: phrase_05
#     Working on paraphrase: phrase_06
#     Working on paraphrase: phrase_07
#     Working on paraphrase: phrase_08
#     Working on paraphrase: phrase_09
#     Working on paraphrase: phrase_10
#     Working on paraphrase: phrase_11
#     Working on paraphrase: phrase_12
# Saved all results to '/Volumes/BCross/paraphrase examples masking/raw-ModernBERT-base/hodja_nasreddin_text_1 vs hodja_nasreddin_text_3.xlsx'

# %%
import sys
# Overwrite sys.argv so argparse in the script sees only what we want
sys.argv = [
    "run_masking_paraphrase_method_v2.py",
    "--known_loc", "/Volumes/BCross/datasets/author_verification/test/Wiki/known_raw.jsonl",
    "--unknown_loc", "/Volumes/BCross/datasets/author_verification/test/Wiki/unknown_raw.jsonl",
    "--metadata_loc", "/Volumes/BCross/datasets/author_verification/test/metadata.rds",
    "--model_loc", "/Volumes/BCross/models/roberta-base",
    "--save_loc", "/Volumes/BCross/paraphrase examples masking/raw-roberta-base",
    "--known_doc", "hodja_nasreddin_text_1",
    "--unknown_doc", "hodja_nasreddin_text_3",
    "--ngram_n", "2",
    "--lowercase"
]

# Now import and run
import run_masking_paraphrase_method_v2
run_masking_paraphrase_method_v2.main()
# Out:
# Working on problem: hodja_nasreddin_text_1 vs hodja_nasreddin_text_3
# Loading model
# Loading data
# Token indices sequence length is longer than the specified maximum sequence length for this model (527 > 512). Running this sequence through the model will result in indexing errors
# Data loaded
# Getting common n-grams
# There are 12 n-grams in common!
# Generating paraphrases
#     Working on paraphrase: phrase_01
#     Spans: [[238, 239, 240, 241]]
#     Working on paraphrase: phrase_02
#     Spans: [[122, 123, 124], [172, 173, 174]]
#     Working on paraphrase: phrase_03
#     Spans: [[204, 205, 206]]
#     Working on paraphrase: phrase_04
#     Spans: [[315, 316, 317]]
#     Working on paraphrase: phrase_05
#     Spans: [[135, 136, 137]]
#     Working on paraphrase: phrase_06
#     Spans: [[208, 209, 210]]
#     Working on paraphrase: phrase_07
#     Spans: [[69, 70, 71]]
#     Working on paraphrase: phrase_08
#     Spans: [[357, 358]]
#     Working on paraphrase: phrase_09
#     Spans: [[216, 217]]
#     Working on paraphrase: phrase_10
#     Spans: [[373, 374]]
#     Working on paraphrase: phrase_11
#     Spans: [[218, 219]]
#     Working on paraphrase: phrase_12
#     Spans: [[117, 118]]
# Saved all results to '/Volumes/BCross/paraphrase examples masking/raw-roberta-base/hodja_nasreddin_text_1 vs hodja_nasreddin_text_3.xlsx'
