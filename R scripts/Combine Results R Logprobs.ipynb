# %% [markdown]
# # Combine N-Gram Paraphrasing Results and Score Using Idiolect
#
# This is a notebook to combine the results for n-gram paraphrasing using several models as scoring models. In this notebook we use the Idiolect R library and specifically the **performance** function to calculate the scores.
#
# **NOTE**: The idea here is that the scores are already calculate and aggregated for each model and that we just need to import and score. Trying to aggregate using R caused some joining issues since n-grams can begin with a space.

# %% [markdown]
# ### Load Libraries

# %%
source("./utils.R")

# %%
# Load while suppressing all warnings
suppressWarnings(
  suppressPackageStartupMessages(
    {
      library(dplyr)
      library(idiolect)
      library(readr)
      library(readxl)
      library(writexl)
      library(purrr)
    }
  )
)

# %% [markdown]
# ### Load Data
#
# Here we load the data, again can see we're not pointing at directories, rather results that have already been aggregated.

# %%
base_location = '/Volumes/BCross/paraphrase examples slurm/Wiki-Test'

# Token Size Problems
# This table contains the problems for each different min_token_size value in the dataset
token_size_problems = read_excel(paste0(base_location, '/token_size_problems.xlsx'))

# Raw Score Data
# This data contains the llr scores aggregated across problems with averaging across phrase occurences done first
# raw_score_data = read_excel(paste0(base_location, '/score_by_token_size_avg.xlsx'))
raw_score_data = read_excel(paste0(base_location, '/combined_token_level_results_agg_v3.xlsx'))

# LambdaG Results
# Load the LambdaG results for the Wiki test dataset
lambdag_raw <- read.csv(paste0(base_location, '/lambdaG_results.csv'))

# %%
raw_score_data
# Out:
# # A tibble: 5,811 × 18
#    paraphrasing_model scoring_model problem      corpus known_author unknown_author
#    <chr>              <chr>         <chr>        <chr>  <chr>        <chr>
#  1 ModernBERT-base    gpt2          HOOTmag vs … Wiki   HOOTmag      HOOTmag
#  2 ModernBERT-base    gpt2          HOOTmag vs … Wiki   HOOTmag      Iain99
#  3 ModernBERT-base    gpt2          Hodja_Nasre… Wiki   Hodja_Nasre… Hodja_Nasredd…
#  4 ModernBERT-base    gpt2          Hodja_Nasre… Wiki   Hodja_Nasre… HonestopL
#  5 ModernBERT-base    gpt2          HonestopL v… Wiki   HonestopL    HOOTmag
#  6 ModernBERT-base    gpt2          HonestopL v… Wiki   HonestopL    HonestopL
#  7 ModernBERT-base    gpt2          Iain99 vs I… Wiki   Iain99       Iain99
#  8 ModernBERT-base    gpt2          Iain99 vs I… Wiki   Iain99       Icarus3
#  9 ModernBERT-base    gpt2          Icarus3 vs … Wiki   Icarus3      Icarus3
# 10 ModernBERT-base    gpt2          Icarus3 vs … Wiki   Icarus3      Intangible
# # ℹ 5,801 more rows
# # ℹ 12 more variables: target <lgl>, no_context_log_prob <dbl>,
# #   known_log_prob <dbl>, unknown_log_prob <dbl>,
# #   known_vs_no_context_log_prob <dbl>, unknown_vs_no_context_log_prob <dbl>,
# #   llr_no_context <dbl>, llr_known <dbl>, llr_unknown <dbl>,
# #   unknown_ref_vs_top_rank <dbl>, unknown_ref_vs_best_rest <dbl>,
# #   min_token_size <dbl>
# # ℹ Use `print(n = ...)` to see more rows

# %% [markdown]
# ### Create Final Dataset
#
# Here we join the raw data with teh problem dataset to filter out incorrect token sizes.

# %%
# We want to rename the unkown score column to just score to allow it to work with performance
score_data = raw_score_data %>%
  inner_join(token_size_problems, by = c('problem', 'min_token_size', 'corpus', 'target')) %>%
  rename('score'='unknown_log_prob')

score_data %>% head()
# Out:
# # A tibble: 6 × 18
#   paraphrasing_model scoring_model problem       corpus known_author unknown_author
#   <chr>              <chr>         <chr>         <chr>  <chr>        <chr>
# 1 ModernBERT-base    gpt2          HOOTmag vs H… Wiki   HOOTmag      HOOTmag
# 2 ModernBERT-base    gpt2          HOOTmag vs I… Wiki   HOOTmag      Iain99
# 3 ModernBERT-base    gpt2          Hodja_Nasred… Wiki   Hodja_Nasre… Hodja_Nasredd…
# 4 ModernBERT-base    gpt2          Hodja_Nasred… Wiki   Hodja_Nasre… HonestopL
# 5 ModernBERT-base    gpt2          HonestopL vs… Wiki   HonestopL    HOOTmag
# 6 ModernBERT-base    gpt2          HonestopL vs… Wiki   HonestopL    HonestopL
# # ℹ 12 more variables: target <lgl>, no_context_log_prob <dbl>,
# #   known_log_prob <dbl>, score <dbl>, known_vs_no_context_log_prob <dbl>,
# #   unknown_vs_no_context_log_prob <dbl>, llr_no_context <dbl>, llr_known <dbl>,
# #   llr_unknown <dbl>, unknown_ref_vs_top_rank <dbl>,
# #   unknown_ref_vs_best_rest <dbl>, min_token_size <dbl>

# %% [markdown]
# ### Calculate Performance

# %%
distinct_model_sizes <- score_data %>%
  select(paraphrasing_model, scoring_model, corpus, min_token_size) %>%
  distinct() %>%
  arrange(paraphrasing_model, scoring_model, corpus, min_token_size)

distinct_model_sizes %>% head()
# Out:
# # A tibble: 6 × 4
#   paraphrasing_model scoring_model corpus min_token_size
#   <chr>              <chr>         <chr>           <dbl>
# 1 ModernBERT-base    gpt2          Wiki                2
# 2 ModernBERT-base    gpt2          Wiki                3
# 3 ModernBERT-base    gpt2          Wiki                4
# 4 ModernBERT-base    gpt2          Wiki                5
# 5 ModernBERT-large   gpt2          Wiki                2
# 6 ModernBERT-large   gpt2          Wiki                3

# %%
process_group <- function(paraphrasing_model, scoring_model, corpus, min_token_size) {

  distinct_problems <- token_size_problems %>%
    filter(min_token_size == !!min_token_size)

  # Filter score_data by the combination
  filtered <- score_data %>%
    filter(paraphrasing_model == !!paraphrasing_model,
           scoring_model == !!scoring_model,
           corpus == !!corpus,
           min_token_size == !!min_token_size) %>%
    inner_join(distinct_problems, by=c('corpus', 'problem', 'min_token_size', 'target'))
  
  # Run performance function
  perf <- performance(filtered)
  perf <- perf$evaluation

  # Add the identifying columns
  cbind(
    data.frame(paraphrasing_model = paraphrasing_model,
               scoring_model=scoring_model,
               corpus = corpus,
               min_token_size = min_token_size),
    perf
  )
}

# %%
results <- distinct_model_sizes %>%
  pmap_dfr(process_group)

results %>% arrange(corpus, min_token_size, paraphrasing_model, scoring_model,) %>% head()
# Out:
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   paraphrasing_model scoring_model corpus min_token_size      Cllr  Cllr_min
# 1    ModernBERT-base          gpt2   Wiki              2 0.8596104 0.7608662
# 2   ModernBERT-large          gpt2   Wiki              2 0.8777187 0.7732053
# 3               gpt5         gemma   Wiki              2 0.8856810 0.8033393
# 4               gpt5          gpt2   Wiki              2 0.8456774 0.7535165
# 5               gpt5         llama   Wiki              2 0.8878195 0.8066612
# 6               gpt5          qwen   Wiki              2 0.8499285 0.7611920
#        EER Mean TRUE LLR Mean FALSE LLR TRUE trials FALSE trials       AUC
# 1 27.97534     0.3504266     -0.2351931         114          114 0.7696110
# 2 29.38808     0.2973148     -0.2055614         106          107 0.7494505
# 3 31.23065     0.2539625     -0.1932376         114          114 0.7472098
# 4 28.20513     0.4098410     -0.2536523         114          114 0.7797353
# 5 31.05023     0.2469576     -0.1902074         114          114 0.7445791
# 6 28.57143     0.3931037     -0.2467528         114          114 0.7739955
#   Balanced Accuracy Precision    Recall        F1 TP FN FP TN
# 1         0.7187500 0.7425743 0.6696429 0.7042254 75 37 26 86
# 2         0.6936813 0.7000000 0.6730769 0.6862745 70 34 30 75
# 3         0.6830357 0.6915888 0.6607143 0.6757991 74 38 33 79
# 4         0.7276786 0.7524752 0.6785714 0.7136150 76 36 25 87
# 5         0.6919643 0.7047619 0.6607143 0.6820276 74 38 31 81
# 6         0.7187500 0.7333333 0.6875000 0.7096774 77 35 28 84

# %% [markdown]
# ### LambdaG Results

# %%
# Get the distinct corpus and min_token_size adding LambdaG as model at front
distinct_corpus_sizes <- distinct_model_sizes %>%
  select(corpus, min_token_size) %>%
  distinct() %>%
  arrange(corpus, min_token_size) %>%
  mutate(paraphrasing_model = "LambdaG", scoring_model = "LambdaG") %>%
  relocate(c(paraphrasing_model, scoring_model), .before = everything())

# %%
distinct_corpus_sizes
# Out:
# # A tibble: 4 × 4
#   paraphrasing_model scoring_model corpus min_token_size
#   <chr>              <chr>         <chr>           <dbl>
# 1 LambdaG            LambdaG       Wiki                2
# 2 LambdaG            LambdaG       Wiki                3
# 3 LambdaG            LambdaG       Wiki                4
# 4 LambdaG            LambdaG       Wiki                5

# %%
lambdag_raw
# Out:
#                                            problem          known_author
# 1                               HOOTmag vs HOOTmag               HOOTmag
# 2                               Icarus3 vs Icarus3               Icarus3
# 3                               Rjecina vs Rjecina               Rjecina
# 4                               Lear_21 vs Lear_21               Lear_21
# 5                     Richard_Daft vs Richard_Daft          Richard_Daft
# 6                               Rjecina vs RolandR               Rjecina
# 7                             Pro-Lick vs Pro-Lick              Pro-Lick
# 8                         Jim_Hardie vs Jim_Hardie            Jim_Hardie
# 9                               Snowded vs Snowded               Snowded
# 10                         WIKI-GUY-16 vs WilliamH           WIKI-GUY-16
# 11                                Yoenit vs Yoenit                Yoenit
# 12                                KBlott vs KBlott                KBlott
# 13                               SKS2K6 vs Snowded                SKS2K6
# 14                      Jimharlow99 vs Jimharlow99           Jimharlow99
# 15                    JereKrischel vs JereKrischel          JereKrischel
# 16                                        Vr vs Vr                    Vr
# 17                                Vedant vs Vedant                Vedant
# 18                Sennen_goroshi vs Sennen_goroshi        Sennen_goroshi
# 19                    Paul_Siebert vs Paul_Siebert          Paul_Siebert
# 20                       Jimharlow99 vs Jim_Hardie           Jimharlow99
# 21                      Soapfan2013 vs Soapfan2013           Soapfan2013
# 22                                Iain99 vs Iain99                Iain99
# 23                                    Itub vs Itub                  Itub
# 24                  Ledenierhomme vs Ledenierhomme         Ledenierhomme
# 25                               HOOTmag vs Iain99               HOOTmag
# 26                        Obamafan70 vs Obamafan70            Obamafan70
# 27  Jeffrey_Vernon_Merkey vs Jeffrey_Vernon_Merkey Jeffrey_Vernon_Merkey
# 28                              Mayalld vs Mayalld               Mayalld
# 29                          Soapfan2013 vs Spaully           Soapfan2013
# 30                            Nocrowx vs Notpietru               Nocrowx
# 31                        Nirvana888 vs Nirvana888            Nirvana888
# 32                    Marine_69-71 vs Marine_69-71          Marine_69-71
# 33                                Maunus vs Maunus                Maunus
# 34              The_Four_Deuces vs The_Four_Deuces       The_Four_Deuces
# 35                        Salix_alba vs Salix_alba            Salix_alba
# 36                  JerryFriedman vs JerryFriedman         JerryFriedman
# 37                         Nil_Einne vs Nirvana888             Nil_Einne
# 38                ZjarriRrethues vs 142.196.88.228        ZjarriRrethues
# 39                              Spaully vs Spaully               Spaully
# 40                  Mystichumwipe vs Mystichumwipe         Mystichumwipe
# 41                            Johnuniq vs Johnuniq              Johnuniq
# 42                      Salix_alba vs Sally_Season            Salix_alba
# 43                             Meowy vs MezzoMezzo                 Meowy
# 44                    Sean.hoyland vs Sean.hoyland          Sean.hoyland
# 45                            WilliamH vs WilliamH              WilliamH
# 46                                  JMRH6 vs JMRH6                 JMRH6
# 47                                      Xtv vs Xtv                   Xtv
# 48                             Spaully vs Spitfire               Spaully
# 49                  PinkAmpersand vs PinkAmpersand         PinkAmpersand
# 50                              RolandR vs RolandR               RolandR
# 51                                  Tvoz vs U21980                  Tvoz
# 52                                UpDown vs Vedant                UpDown
# 53                            SriSuren vs SriSuren              SriSuren
# 54                        Intangible vs Intangible            Intangible
# 55                            Sgrayban vs Sgrayban              Sgrayban
# 56            Musical_Linguist vs Musical_Linguist      Musical_Linguist
# 57                       Sgrayban vs Simoncursitor              Sgrayban
# 58                                  Meowy vs Meowy                 Meowy
# 59                  Livelikemusic vs Livelikemusic         Livelikemusic
# 60                             Pro-Lick vs Protonk              Pro-Lick
# 61                          Snowded vs Soapfan2013               Snowded
# 62                        Tintin1107 vs Tintin1107            Tintin1107
# 63                                   Wobble vs Xtv                Wobble
# 64                         Mystichumwipe vs N419BH         Mystichumwipe
# 65                        Yoenit vs ZjarriRrethues                Yoenit
# 66                      Ottava_Rima vs Ottava_Rima           Ottava_Rima
# 67                               Mathsci vs Maunus               Mathsci
# 68                         Simoncursitor vs SKS2K6         Simoncursitor
# 69                            Phead128 vs Phead128              Phead128
# 70                   Multixfer vs Musical_Linguist             Multixfer
# 71              Hodja_Nasreddin vs Hodja_Nasreddin       Hodja_Nasreddin
# 72                              Nirvana888 vs NJGW            Nirvana888
# 73             Musical_Linguist vs MyMoloboaccount      Musical_Linguist
# 74                            Jwanders vs Jwanders              Jwanders
# 75                              Protonk vs Protonk               Protonk
# 76                              Mangoe vs Mareklug                Mangoe
# 77                        IvoShandor vs IvoShandor            IvoShandor
# 78                                U21980 vs U21980                U21980
# 79            Scheinwerfermann vs Scheinwerfermann      Scheinwerfermann
# 80                           Icarus3 vs Intangible               Icarus3
# 81                   Jc37 vs Jeffrey_Vernon_Merkey                  Jc37
# 82                             Protonk vs Ramdrake               Protonk
# 83                          Vr vs VsevolodKrolikov                    Vr
# 84                        Livelikemusic vs Livitup         Livelikemusic
# 85                                Nathan vs Nathan                Nathan
# 86          StillStanding-247 vs StillStanding-247     StillStanding-247
# 87            VsevolodKrolikov vs VsevolodKrolikov      VsevolodKrolikov
# 88                            O_Fenian vs O_Fenian              O_Fenian
# 89                             Jim_Hardie vs JMRH6            Jim_Hardie
# 90                            Kashmiri vs Kashmiri              Kashmiri
# 91                     Orangemarlin vs Ottava_Rima          Orangemarlin
# 92                       KBlott vs KillerChihuahua                KBlott
# 93                           Volunteer_Marek vs Vr       Volunteer_Marek
# 94                            Vedant vs Viewfinder                Vedant
# 95                                    Jc37 vs Jc37                  Jc37
# 96              KillerChihuahua vs KillerChihuahua       KillerChihuahua
# 97                          Nil_Einne vs Nil_Einne             Nil_Einne
# 98                WilliamH vs William_M._Connolley              WilliamH
# 99                          Milomedes vs Multixfer             Milomedes
# 100                   SaliereTheFish vs Salix_alba        SaliereTheFish
# 101                         Nigel_Ish vs Nil_Einne             Nigel_Ish
# 102                             Tintin1107 vs Tvoz            Tintin1107
# 103                     Intothefire vs Intothefire           Intothefire
# 104               MyMoloboaccount vs Mystichumwipe       MyMoloboaccount
# 105                      KillerChihuahua vs Kudzu1       KillerChihuahua
# 106             Machine_Elf_1735 vs Magog_the_Ogre      Machine_Elf_1735
# 107                          Swift&silent vs T34CH          Swift&silent
# 108                           Ramdrake vs Ramdrake              Ramdrake
# 109                           Spitfire vs SriSuren              Spitfire
# 110             StephenBuxton vs StillStanding-247         StephenBuxton
# 111                         Notpietru vs Notpietru             Notpietru
# 112                       Ramdrake vs Richard_Daft              Ramdrake
# 113                      SriSuren vs StephenBuxton              SriSuren
# 114                            MCB vs Media_anthro                   MCB
# 115                              Maunus vs Mayalld                Maunus
# 116                        Jasper_Deng vs Jbmurray           Jasper_Deng
# 117                               UpDown vs UpDown                UpDown
# 118                  JereKrischel vs JerryFriedman          JereKrischel
# 119                           HonestopL vs HOOTmag             HonestopL
# 120                         Thekohser vs Thekohser             Thekohser
# 121                         HonestopL vs HonestopL             HonestopL
# 122                     Peter_James vs Peter_James           Peter_James
# 123               SaliereTheFish vs SaliereTheFish        SaliereTheFish
# 124                       Viewfinder vs Viewfinder            Viewfinder
# 125            Secret_of_success vs Sennen_goroshi     Secret_of_success
# 126                             Nocrowx vs Nocrowx               Nocrowx
# 127                     Sennen_goroshi vs Sgrayban        Sennen_goroshi
# 128                     Legolas2186 vs Legolas2186           Legolas2186
# 129                           Spitfire vs Spitfire              Spitfire
# 130                 Simoncursitor vs Simoncursitor         Simoncursitor
# 131                               Irvine22 vs Itub              Irvine22
# 132             MyMoloboaccount vs MyMoloboaccount       MyMoloboaccount
# 133                               Kudzu1 vs Kudzu1                Kudzu1
# 134                                 Mayalld vs MCB               Mayalld
# 135                               Wobble vs Wobble                Wobble
# 136                         Milomedes vs Milomedes             Milomedes
# 137                   Orangemarlin vs Orangemarlin          Orangemarlin
# 138                         Tijfo098 vs Tintin1107              Tijfo098
# 139                               U21980 vs UpDown                U21980
# 140                           Tijfo098 vs Tijfo098              Tijfo098
# 141                      IvoShandor vs Jasper_Deng            IvoShandor
# 142                                   Tvoz vs Tvoz                  Tvoz
# 143                               SKS2K6 vs SKS2K6                SKS2K6
# 144                       Lear_21 vs Ledenierhomme               Lear_21
# 145                   Hodja_Nasreddin vs HonestopL       Hodja_Nasreddin
# 146                   Paul_Siebert vs PeterSymonds          Paul_Siebert
# 147                        Richard_Daft vs Rjecina          Richard_Daft
# 148                                   NJGW vs NJGW                  NJGW
# 149               ZjarriRrethues vs ZjarriRrethues        ZjarriRrethues
# 150                              Iain99 vs Icarus3                Iain99
# 151                           Irvine22 vs Irvine22              Irvine22
# 152                            NoCal100 vs Nocrowx              NoCal100
# 153                              JMRH6 vs Johnuniq                 JMRH6
# 154                             Mathsci vs Mathsci               Mathsci
# 155                VsevolodKrolikov vs WIKI-GUY-16      VsevolodKrolikov
# 156                   PeterSymonds vs PeterSymonds          PeterSymonds
# 157   William_M._Connolley vs William_M._Connolley  William_M._Connolley
# 158                      RolandR vs SaliereTheFish               RolandR
# 159                   Ledenierhomme vs Legolas2186         Ledenierhomme
# 160                      Intangible vs Intothefire            Intangible
# 161                                     MCB vs MCB                   MCB
# 162                               N419BH vs N419BH                N419BH
# 163                         Multixfer vs Multixfer             Multixfer
# 164                               Mangoe vs Mangoe                Mangoe
# 165                       MezzoMezzo vs MezzoMezzo            MezzoMezzo
# 166                      Phead128 vs PinkAmpersand              Phead128
#            unknown_author target      score  Magnitude
# 1                 HOOTmag   TRUE 161.614000 161.614000
# 2                 Icarus3   TRUE 153.800067 153.800067
# 3                 Rjecina   TRUE 118.796333 118.796333
# 4                 Lear_21   TRUE 101.188267 101.188267
# 5            Richard_Daft   TRUE  97.970333  97.970333
# 6                 RolandR  FALSE -80.528467  80.528467
# 7                Pro-Lick   TRUE  78.520867  78.520867
# 8              Jim_Hardie   TRUE  73.956867  73.956867
# 9                 Snowded   TRUE  60.933467  60.933467
# 10               WilliamH  FALSE -60.783400  60.783400
# 11                 Yoenit   TRUE  60.363067  60.363067
# 12                 KBlott   TRUE  55.522200  55.522200
# 13                Snowded  FALSE -55.071000  55.071000
# 14            Jimharlow99   TRUE  53.548867  53.548867
# 15           JereKrischel   TRUE  52.744133  52.744133
# 16                     Vr   TRUE  52.380867  52.380867
# 17                 Vedant   TRUE  50.775467  50.775467
# 18         Sennen_goroshi   TRUE  49.705867  49.705867
# 19           Paul_Siebert   TRUE  48.321400  48.321400
# 20             Jim_Hardie  FALSE -47.409067  47.409067
# 21            Soapfan2013   TRUE  47.122867  47.122867
# 22                 Iain99   TRUE  46.865867  46.865867
# 23                   Itub   TRUE  46.722800  46.722800
# 24          Ledenierhomme   TRUE  44.549600  44.549600
# 25                 Iain99  FALSE -42.095733  42.095733
# 26             Obamafan70   TRUE  40.894400  40.894400
# 27  Jeffrey_Vernon_Merkey   TRUE  39.656667  39.656667
# 28                Mayalld   TRUE  39.614867  39.614867
# 29                Spaully  FALSE -39.027333  39.027333
# 30              Notpietru  FALSE -38.515467  38.515467
# 31             Nirvana888   TRUE  37.432733  37.432733
# 32           Marine_69-71   TRUE  36.243933  36.243933
# 33                 Maunus   TRUE  34.552000  34.552000
# 34        The_Four_Deuces   TRUE  34.157267  34.157267
# 35             Salix_alba   TRUE  33.733867  33.733867
# 36          JerryFriedman   TRUE  33.485000  33.485000
# 37             Nirvana888  FALSE -33.420000  33.420000
# 38         142.196.88.228  FALSE -33.414400  33.414400
# 39                Spaully   TRUE  33.225267  33.225267
# 40          Mystichumwipe   TRUE  32.708600  32.708600
# 41               Johnuniq   TRUE  32.257400  32.257400
# 42           Sally_Season  FALSE -32.214467  32.214467
# 43             MezzoMezzo  FALSE -32.188333  32.188333
# 44           Sean.hoyland   TRUE  32.029867  32.029867
# 45               WilliamH   TRUE  31.118267  31.118267
# 46                  JMRH6   TRUE  30.952533  30.952533
# 47                    Xtv   TRUE  28.339600  28.339600
# 48               Spitfire  FALSE -27.065067  27.065067
# 49          PinkAmpersand   TRUE  26.719000  26.719000
# 50                RolandR   TRUE  26.627133  26.627133
# 51                 U21980  FALSE -26.429000  26.429000
# 52                 Vedant  FALSE -26.210133  26.210133
# 53               SriSuren   TRUE  25.971533  25.971533
# 54             Intangible   TRUE  25.497733  25.497733
# 55               Sgrayban   TRUE  25.029000  25.029000
# 56       Musical_Linguist   TRUE  24.939067  24.939067
# 57          Simoncursitor  FALSE -24.777733  24.777733
# 58                  Meowy   TRUE  24.736067  24.736067
# 59          Livelikemusic   TRUE  24.356267  24.356267
# 60                Protonk  FALSE -24.179400  24.179400
# 61            Soapfan2013  FALSE -24.127600  24.127600
# 62             Tintin1107   TRUE  24.108667  24.108667
# 63                    Xtv  FALSE  24.038400  24.038400
# 64                 N419BH  FALSE -22.904133  22.904133
# 65         ZjarriRrethues  FALSE -22.850667  22.850667
# 66            Ottava_Rima   TRUE  22.826667  22.826667
# 67                 Maunus  FALSE  22.692800  22.692800
# 68                 SKS2K6  FALSE -22.647467  22.647467
# 69               Phead128   TRUE  22.541600  22.541600
# 70       Musical_Linguist  FALSE -22.386733  22.386733
# 71        Hodja_Nasreddin   TRUE  21.316867  21.316867
# 72                   NJGW  FALSE -20.753067  20.753067
# 73        MyMoloboaccount  FALSE -20.710667  20.710667
# 74               Jwanders   TRUE  20.571267  20.571267
# 75                Protonk   TRUE  20.246800  20.246800
# 76               Mareklug  FALSE -19.971867  19.971867
# 77             IvoShandor   TRUE  19.907533  19.907533
# 78                 U21980   TRUE  19.615400  19.615400
# 79       Scheinwerfermann   TRUE  19.057600  19.057600
# 80             Intangible  FALSE -18.848733  18.848733
# 81  Jeffrey_Vernon_Merkey  FALSE -18.722267  18.722267
# 82               Ramdrake  FALSE -18.572267  18.572267
# 83       VsevolodKrolikov  FALSE -17.879733  17.879733
# 84                Livitup  FALSE -17.591267  17.591267
# 85                 Nathan   TRUE  17.579467  17.579467
# 86      StillStanding-247   TRUE  17.511400  17.511400
# 87       VsevolodKrolikov   TRUE -17.480867  17.480867
# 88               O_Fenian   TRUE  17.429267  17.429267
# 89                  JMRH6  FALSE  17.395533  17.395533
# 90               Kashmiri   TRUE  17.351600  17.351600
# 91            Ottava_Rima  FALSE -17.288400  17.288400
# 92        KillerChihuahua  FALSE  16.995267  16.995267
# 93                     Vr  FALSE -16.941333  16.941333
# 94             Viewfinder  FALSE -16.820467  16.820467
# 95                   Jc37   TRUE  16.789400  16.789400
# 96        KillerChihuahua   TRUE  16.782600  16.782600
# 97              Nil_Einne   TRUE -16.773467  16.773467
# 98   William_M._Connolley  FALSE  16.766267  16.766267
# 99              Multixfer  FALSE -16.756667  16.756667
# 100            Salix_alba  FALSE -16.545667  16.545667
# 101             Nil_Einne  FALSE -16.508267  16.508267
# 102                  Tvoz  FALSE -16.469867  16.469867
# 103           Intothefire   TRUE  16.387000  16.387000
# 104         Mystichumwipe  FALSE -16.367133  16.367133
# 105                Kudzu1  FALSE -16.124733  16.124733
# 106        Magog_the_Ogre  FALSE -16.117867  16.117867
# 107                 T34CH  FALSE -16.093067  16.093067
# 108              Ramdrake   TRUE  16.068733  16.068733
# 109              SriSuren  FALSE -15.135133  15.135133
# 110     StillStanding-247  FALSE -15.065133  15.065133
# 111             Notpietru   TRUE  14.831933  14.831933
# 112          Richard_Daft  FALSE -14.667200  14.667200
# 113         StephenBuxton  FALSE -14.532067  14.532067
# 114          Media_anthro  FALSE -14.257000  14.257000
# 115               Mayalld  FALSE  14.103333  14.103333
# 116              Jbmurray  FALSE -13.961933  13.961933
# 117                UpDown   TRUE  13.792667  13.792667
# 118         JerryFriedman  FALSE -13.598133  13.598133
# 119               HOOTmag  FALSE -13.158267  13.158267
# 120             Thekohser   TRUE  13.094533  13.094533
# 121             HonestopL   TRUE -13.091333  13.091333
# 122           Peter_James   TRUE  12.643067  12.643067
# 123        SaliereTheFish   TRUE  12.439867  12.439867
# 124            Viewfinder   TRUE  12.431933  12.431933
# 125        Sennen_goroshi  FALSE -12.401267  12.401267
# 126               Nocrowx   TRUE  12.375067  12.375067
# 127              Sgrayban  FALSE -12.251333  12.251333
# 128           Legolas2186   TRUE -12.245867  12.245867
# 129              Spitfire   TRUE -11.902867  11.902867
# 130         Simoncursitor   TRUE  11.787733  11.787733
# 131                  Itub  FALSE  11.704200  11.704200
# 132       MyMoloboaccount   TRUE  11.643533  11.643533
# 133                Kudzu1   TRUE  11.546933  11.546933
# 134                   MCB  FALSE -11.511533  11.511533
# 135                Wobble   TRUE  11.273067  11.273067
# 136             Milomedes   TRUE  11.228467  11.228467
# 137          Orangemarlin   TRUE  10.855667  10.855667
# 138            Tintin1107  FALSE -10.812600  10.812600
# 139                UpDown  FALSE -10.703400  10.703400
# 140              Tijfo098   TRUE -10.578000  10.578000
# 141           Jasper_Deng  FALSE -10.521267  10.521267
# 142                  Tvoz   TRUE  10.361000  10.361000
# 143                SKS2K6   TRUE   9.802933   9.802933
# 144         Ledenierhomme  FALSE   9.478200   9.478200
# 145             HonestopL  FALSE   9.259067   9.259067
# 146          PeterSymonds  FALSE  -9.059267   9.059267
# 147               Rjecina  FALSE  -8.983200   8.983200
# 148                  NJGW   TRUE  -8.915533   8.915533
# 149        ZjarriRrethues   TRUE   8.893733   8.893733
# 150               Icarus3  FALSE   8.846000   8.846000
# 151              Irvine22   TRUE   8.628400   8.628400
# 152               Nocrowx  FALSE  -8.566667   8.566667
# 153              Johnuniq  FALSE  -8.531533   8.531533
# 154               Mathsci   TRUE   8.004067   8.004067
# 155           WIKI-GUY-16  FALSE  -7.880133   7.880133
# 156          PeterSymonds   TRUE   7.748067   7.748067
# 157  William_M._Connolley   TRUE  -7.471533   7.471533
# 158        SaliereTheFish  FALSE  -7.043267   7.043267
# 159           Legolas2186  FALSE   7.031800   7.031800
# 160           Intothefire  FALSE  -6.721267   6.721267
# 161                   MCB   TRUE   6.718533   6.718533
# 162                N419BH   TRUE   6.683267   6.683267
# 163             Multixfer   TRUE   6.402933   6.402933
# 164                Mangoe   TRUE   6.359067   6.359067
# 165            MezzoMezzo   TRUE   6.076933   6.076933
# 166         PinkAmpersand  FALSE   5.992533   5.992533
#  [ reached 'max' / getOption("max.print") -- omitted 58 rows ]

# %%
process_group_lambdag <- function(paraphrasing_model, scoring_model, corpus, min_token_size) {
  "Function to process the lambdaG results"

  # Filter score_data by the combination
  problems <- token_size_problems %>%
    filter(corpus == !!corpus,
           min_token_size == !!min_token_size)
  
  filtered_lambdag <- lambdag_raw %>%
    inner_join(problems, by=c('problem', 'target'))

  # Run your performance function (assume it returns a 1-row data frame)
  perf <- performance(filtered_lambdag)
  perf <- perf$evaluation

  # Add the identifying columns
  cbind(
    data.frame(paraphrasing_model = paraphrasing_model,
               scoring_model = scoring_model,
               corpus = corpus,
               min_token_size = min_token_size),
    perf
  )
}

# %%
results_lambdag <- distinct_corpus_sizes %>%
  pmap_dfr(process_group_lambdag)
# Out:
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases
#   |=========================================================================| 100%
# Setting levels: control = FALSE, case = TRUE
# Setting direction: controls < cases

# %%
results_lambdag %>% head()
# Out:
#   paraphrasing_model scoring_model corpus min_token_size      Cllr  Cllr_min
# 1            LambdaG       LambdaG   Wiki              2 0.6476871 0.5243020
# 2            LambdaG       LambdaG   Wiki              3 0.6374915 0.5171254
# 3            LambdaG       LambdaG   Wiki              4 0.6061458 0.4756306
# 4            LambdaG       LambdaG   Wiki              5 0.6872042 0.4197365
#        EER Mean TRUE LLR Mean FALSE LLR TRUE trials FALSE trials       AUC
# 1 16.66667      1.092086     -0.7585601         114          114 0.9011480
# 2 16.44444      1.139849     -0.7887780         113          112 0.9049140
# 3 14.59695      1.331042     -0.8316408          92           55 0.9171908
# 4 15.33742      1.709290     -0.6700987          50           12 0.8895833
#   Balanced Accuracy Precision    Recall        F1 TP FN FP TN
# 1         0.8303571 0.8303571 0.8303571 0.8303571 93 19 19 93
# 2         0.8325962 0.8363636 0.8288288 0.8325792 92 19 18 92
# 3         0.8545073 0.9250000 0.8222222 0.8705882 74 16  6 47
# 4         0.8666667 0.9756098 0.8333333 0.8988764 40  8  1  9

# %% [markdown]
# ### Combine Results with LambdaG Results

# %%
results_combined <- rbind(results, results_lambdag) %>%
  arrange(corpus, min_token_size, paraphrasing_model, scoring_model)

# %%
results_combined %>% head(12)
# Out:
#    paraphrasing_model scoring_model corpus min_token_size      Cllr  Cllr_min
# 1             LambdaG       LambdaG   Wiki              2 0.6476871 0.5243020
# 2     ModernBERT-base          gpt2   Wiki              2 0.8596104 0.7608662
# 3    ModernBERT-large          gpt2   Wiki              2 0.8777187 0.7732053
# 4                gpt5         gemma   Wiki              2 0.8856810 0.8033393
# 5                gpt5          gpt2   Wiki              2 0.8456774 0.7535165
# 6                gpt5         llama   Wiki              2 0.8878195 0.8066612
# 7                gpt5          qwen   Wiki              2 0.8499285 0.7611920
# 8             LambdaG       LambdaG   Wiki              3 0.6374915 0.5171254
# 9     ModernBERT-base          gpt2   Wiki              3 0.7933321 0.6895292
# 10   ModernBERT-large          gpt2   Wiki              3 0.8119625 0.7151030
# 11               gpt5         gemma   Wiki              3 0.7703894 0.6627526
# 12               gpt5          gpt2   Wiki              3 0.7630833 0.6552707
#         EER Mean TRUE LLR Mean FALSE LLR TRUE trials FALSE trials       AUC
# 1  16.66667     1.0920856     -0.7585601         114          114 0.9011480
# 2  27.97534     0.3504266     -0.2351931         114          114 0.7696110
# 3  29.38808     0.2973148     -0.2055614         106          107 0.7494505
# 4  31.23065     0.2539625     -0.1932376         114          114 0.7472098
# 5  28.20513     0.4098410     -0.2536523         114          114 0.7797353
# 6  31.05023     0.2469576     -0.1902074         114          114 0.7445791
# 7  28.57143     0.3931037     -0.2467528         114          114 0.7739955
# 8  16.44444     1.1398488     -0.7887780         113          112 0.9049140
# 9  25.96445     0.8352370     -0.3209288         113          112 0.8167895
# 10 26.84168     0.7644592     -0.2896310         105          104 0.7994479
# 11 24.86679     0.9072306     -0.3567380         113          112 0.8347256
# 12 25.12690     1.1316664     -0.3598566         113          112 0.8332514
#    Balanced Accuracy Precision    Recall        F1 TP FN FP TN
# 1          0.8303571 0.8303571 0.8303571 0.8303571 93 19 19 93
# 2          0.7187500 0.7425743 0.6696429 0.7042254 75 37 26 86
# 3          0.6936813 0.7000000 0.6730769 0.6862745 70 34 30 75
# 4          0.6830357 0.6915888 0.6607143 0.6757991 74 38 33 79
# 5          0.7276786 0.7524752 0.6785714 0.7136150 76 36 25 87
# 6          0.6919643 0.7047619 0.6607143 0.6820276 74 38 31 81
# 7          0.7187500 0.7333333 0.6875000 0.7096774 77 35 28 84
# 8          0.8325962 0.8363636 0.8288288 0.8325792 92 19 18 92
# 9          0.7242424 0.7551020 0.6666667 0.7081340 74 37 24 86
# 10         0.7222540 0.7555556 0.6601942 0.7046632 68 35 22 80
# 11         0.7559378 0.7938144 0.6936937 0.7403846 77 34 20 90
# 12         0.7605242 0.8085106 0.6846847 0.7414634 76 35 18 92

# %%
results_combined %>%
  write_xlsx(paste0(base_location, "/idiolect_token_results_summary_avg_logprobs.xlsx"))
