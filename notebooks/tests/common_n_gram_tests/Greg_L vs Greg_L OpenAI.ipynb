# %%
import sys
import os
import json

import pandas as pd

# %%
sys.path.append(os.path.abspath('../../../src'))

from read_and_write_docs import read_jsonl, read_rds
from tokenize_and_score import load_model
from utils import apply_temp_doc_id, build_metadata_df
from n_gram_functions import (
    common_ngrams,
    pretty_print_common_ngrams,
    keep_before_phrase,
    score_phrases,
    add_pmf_column,
    score_phrases_no_context,
    compute_log_probs_with_median
)
from open_ai import initialise_client, llm

# %%
corpus = "Wiki"
data_type = "training"

known_loc = f"/Volumes/BCross/datasets/author_verification/{data_type}/{corpus}/known_raw.jsonl"
known = read_jsonl(known_loc)
known = apply_temp_doc_id(known)

unknown_loc = f"/Volumes/BCross/datasets/author_verification/{data_type}/{corpus}/unknown_raw.jsonl"
unknown = read_jsonl(unknown_loc)
unknown_df = apply_temp_doc_id(unknown)

metadata_loc = f"/Volumes/BCross/datasets/author_verification/{data_type}/metadata.rds"
metadata = read_rds(metadata_loc)
filtered_metadata = metadata[metadata['corpus'] == corpus]
agg_metadata = build_metadata_df(filtered_metadata, known, unknown)

# %%
problem_dataset_agg = read_jsonl("/Users/user/Documents/test_data/n-gram_tracing/Wiki_training_agg.jsonl")
problem_dataset_profile = read_jsonl("/Users/user/Documents/test_data/n-gram_tracing/Wiki_training_profile.jsonl")

# %%
same_author_problems = problem_dataset_agg[problem_dataset_agg['known_author'] == problem_dataset_agg['unknown_author']].copy()
same_author_problems.sort_values(["highest_common_count"], ascending=[False], inplace=True)
same_author_problems[(same_author_problems['highest_common_count'] >= 3) & (same_author_problems['highest_common_count'] <= 10)]
# Out:
#                                     problem       known_author  \
# 379                        Greg_L vs Greg_L             Greg_L
# 432                    Haymaker vs Haymaker           Haymaker
# 354  Fragments_of_Jade vs Fragments_of_Jade  Fragments_of_Jade
# 337                Fixentries vs Fixentries         Fixentries
# 248        DonaNobisPacem vs DonaNobisPacem     DonaNobisPacem
# ..                                      ...                ...
# 222      David_Shankbone vs David_Shankbone    David_Shankbone
# 211                    D7G1DX~0 vs D7G1DX~0           D7G1DX~0
# 187                      Collect vs Collect            Collect
# 198                      Cptnono vs Cptnono            Cptnono
# 218                Danlaycock vs Danlaycock         Danlaycock
#
#         unknown_author              known_doc_id             unknown_doc_id  \
# 379             Greg_L            greg_l_text_11             greg_l_text_10
# 432           Haymaker           haymaker_text_3            haymaker_text_2
# 354  Fragments_of_Jade  fragments_of_jade_text_2  fragments_of_jade_text_10
# 337         Fixentries         fixentries_text_2          fixentries_text_5
# 248     DonaNobisPacem     donanobispacem_text_5      donanobispacem_text_2
# ..                 ...                       ...                        ...
# 222    David_Shankbone    david_shankbone_text_1     david_shankbone_text_4
# 211           D7G1DX~0           d7g1dx_0_text_2            d7g1dx_0_text_5
# 187            Collect           collect_text_12            collect_text_11
# 198            Cptnono            cptnono_text_1            cptnono_text_12
# 218         Danlaycock         danlaycock_text_5          danlaycock_text_2
#
#      highest_common_count                               highest_common_ngram
# 379                     9  , Ġthey Ġshould Ġhave Ġparticipated Ġin Ġthe Ġ...
# 432                     9              Ġat Ġthe Ġend Ġof Ġthe Ġday , Ġwe 're
# 354                     8                 Ġme , Ġand Ġit 's Ġgetting Ġold .Ċ
# 337                     8  Ġthe Ġindividual Ġher it ability Ġof Ġintellig...
# 248                     8                          Ġafter Ġ 1 8 - 2 0 Ġweeks
# ..                    ...                                                ...
# 222                     3                                       , Ġwhich Ġis
# 211                     3                                     Ġdon 't Ġthink
# 187                     3                                          , Ġand Ġi
# 198                     3                                       , Ġthough .Ċ
# 218                     3                                          .Ċ also ,
#
# [197 rows x 7 columns]

# %%
known_doc = "greg_l_text_11"
known_text = known[known['doc_id'] == known_doc].reset_index().loc[0, 'text']

unknown_doc = "greg_l_text_10"
unknown_text = unknown[unknown['doc_id'] == unknown_doc].reset_index().loc[0, 'text']

specific_problem_metadata = agg_metadata[(agg_metadata['known_doc_id'] == known_doc) & ((agg_metadata['unknown_doc_id'] == unknown_doc))].reset_index()
specific_problem_metadata['target'] = specific_problem_metadata['known_author'] == specific_problem_metadata['unknown_author']
specific_problem = specific_problem_metadata.loc[0, 'problem']
# Out:
# 'Greg_L vs Greg_L'

# %%
tokenizer, model = load_model("/Volumes/BCross/models/Qwen 2.5/Qwen2.5-0.5B-Instruct")

# %%
common = common_ngrams(known_text, unknown_text, 2, model, tokenizer, lowercase=True)

# %%
n_gram_list = pretty_print_common_ngrams(common, tokenizer=tokenizer, order='len_desc', return_format='flat')
n_gram_list
# Out:
# [' allege harbor views that are contrary to the consensus',
#  ', they should have participated in the poll.\n',
#  ' had felt they had',
#  ' dicklyon',
#  ' meritorious',
#  ' the eight editors',
#  ' consensus view',
#  ' of the',
#  ' such as',
#  ' was a',
#  '.\nyou']

# %% [markdown]
# ## Initialise OpenAI Stuff

# %%
client = initialise_client("../../../credentials.json")

# %%
def create_user_prompt(known_text, phrase):
    user_prompt = f"""
<DOC>
{known_text}
</DOC>
<NGRAM>
"{phrase}"
</NGRAM>
"""
    
    return user_prompt

# %%
def create_system_prompt(prompt_loc):
    with open(prompt_loc,"r") as f:
        system_prompt = f.read()
        
    return system_prompt

# %%
def parse_paraphrases(response, phrase):
    
    paraphrase_list = []
    for i in range(1, len(response.choices)):
        content = response.choices[i].message.content
        
        try:
            content_json = json.loads(content)
            for para in content_json['paraphrases']:
                if para != phrase:
                    paraphrase_list.append(para)  
        except:
            pass
        
    unique_list = list(set(paraphrase_list))
    
    return unique_list

# %%
system_prompt = create_system_prompt("../../../prompts/exhaustive_constrained_ngram_paraphraser_prompt_JSON.txt")

# %%
n_gram_dict = {}
width = len(str(len(n_gram_list)))  # e.g., 10 -> 2, 100 -> 3

for idx, phrase in enumerate(n_gram_list, start=1):
    user_prompt = create_user_prompt(known_text, phrase)
    response = llm(
        system_prompt,
        user_prompt,
        client,
        model="gpt-4.1",
        max_tokens=5000,
        temperature=0.7,
        n=10,
        response_format={"type": "json_object"},
    )
    paraphrases = parse_paraphrases(response, phrase)
    key = f"phrase_{idx:0{width}d}"  # -> phrase_01, phrase_002, etc.
    n_gram_dict[key] = {"phrase": phrase, "paraphrases": paraphrases}

# %%
n_gram_dict
# Out:
# {'phrase_01': {'phrase': ' allege harbor views that are contrary to the consensus',
#   'paraphrases': ['allege have views that differ from the consensus',
#    'allege harbour beliefs which are contrary to the consensus',
#    'allege harbor views that run counter to the consensus',
#    ' allege harbor opinions which are opposed to the consensus',
#    'allege have opinions that are contrary to the consensus',
#    'allege have beliefs that are contrary to the consensus',
#    'allege possess views that go against the consensus',
#    ' allege harbor opinions that are contrary to consensus',
#    ' allege harbor beliefs which are opposed to the consensus',
#    'allege harbour opinions that run counter to the consensus',
#    'allege harbor opinions that are contrary to consensus',
#    ' allege have opinions that are contrary to consensus',
#    ' allege harbor beliefs that go against the consensus',
#    ' allege harbour beliefs which are contrary to the consensus',
#    'allege possess views which are contrary to the consensus',
#    'allege harbor beliefs inconsistent with the consensus',
#    ' allege harbour views that are at odds with the consensus',
#    'allege harbour opinions that are not in line with the consensus',
#    ' allege harbor opinions which are contrary to the consensus',
#    ' allege hold opinions that are opposed to the consensus',
#    'allege possess views that run counter to the consensus',
#    'allege harbor views that are contrary to the consensus',
#    'allege harbor opinions that do not align with the consensus',
#    'allege harbor opinions which are contrary to the consensus',
#    'allege harbour opinions that are contrary to the consensus',
#    'allege harbor beliefs that differ from the consensus',
#    'allege harbor opinions that are inconsistent with the consensus',
#    'allege harbour viewpoints that are contrary to the consensus',
#    ' allege harbor views that go against the consensus',
#    ' allege harbour views that are contrary to the consensus',
#    'allege harbour opinions contrary to the consensus',
#    ' allege harbour views opposed to the consensus',
#    'allege hold views that are not aligned with the consensus',
#    "allege harbor beliefs that don't align with the consensus",
#    ' allege hold beliefs contrary to the consensus',
#    ' allege have opinions contrary to the consensus',
#    'allege harbour opinions at odds with the consensus',
#    ' allege harbor beliefs contrary to the consensus',
#    ' allege harbor viewpoints that are at odds with the consensus',
#    'allege harbour beliefs that are inconsistent with the consensus',
#    ' allege hold opinions that are contrary to the consensus',
#    ' allege harbor views that are at odds with the consensus',
#    'allege have views that are contrary to the consensus',
#    'allege harbour beliefs that conflict with the consensus',
#    'allege harbor beliefs which are contrary to the consensus',
#    ' allege hold views that are opposed to the consensus',
#    'allege have views inconsistent with the consensus',
#    'allege harbour beliefs that are not aligned with the consensus',
#    'allege harbour opinions inconsistent with the consensus',
#    ' allege harbour views contrary to the consensus',
#    ' allege harbor viewpoints that go against the consensus',
#    'allege harbor opinions that are not in line with the consensus',
#    'allege possess views that are inconsistent with the consensus',
#    'allege harbour views that are opposed to the consensus',
#    'allege that harbour opinions that are contrary to the consensus',
#    ' allege possess opinions that are at odds with the consensus',
#    ' allege harbour viewpoints that are opposed to the consensus',
#    'allege harbour opinions that do not align with the consensus',
#    'allege harbour opinions that go against the consensus',
#    'allege that harbour views that are contrary to the consensus',
#    ' allege harbor viewpoints that contradict the consensus',
#    ' allege harbour views that go against the consensus',
#    ' allege have beliefs that are opposed to the consensus',
#    ' allege harbor opinions that are contrary to the consensus',
#    'allege harbor views that are contrary to the consensuses',
#    'allege possess views that conflict with the consensus',
#    'allege hold views which are contrary to the consensus',
#    ' allege harbour opinions that are opposed to the consensus',
#    'allege harbor beliefs that run counter to the consensus',
#    ' allege harbor views which are contrary to the consensus',
#    'allege have views that are not aligned with the consensus',
#    ' allege possess views that are contrary to the consensus',
#    ' allege harbor views that are opposed to the consensus',
#    'allege harbor views contrary to the consensus',
#    ' allege have views that are contrary to the consensus',
#    'allege harbour beliefs that do not align with the consensus',
#    "allege harbour beliefs that don't align with the consensus",
#    'allege harbour opinions that differ from the consensus',
#    'allege hold views inconsistent with the consensus',
#    ' allege possess beliefs that are at odds with the consensus',
#    ' allege hold opinions that are at odds with the consensus',
#    ' allege hold opinions that contradict the consensus',
#    ' allege harbour opinions contrary to the consensus',
#    'allege maintain views that are contrary to consensus',
#    ' allege possess views that contradict the consensus',
#    ' allege hold beliefs that are opposed to the consensus',
#    'allege possess views that are opposed to the consensus',
#    'allege harbor views that conflict with the consensus',
#    'allege have views that conflict with the consensus',
#    'allege harbor viewpoints that are contrary to the consensus',
#    'allege harbour views that are not in line with the consensus',
#    'allege harbour beliefs that are not in line with the consensus',
#    'allege hold views that do not align with the consensus',
#    'allege harbor views inconsistent with the consensus',
#    ' allege have beliefs that contradict the consensus',
#    'allege harbor opinions at odds with the consensus',
#    ' allege hold views contrary to the consensus',
#    'allege possess views inconsistent with the consensus',
#    "allege have views that don't align with the consensus",
#    'allege hold opinions that are contrary to consensus',
#    'allege harbour beliefs that are opposed to the consensus',
#    'allege harbor beliefs that are not aligned with the consensus',
#    'allege harbour opinions that are not aligned with the consensus',
#    ' allege harbor views contrary to the consensus',
#    ' allege harbour beliefs that are contrary to the consensus',
#    'allege harbor views that are inconsistent with the consensus',
#    "allege possess views that don't align with the consensus",
#    ' allege possess beliefs that are contrary to the consensus',
#    'allege possess opinions that are contrary to consensus',
#    ' allege harbour viewpoints that are at odds with the consensus',
#    ' allege hold views that are contrary to the consensus',
#    'allege have views that do not align with the consensus',
#    ' allege possess views that are contrary to consensus',
#    'allege harbour views inconsistent with the consensus',
#    ' allege have opinions that contradict the consensus',
#    'allege harbour views contrary to the consensus',
#    'allege that harbour views contrary to the consensus',
#    ' allege harbor beliefs which are contrary to the consensus',
#    ' allege harbour opinions which are opposed to the consensus',
#    ' allege harbour viewpoints that go against the consensus',
#    'allege harbor opinions that run counter to the consensus',
#    ' allege harbour opinions which are contrary to the consensus',
#    'allege harbor views which are contrary to the consensus',
#    "allege harbor views that don't align with the consensus",
#    ' allege harbour beliefs that contradict the consensus',
#    'allege harbor beliefs that do not align with the consensus',
#    ' allege harbor beliefs that are opposed to the consensus',
#    'allege harbor beliefs that are inconsistent with the consensus',
#    ' allege harbor opinions that are opposed to the consensus',
#    ' allege harbour beliefs which are opposed to the consensus',
#    ' allege harbour opinions that are contrary to the consensus',
#    "allege harbour opinions that don't align with the consensus",
#    'allege hold views that are opposed to the consensus',
#    'allege harbour opinions that conflict with the consensus',
#    'allege have views that go against the consensus',
#    'allege harbor beliefs that conflict with the consensus',
#    ' allege have opinions that are at odds with the consensus',
#    'allege harbor views that are contrary to consensus',
#    'allege harbor opinions that differ from the consensus',
#    'allege harbor opinions that conflict with the consensus',
#    'allege possess opinions that are contrary to the consensus',
#    ' allege have views that contradict the consensus',
#    ' allege possess opinions contrary to the consensus',
#    ' allege have views that are contrary to consensus',
#    'allege possess views that do not align with the consensus',
#    'allege harbour opinions that are opposed to the consensus',
#    'allege harbor opinions contrary to the consensus',
#    ' allege possess views that are opposed to the consensus',
#    ' allege harbour beliefs that are at odds with the consensus',
#    'allege hold beliefs that are contrary to the consensus',
#    'allege harbour views that are inconsistent with the consensus',
#    'allege harbor opinions inconsistent with the consensus',
#    'allege harbour beliefs that differ from the consensus',
#    ' allege harbour beliefs contrary to the consensus',
#    ' allege harbor views that are contrary to consensus',
#    'allege that harbor views that are contrary to the consensus',
#    ' allege harbour opinions that are contrary to consensus',
#    ' allege possess beliefs contrary to the consensus',
#    'allege harbour beliefs that are contrary to the consensus',
#    ' allege harbour opinions that are at odds with the consensus',
#    'allege hold views that go against the consensus',
#    'allege possess views that are not aligned with the consensus',
#    ' allege harbour opinions that contradict the consensus',
#    'allege have views that are not in line with the consensus',
#    ' allege harbour viewpoints that are contrary to the consensus',
#    'allege harbor beliefs that are opposed to the consensus',
#    ' allege harbour views that contradict the consensus',
#    'allege harbour opinions which are contrary to the consensus',
#    ' allege have opinions that are contrary to the consensus',
#    'allege harbor beliefs that are not in line with the consensus',
#    'allege have views that are inconsistent with the consensus',
#    'allege possess views at odds with the consensus',
#    ' allege hold beliefs that are contrary to the consensus',
#    "allege hold views that don't align with the consensus",
#    'allege have views which are contrary to the consensus',
#    ' allege harbour viewpoints which are contrary to the consensus',
#    'allege that harbor opinions that are contrary to the consensus',
#    'allege that harbour opinions contrary to the consensus',
#    ' allege harbor opinions that are at odds with the consensus',
#    "allege harbor opinions that don't align with the consensus",
#    'allege harbour beliefs at odds with the consensus',
#    'allege harbor beliefs that are contrary to the consensus',
#    'allege hold views that conflict with the consensus',
#    ' allege have views that are opposed to the consensus',
#    'allege possess views that are contrary to the consensus',
#    ' allege hold beliefs that contradict the consensus',
#    'allege hold views that differ from the consensus',
#    ' allege possess beliefs that are opposed to the consensus',
#    ' allege harbour views which are contrary to the consensus',
#    'allege harbor views that are opposed to the consensus',
#    'allege harbour views that conflict with the consensus',
#    ' allege harbour viewpoints that contradict the consensus',
#    ' allege harbour beliefs that are opposed to the consensus',
#    ' allege have opinions that are opposed to the consensus',
#    ' allege possess opinions that contradict the consensus',
#    'allege have views at odds with the consensus',
#    ' allege possess opinions that are opposed to the consensus',
#    'allege have views that are contrary to consensus',
#    'allege harbor views at odds with the consensus',
#    'allege harbour views that go against the consensus',
#    'allege harbor opinions that go against the consensus',
#    ' allege harbor beliefs that are contrary to the consensus',
#    ' allege harbour views that are opposed to the consensus',
#    ' allege harbor viewpoints which are contrary to the consensus',
#    'allege harbor opinions that are opposed to the consensus',
#    ' allege have beliefs contrary to the consensus',
#    ' allege have views that are at odds with the consensus',
#    ' allege have views contrary to the consensus',
#    'allege harbor views that differ from the consensus',
#    'allege harbor beliefs at odds with the consensus',
#    ' allege harbour views that are contrary to consensus',
#    ' allege possess beliefs that contradict the consensus',
#    ' allege possess opinions that are contrary to consensus',
#    'allege have views that are opposed to the consensus',
#    'allege harbor views that are not in line with the consensus',
#    'allege harbour views which are contrary to the consensus',
#    'allege harbor views that are not aligned with the consensus',
#    'allege hold views that run counter to the consensus',
#    'allege harbour views that are contrary to consensus',
#    ' allege harbor views opposed to the consensus',
#    'allege hold views that are not in line with the consensus',
#    'allege harbor opinions that are contrary to the consensus',
#    ' allege harbor views that contradict the consensus',
#    'allege possess views that are not in line with the consensus',
#    'allege hold opinions that are contrary to the consensus',
#    'allege harbour beliefs inconsistent with the consensus',
#    ' allege hold beliefs that are at odds with the consensus',
#    'allege maintain views that are contrary to the consensus',
#    'allege harbour opinions that are contrary to consensus',
#    'allege harbour views that differ from the consensus',
#    'allege have opinions that are contrary to consensus',
#    ' allege hold views that are contrary to consensus',
#    ' allege possess views contrary to the consensus',
#    'allege maintain opinions that are contrary to the consensus',
#    ' allege hold opinions that are contrary to consensus',
#    ' allege harbor opinions that go against the consensus',
#    'allege harbour beliefs that run counter to the consensus',
#    'allege harbor views that go against the consensus',
#    'allege harbour views at odds with the consensus',
#    'allege harbor opinions that are not aligned with the consensus',
#    ' allege hold opinions contrary to the consensus',
#    'allege harbour beliefs that go against the consensus',
#    'allege harbour views that are contrary to the consensus',
#    ' allege harbor viewpoints that are opposed to the consensus',
#    ' allege have beliefs that are contrary to the consensus',
#    'allege maintain opinions that are contrary to consensus',
#    'allege harbour views that are contrary to the consensuses',
#    'allege hold views that are inconsistent with the consensus',
#    "allege harbour views that don't align with the consensus",
#    'allege have views that run counter to the consensus',
#    ' allege possess opinions that are contrary to the consensus',
#    'allege harbor views that do not align with the consensus',
#    'allege harbour views that are not aligned with the consensus',
#    'allege harbour views that run counter to the consensus',
#    'allege hold views that are contrary to the consensus',
#    'allege harbor beliefs that go against the consensus',
#    ' allege harbor opinions that contradict the consensus',
#    'allege hold views at odds with the consensus',
#    'allege possess views that are contrary to consensus',
#    ' allege hold views that are at odds with the consensus',
#    'allege harbour opinions that are inconsistent with the consensus',
#    ' allege harbor beliefs that are at odds with the consensus',
#    'allege that harbor views contrary to the consensus',
#    ' allege have beliefs that are at odds with the consensus',
#    'allege hold views that are contrary to consensus',
#    ' allege harbour opinions that go against the consensus',
#    'allege possess views that differ from the consensus',
#    'allege harbour views that do not align with the consensus',
#    ' allege harbour beliefs that go against the consensus',
#    'allege that harbor opinions contrary to the consensus',
#    'allege possess beliefs that are contrary to the consensus',
#    ' allege harbor viewpoints that are contrary to the consensus',
#    ' allege harbor opinions contrary to the consensus',
#    ' allege harbor beliefs that contradict the consensus',
#    ' allege possess views that are at odds with the consensus',
#    ' allege hold views that contradict the consensus']},
#  'phrase_02': {'phrase': ', they should have participated in the poll.\n',
#   'paraphrases': [', they should have taken part in the poll.',
#    ", they ought've joined the poll.",
#    ", they should've taken part in the poll.",
#    ", they should've entered the poll.",
#    ', they should have joined in the poll.',
#    ", they should've participated in the poll.",
#    ", they ought to've participated in the poll.",
#    ", they ought to've taken part in the poll.",
#    ", they ought to've joined in the poll.",
#    ', they ought to have participated in the poll.',
#    ", they should've joined in the poll.",
#    ", they ought've joined in the poll.",
#    ", they should've joined the poll.",
#    ', they ought to have taken part in the poll.',
#    ', they should have joined the poll.',
#    ", they ought've participated in the poll.",
#    ", they ought've taken part in the poll.",
#    ', they ought to have joined in the poll.',
#    ', they ought to have joined the poll.',
#    ', they should have participated in the poll.',
#    ', they should have entered the poll.',
#    ", they ought to've joined the poll."]},
#  'phrase_03': {'phrase': ' had felt they had',
#   'paraphrases': ["felt they'd",
#    'had felt that they had',
#    'had felt they’d',
#    'felt they\x0020had',
#    'had felt they\x027d',
#    "had felt they'd",
#    "had believed they'd",
#    'had felt they\x020had',
#    'had believed they had',
#    'had felt that they’d',
#    'felt they had',
#    'had felt that they\x19d',
#    'had thought they had',
#    "had felt that they'd",
#    'had felt they had',
#    'had felt that they\x0027d',
#    "had thought they'd",
#    'had felt they\x19d']},
#  'phrase_04': {'phrase': ' dicklyon',
#   'paraphrases': ['" Dicklyon "',
#    '" dicklyon"',
#    '"DickLyon"',
#    '"dicklyon"',
#    '" Dicklyon"',
#    '" dicklyon "',
#    '" dick lyon"',
#    '"Dick Lyon"',
#    '"Dicklyon"']},
#  'phrase_05': {'phrase': ' meritorious',
#   'paraphrases': ['meritorious',
#    '"meritous"',
#    '" meritorious"',
#    '"worthy"',
#    'meritorius',
#    '"meritorious"',
#    '"meritorius"',
#    '" meritorius"',
#    '"meritious"',
#    '"meritable"',
#    '"deserving"']},
#  'phrase_06': {'phrase': ' the eight editors',
#   'paraphrases': ['the 8 editors',
#    '8 editors',
#    'the eight editors',
#    'eight editors']},
#  'phrase_07': {'phrase': ' consensus view',
#   'paraphrases': ['"consensus stand"',
#    '"consensus opinion"',
#    '"consensus view"',
#    '" consensus opinion"',
#    'consensus standpoint',
#    '"consensus standpoint"',
#    'the consensus perspective',
#    '"view of the consensus"',
#    '" consensus stand"',
#    'consensus perspective',
#    'perspective of the consensus',
#    'consensus position',
#    '"consensus judgement"',
#    '" consensus judgement"',
#    'consensus outlook',
#    '"consensus stand point"',
#    'consensus stance',
#    '"consensus judgment"',
#    '"consensus perspective"',
#    '" consensus position"',
#    'the consensus opinion',
#    'consensus viewpoint',
#    '"consensus point of view"',
#    '"consensus-view"',
#    '"consensus outlook"',
#    '" consensus outlook"',
#    '"consensus viewpoint"',
#    'consensus view',
#    'consensus opinion',
#    '"consensus position"',
#    '"standpoint of the consensus"',
#    '"consensus stance"',
#    'consensus stand',
#    'view of the consensus',
#    'the consensus view',
#    'standpoint of the consensus',
#    '"consensus-opinion"',
#    'viewpoint of the consensus',
#    '"consensus-point of view"',
#    '"perspective of the consensus"',
#    '"opinion of the consensus"',
#    'consensus judgment',
#    '"consensus-standpoint"',
#    '" consensus view"',
#    '"consensus-perspective"',
#    'the consensus standpoint',
#    'opinion of the consensus',
#    'consensus judgement',
#    'the consensus viewpoint',
#    '"viewpoint of the consensus"']},
#  'phrase_08': {'phrase': ' of the',
#   'paraphrases': [" o' the",
#    ' of th',
#    'of the',
#    'of th',
#    'ofthe',
#    'o f the',
#    " of th'",
#    ' ofthe']},
#  'phrase_09': {'phrase': ' such as',
#   'paraphrases': ['like',
#    ' suchas ',
#    'such as',
#    ' such as ',
#    ' like',
#    ' for example',
#    'like ',
#    ' suchas',
#    ' like ',
#    'including',
#    ' such like',
#    ' including',
#    ' for instance']},
#  'phrase_10': {'phrase': ' was a', 'paraphrases': [' was an']},
#  'phrase_11': {'phrase': '.\nyou',
#   'paraphrases': ['".  ya"',
#    '".ya"',
#    '. you"',
#    '".  U"',
#    '".you"',
#    '". U"',
#    '". you',
#    '". You"',
#    '". ya"',
#    '".you',
#    "'. you'",
#    '".  you',
#    '".u"',
#    '".  you"',
#    '. you',
#    '".  u"',
#    '".\nyou"',
#    "'.  you'",
#    '".\nYou"',
#    "'.\nyou'",
#    '". you"']}}

# %%
def get_scored_df(n_gram_dict, full_text, tokenizer, model):
    
    dfs=[]
    
    for phrase_num, entry in n_gram_dict.items():  # keeps insertion order
        phrase = entry["phrase"]
        paraphrases = entry["paraphrases"]
        
        print(f"Completing {phrase_num} - {phrase}")
        base_text = keep_before_phrase(known_text, phrase)
        
        df = score_phrases(base_text, phrase, paraphrases, tokenizer, model).copy()
        df.insert(0, "phrase_num", phrase_num)  # put at beginning
        dfs.append(df)

    return pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()

# %%
known_scored = get_scored_df(n_gram_dict, known_text, tokenizer, model)
# Out:
# Completing phrase_01 -  allege harbor views that are contrary to the consensus
# → Scoring base_text alone…
#    base_total = -167.7171
#
# → [1/277] Processing reference…
# → [2/277] Processing paraphrase…
# → [3/277] Processing paraphrase…
# → [4/277] Processing paraphrase…
# → [5/277] Processing paraphrase…
# → [6/277] Processing paraphrase…
# → [7/277] Processing paraphrase…
# → [8/277] Processing paraphrase…
# → [9/277] Processing paraphrase…
# → [10/277] Processing paraphrase…
# → [11/277] Processing paraphrase…
# → [12/277] Processing paraphrase…
# → [13/277] Processing paraphrase…
# → [14/277] Processing paraphrase…
# → [15/277] Processing paraphrase…
# → [16/277] Processing paraphrase…
# → [17/277] Processing paraphrase…
# → [18/277] Processing paraphrase…
# → [19/277] Processing paraphrase…
# → [20/277] Processing paraphrase…
# → [21/277] Processing paraphrase…
# → [22/277] Processing paraphrase…
# → [23/277] Processing paraphrase…
# → [24/277] Processing paraphrase…
# → [25/277] Processing paraphrase…
# → [26/277] Processing paraphrase…
# → [13/23] Processing paraphrase…
# → [14/23] Processing paraphrase…
# → [15/23] Processing paraphrase…
# → [16/23] Processing paraphrase…
# → [17/23] Processing paraphrase…
# → [18/23] Processing paraphrase…
# → [19/23] Processing paraphrase…
# → [20/23] Processing paraphrase…
# → [21/23] Processing paraphrase…
# → [22/23] Processing paraphrase…
# → [23/23] Processing paraphrase…
# Completing phrase_03 -  had felt they had
# → Scoring base_text alone…
#    base_total = -227.1298
#
# → [1/19] Processing reference…
# → [2/19] Processing paraphrase…
# → [3/19] Processing paraphrase…
# → [4/19] Processing paraphrase…
# → [5/19] Processing paraphrase…
# → [6/19] Processing paraphrase…
# → [7/19] Processing paraphrase…
# → [8/19] Processing paraphrase…
# → [9/19] Processing paraphrase…
# → [10/19] Processing paraphrase…
# → [11/19] Processing paraphrase…
# → [12/19] Processing paraphrase…
# → [13/19] Processing paraphrase…
# → [14/19] Processing paraphrase…
# → [15/19] Processing paraphrase…
# → [16/19] Processing paraphrase…
# → [17/19] Processing paraphrase…
# → [18/19] Processing paraphrase…
# → [19/19] Processing paraphrase…
# Completing phrase_04 -  dicklyon
# → Scoring base_text alone…
#    base_total = -892.9659
#
# → [1/10] Processing reference…
# → [2/10] Processing paraphrase…
# → [3/10] Processing paraphrase…
# → [4/10] Processing paraphrase…
# → [5/10] Processing paraphrase…
# → [6/10] Processing paraphrase…
# → [7/10] Processing paraphrase…
# → [8/10] Processing paraphrase…
# → [9/10] Processing paraphrase…
# → [10/10] Processing paraphrase…
# Completing phrase_05 -  meritorious
# → Scoring base_text alone…
#    base_total = -247.8257
#
# → [1/12] Processing reference…
# → [2/12] Processing paraphrase…
# → [3/12] Processing paraphrase…
# → [4/12] Processing paraphrase…
# → [5/12] Processing paraphrase…
# → [6/12] Processing paraphrase…
# → [7/12] Processing paraphrase…
# → [8/12] Processing paraphrase…
# → [9/12] Processing paraphrase…
# → [10/12] Processing paraphrase…
# → [11/12] Processing paraphrase…
# → [12/12] Processing paraphrase…
# Completing phrase_06 -  the eight editors
# → Scoring base_text alone…
#    base_total = -121.4257
#
# → [1/5] Processing reference…
# → [2/5] Processing paraphrase…
# → [3/5] Processing paraphrase…
# → [4/5] Processing paraphrase…
# → [5/5] Processing paraphrase…
# Completing phrase_07 -  consensus view
# → Scoring base_text alone…
#    base_total = -426.5000
#
# → [1/51] Processing reference…
# → [2/51] Processing paraphrase…
# → [3/51] Processing paraphrase…
# → [4/51] Processing paraphrase…
# → [5/51] Processing paraphrase…
# → [6/51] Processing paraphrase…
# → [7/51] Processing paraphrase…
# → [8/51] Processing paraphrase…
# → [9/51] Processing paraphrase…
# → [10/51] Processing paraphrase…
# → [11/51] Processing paraphrase…
# → [12/51] Processing paraphrase…
# → [13/51] Processing paraphrase…
# → [14/51] Processing paraphrase…
# → [15/51] Processing paraphrase…
# → [16/51] Processing paraphrase…
# → [17/51] Processing paraphrase…
# → [18/51] Processing paraphrase…
# → [19/51] Processing paraphrase…
# → [20/51] Processing paraphrase…
# → [21/51] Processing paraphrase…
# → [22/51] Processing paraphrase…
# → [23/51] Processing paraphrase…
# → [24/51] Processing paraphrase…
# → [25/51] Processing paraphrase…
# → [26/51] Processing paraphrase…
# → [27/51] Processing paraphrase…
# → [28/51] Processing paraphrase…
# → [29/51] Processing paraphrase…
# → [30/51] Processing paraphrase…
# → [31/51] Processing paraphrase…
# → [32/51] Processing paraphrase…
# → [33/51] Processing paraphrase…
# → [34/51] Processing paraphrase…
# → [35/51] Processing paraphrase…
# → [36/51] Processing paraphrase…
# → [37/51] Processing paraphrase…
# → [38/51] Processing paraphrase…
# → [39/51] Processing paraphrase…
# → [40/51] Processing paraphrase…
# → [41/51] Processing paraphrase…
# → [42/51] Processing paraphrase…
# → [43/51] Processing paraphrase…
# → [44/51] Processing paraphrase…
# → [45/51] Processing paraphrase…
# → [46/51] Processing paraphrase…
# → [47/51] Processing paraphrase…
# → [48/51] Processing paraphrase…
# → [49/51] Processing paraphrase…
# → [50/51] Processing paraphrase…
# → [51/51] Processing paraphrase…
# Completing phrase_08 -  of the
# → Scoring base_text alone…
#    base_total = -839.3382
#
# → [1/9] Processing reference…
# → [2/9] Processing paraphrase…
# → [3/9] Processing paraphrase…
# → [4/9] Processing paraphrase…
# → [5/9] Processing paraphrase…
# → [6/9] Processing paraphrase…
# → [7/9] Processing paraphrase…
# → [8/9] Processing paraphrase…
# → [9/9] Processing paraphrase…
# Completing phrase_09 -  such as
# → Scoring base_text alone…
#    base_total = -73.1008
#
# → [1/14] Processing reference…
# → [2/14] Processing paraphrase…
# → [3/14] Processing paraphrase…
# → [4/14] Processing paraphrase…
# → [5/14] Processing paraphrase…
# → [6/14] Processing paraphrase…
# → [7/14] Processing paraphrase…
# → [8/14] Processing paraphrase…
# → [9/14] Processing paraphrase…
# → [10/14] Processing paraphrase…
# → [11/14] Processing paraphrase…
# → [12/14] Processing paraphrase…
# → [13/14] Processing paraphrase…
# → [14/14] Processing paraphrase…
# Completing phrase_10 -  was a
# → Scoring base_text alone…
#    base_total = -740.0939
#
# → [1/2] Processing reference…
# → [2/2] Processing paraphrase…
# Completing phrase_11 - .
# you
# → Scoring base_text alone…
#    base_total = -892.9659
#
# → [1/22] Processing reference…
# → [2/22] Processing paraphrase…
# → [3/22] Processing paraphrase…
# → [4/22] Processing paraphrase…
# → [5/22] Processing paraphrase…
# → [6/22] Processing paraphrase…
# → [7/22] Processing paraphrase…
# → [8/22] Processing paraphrase…
# → [9/22] Processing paraphrase…
# → [10/22] Processing paraphrase…
# → [11/22] Processing paraphrase…
# → [12/22] Processing paraphrase…
# → [13/22] Processing paraphrase…
# → [14/22] Processing paraphrase…
# → [15/22] Processing paraphrase…
# → [16/22] Processing paraphrase…
# → [17/22] Processing paraphrase…
# → [18/22] Processing paraphrase…
# → [19/22] Processing paraphrase…
# → [20/22] Processing paraphrase…
# → [21/22] Processing paraphrase…
# → [22/22] Processing paraphrase…

# %%
known_scored
# Out:
#     phrase_num phrase_type                                             phrase  \
# 0    phrase_01   reference   allege harbor views that are contrary to the ...
# 1    phrase_01  paraphrase   allege have views that differ from the consensus
# 2    phrase_01  paraphrase  allege harbour beliefs which are contrary to t...
# 3    phrase_01  paraphrase  allege harbor views that run counter to the co...
# 4    phrase_01  paraphrase   allege harbor opinions which are opposed to t...
# ..         ...         ...                                                ...
# 439  phrase_11  paraphrase                                           ".\nyou"
# 440  phrase_11  paraphrase                                           '.  you'
# 441  phrase_11  paraphrase                                           ".\nYou"
# 442  phrase_11  paraphrase                                           '.\nyou'
# 443  phrase_11  paraphrase                                            ". you"
#
#                                                 tokens  sum_log_probs_base  \
# 0    [Ġallege, Ġharbor, Ġviews, Ġthat, Ġare, Ġcontr...         -167.717062
# 1    [al, lege, Ġhave, Ġviews, Ġthat, Ġdiffer, Ġfro...         -167.717062
# 2    [al, lege, Ġharbour, Ġbeliefs, Ġwhich, Ġare, Ġ...         -167.717062
# 3    [al, lege, Ġharbor, Ġviews, Ġthat, Ġrun, Ġcoun...         -167.717062
# 4    [Ġallege, Ġharbor, Ġopinions, Ġwhich, Ġare, Ġo...         -167.717062
# ..                                                 ...                 ...
# 439                                       [.Ċ, you, "]         -892.965883
# 440                                  [.'., Ġ, Ġyou, ']         -892.965883
# 441                                       [.Ċ, You, "]         -892.965883
# 442                                       [.Ċ, you, ']         -892.965883
# 443                                     [."., Ġyou, "]         -892.965883
#
#      sum_log_probs_inc_phrase  difference  \
# 0                 -214.570143   46.853081
# 1                 -218.790776   51.073714
# 2                 -225.757962   58.040900
# 3                 -224.819965   57.102903
# 4                 -221.924563   54.207500
# ..                        ...         ...
# 439               -923.521836   30.555953
# 440               -930.174937   37.209054
# 441               -920.921140   27.955257
# 442               -918.430422   25.464539
# 443               -927.013589   34.047706
#
#                                       phrase_log_probs  sum_log_probs_phrase
# 0    [-13.314923286437988, -15.109182357788086, -5....            -46.853080
# 1    [-14.468381881713867, -8.374942779541016, -8.5...            -51.073713
# 2    [-14.468381881713867, -8.374942779541016, -13....            -58.040899
# 3    [-14.468381881713867, -8.374942779541016, -14....            -57.102902
# 4    [-13.314923286437988, -15.109182357788086, -6....            -54.207499
# ..                                                 ...                   ...
# 439  [-3.666156530380249, -8.921257019042969, -10.1...            -22.751129
# 440  [-16.047304153442383, -6.903303146362305, -9.4...            -40.340238
# 441  [-3.666156530380249, -4.338685989379883, -12.1...            -20.150432
# 442  [-2.4166526794433594, -8.296977043151855, -7.2...            -17.987002
# 443  [-14.938770294189453, -11.293185234069824, -10...            -37.178890
#
# [444 rows x 9 columns]

# %%
import math
import pandas as pd

def score_phrases(
    base_text: str,
    ref_phrase: str,
    paraphrases: list[str],
    tokenizer,
    model
) -> pd.DataFrame:
    """
    Returns rows for the reference and each paraphrase with:
      sum_log_probs_phrase (log-likelihood for the phrase tokens) and
      raw_prob = exp(sum_log_probs_phrase)
    """
    # 1) score base_text
    _, log_probs_base, _ = compute_log_probs_with_median(base_text.strip(), tokenizer, model)
    base_total = sum(log_probs_base)

    items = [("reference", ref_phrase)] + [("paraphrase", p) for p in paraphrases]
    rows = []

    for ptype, phrase in items:
        # a) phrase alone → token count
        tokens_phrase, log_probs_phrase, _ = compute_log_probs_with_median(phrase, tokenizer, model)
        n_phrase_tokens = len(tokens_phrase)

        # b) full sequence
        full_text = base_text + phrase
        tokens_full, log_probs_full, _ = compute_log_probs_with_median(full_text, tokenizer, model)

        # c) full sum (base + phrase)
        sum_before = sum(log_probs_full)

        # d/e) last n tokens correspond to phrase
        phrase_tokens    = tokens_full[-n_phrase_tokens:]
        phrase_log_probs = log_probs_full[-n_phrase_tokens:]

        # f) totals
        phrase_total = sum(phrase_log_probs)
        difference   = base_total - sum_before  # typically == -phrase_total

        # raw (unnormalized) probability of the phrase given the base
        raw_prob = math.exp(phrase_total)  # may underflow to 0.0 for long phrases; that's fine

        rows.append({
            "phrase_type":               ptype,
            "phrase":                    phrase,
            "tokens":                    phrase_tokens,
            "sum_log_probs_base":        base_total,
            "sum_log_probs_inc_phrase":  sum_before,
            "difference":                difference,
            "phrase_log_probs":          phrase_log_probs,
            "sum_log_probs_phrase":      phrase_total,
            "raw_prob":                  raw_prob,
        })

    return pd.DataFrame(rows, columns=[
        "phrase_type", "phrase", "tokens",
        "sum_log_probs_base", "sum_log_probs_inc_phrase",
        "difference", "phrase_log_probs", "sum_log_probs_phrase",
        "raw_prob",
    ])


def get_scored_df(n_gram_dict, full_text, tokenizer, model):
    """Row-concat each scored df, add phrase_num, sort, then rank paraphrases within each phrase_num."""
    dfs = []
    for phrase_num, entry in n_gram_dict.items():  # relies on insertion order
        phrase = entry["phrase"]
        paraphrases = entry["paraphrases"]

        base_text = keep_before_phrase(full_text, phrase)

        df = score_phrases(base_text, phrase, paraphrases, tokenizer, model).copy()
        df.insert(0, "phrase_num", phrase_num)  # first column
        dfs.append(df)

    if not dfs:
        return pd.DataFrame(columns=["phrase_num"])

    out = pd.concat(dfs, ignore_index=True)

    # sort by phrase_num (zero-padded → lexicographic == numeric)
    out = out.sort_values("phrase_num", kind="mergesort").reset_index(drop=True)

    # rank within phrase_num: reference -> 0; paraphrases ranked by descending raw_prob starting at 1
    out["rank"] = None
    mask = out["phrase_type"].eq("paraphrase")
    out.loc[mask, "rank"] = (
        out.loc[mask]
           .groupby("phrase_num")["raw_prob"]
           .rank(method="first", ascending=False)
           .astype(int)
    )
    out.loc[out["phrase_type"].eq("reference"), "rank"] = 0
    out["rank"] = out["rank"].astype(int)

    return out

# %%
known_scored = get_scored_df(n_gram_dict, known_text, tokenizer, model)

# %%
unknown_scored = get_scored_df(n_gram_dict, unknown_text, tokenizer, model)

# %%
import math
import pandas as pd
from typing import List

def score_phrases_no_context(
    ref_phrase: str,
    paraphrases: List[str],
    tokenizer,
    model
) -> pd.DataFrame:
    """
    Score the reference and each paraphrase *without* any ranking.
    Returns:
      phrase_type, phrase, tokens, log_probs, sum_log_probs, raw_prob
    """
    items = [("reference", ref_phrase)] + [("paraphrase", p) for p in paraphrases]
    rows = []

    for idx, (ptype, phrase) in enumerate(items, start=1):
        print(f"→ [{idx}/{len(items)}] Processing {ptype}…")
        tokens_phrase, log_probs_phrase, _ = compute_log_probs_with_median(phrase, tokenizer, model)
        phrase_total = sum(log_probs_phrase)
        raw_prob = math.exp(phrase_total)  # unnormalized prob

        rows.append({
            "phrase_type":   ptype,
            "phrase":        phrase,
            "tokens":        tokens_phrase,
            "log_probs":     log_probs_phrase,
            "sum_log_probs": phrase_total,
            "raw_prob":      raw_prob,
        })

    return pd.DataFrame(rows, columns=[
        "phrase_type", "phrase", "tokens", "log_probs", "sum_log_probs", "raw_prob"
    ])

def get_scored_df_no_context(n_gram_dict, tokenizer, model):
    """
    Row-concat each score_phrases_no_context df, add phrase_num, sort by phrase_num,
    then rank paraphrases within each phrase_num by descending raw_prob.
    'reference' rows always get rank 0.
    """
    dfs = []
    for phrase_num, entry in n_gram_dict.items():  # insertion order preserved
        phrase = entry["phrase"]
        paraphrases = entry["paraphrases"]

        df = score_phrases_no_context(phrase, paraphrases, tokenizer, model).copy()
        df.insert(0, "phrase_num", phrase_num)  # make it the first column
        dfs.append(df)

    if not dfs:
        return pd.DataFrame(columns=["phrase_num"])

    out = pd.concat(dfs, ignore_index=True)

    # zero-padded keys => lexicographic equals numeric order
    out = out.sort_values("phrase_num", kind="mergesort").reset_index(drop=True)

    # Rank within phrase_num: reference -> 0; paraphrases ranked by descending raw_prob starting at 1
    out["rank"] = None
    mask_para = out["phrase_type"].eq("paraphrase")
    out.loc[mask_para, "rank"] = (
        out.loc[mask_para]
           .groupby("phrase_num")["raw_prob"]
           .rank(method="first", ascending=False)  # use "dense" if you prefer 1,2,3 without gaps
           .astype(int)
    )
    out.loc[out["phrase_type"].eq("reference"), "rank"] = 0
    out["rank"] = out["rank"].astype(int)

    return out

# %%
score_df_no_context = get_scored_df_no_context(n_gram_dict, tokenizer, model)
# Out:
# → [1/277] Processing reference…
# → [2/277] Processing paraphrase…
# → [3/277] Processing paraphrase…
# → [4/277] Processing paraphrase…
# → [5/277] Processing paraphrase…
# → [6/277] Processing paraphrase…
# → [7/277] Processing paraphrase…
# → [8/277] Processing paraphrase…
# → [9/277] Processing paraphrase…
# → [10/277] Processing paraphrase…
# → [11/277] Processing paraphrase…
# → [12/277] Processing paraphrase…
# → [13/277] Processing paraphrase…
# → [14/277] Processing paraphrase…
# → [15/277] Processing paraphrase…
# → [16/277] Processing paraphrase…
# → [17/277] Processing paraphrase…
# → [18/277] Processing paraphrase…
# → [19/277] Processing paraphrase…
# → [20/277] Processing paraphrase…
# → [21/277] Processing paraphrase…
# → [22/277] Processing paraphrase…
# → [23/277] Processing paraphrase…
# → [24/277] Processing paraphrase…
# → [25/277] Processing paraphrase…
# → [26/277] Processing paraphrase…
# → [27/277] Processing paraphrase…
# → [28/277] Processing paraphrase…
# → [29/277] Processing paraphrase…
# → [40/51] Processing paraphrase…
# → [41/51] Processing paraphrase…
# → [42/51] Processing paraphrase…
# → [43/51] Processing paraphrase…
# → [44/51] Processing paraphrase…
# → [45/51] Processing paraphrase…
# → [46/51] Processing paraphrase…
# → [47/51] Processing paraphrase…
# → [48/51] Processing paraphrase…
# → [49/51] Processing paraphrase…
# → [50/51] Processing paraphrase…
# → [51/51] Processing paraphrase…
# → [1/9] Processing reference…
# → [2/9] Processing paraphrase…
# → [3/9] Processing paraphrase…
# → [4/9] Processing paraphrase…
# → [5/9] Processing paraphrase…
# → [6/9] Processing paraphrase…
# → [7/9] Processing paraphrase…
# → [8/9] Processing paraphrase…
# → [9/9] Processing paraphrase…
# → [1/14] Processing reference…
# → [2/14] Processing paraphrase…
# → [3/14] Processing paraphrase…
# → [4/14] Processing paraphrase…
# → [5/14] Processing paraphrase…
# → [6/14] Processing paraphrase…
# → [7/14] Processing paraphrase…
# → [8/14] Processing paraphrase…
# → [9/14] Processing paraphrase…
# → [10/14] Processing paraphrase…
# → [11/14] Processing paraphrase…
# → [12/14] Processing paraphrase…
# → [13/14] Processing paraphrase…
# → [14/14] Processing paraphrase…
# → [1/2] Processing reference…
# → [2/2] Processing paraphrase…
# → [1/22] Processing reference…
# → [2/22] Processing paraphrase…
# → [3/22] Processing paraphrase…
# → [4/22] Processing paraphrase…
# → [5/22] Processing paraphrase…
# → [6/22] Processing paraphrase…
# → [7/22] Processing paraphrase…
# → [8/22] Processing paraphrase…
# → [9/22] Processing paraphrase…
# → [10/22] Processing paraphrase…
# → [11/22] Processing paraphrase…
# → [12/22] Processing paraphrase…
# → [13/22] Processing paraphrase…
# → [14/22] Processing paraphrase…
# → [15/22] Processing paraphrase…
# → [16/22] Processing paraphrase…
# → [17/22] Processing paraphrase…
# → [18/22] Processing paraphrase…
# → [19/22] Processing paraphrase…
# → [20/22] Processing paraphrase…
# → [21/22] Processing paraphrase…
# → [22/22] Processing paraphrase…

# %%
import re
import pandas as pd

# remove illegal control chars (keep \t, \n, \r)
_ILLEGAL_RE = re.compile(r"[\x00-\x08\x0B-\x0C\x0E-\x1F]")

def _clean_cell(x):
    if isinstance(x, str):
        return _ILLEGAL_RE.sub("", x)
    return x

def clean_for_excel(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    obj_cols = df.select_dtypes(include=["object"]).columns
    df[obj_cols] = df[obj_cols].applymap(_clean_cell)
    return df

# %%
save_loc = f"/Users/user/Documents/PhD Stuff/Supervisor Meetings/paraphrase examples/{specific_problem}_v2.xlsx"

with pd.ExcelWriter(save_loc, engine="openpyxl") as xls:
    clean_for_excel(specific_problem_metadata).to_excel(xls, sheet_name="metadata", index=False)
    clean_for_excel(score_df_no_context).to_excel(xls, sheet_name="no context", index=False)
    clean_for_excel(known_scored).to_excel(xls, sheet_name="known", index=False)
    clean_for_excel(unknown_scored).to_excel(xls, sheet_name="unknown", index=False)
# Out:
# <positron-console-cell-105>:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# <positron-console-cell-105>:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# <positron-console-cell-105>:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# <positron-console-cell-105>:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
