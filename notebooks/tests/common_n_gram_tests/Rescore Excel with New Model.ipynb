# %% [markdown]
# # Rescore Excel with new model
#
# This code is used to rescore a pre-completed Excel file using a new model. This is needed due to me being an idiot and not creating a full pipeline and instead paraphrasing and scoring in a single step.
#
# The script to run this through CSF etc. is **scripts/run_scoring_with_new_model.py**

# %%
import sys

from pathlib import Path
from from_root import from_root

sys.path.insert(0, str(from_root("src")))

from read_and_write_docs import read_excel_sheets
from model_loading import load_model
from n_gram_functions import (
    get_scored_df,
    get_scored_df_no_context
)
from excel_functions import create_excel_template

# %%
data_loc = '/Volumes/BCross/paraphrase examples slurm/Wiki-test/hodja_nasreddin_text_1 vs hodja_nasreddin_text_3.xlsx'
save_dir = '/Volumes/BCross/paraphrase examples slurm/Wiki-test/gemma'

data_path = Path(data_loc)
if not data_path.is_file():
    raise FileNotFoundError(f"Input file not found: {data_path}")

# Build write_path FIRST using save_dir + input filename (stem) + ".xlsx"
save_dir_path = Path(save_dir)
write_path = save_dir_path / f"{data_path.stem}.xlsx"

# %%
model_loc = '/Volumes/BCross/models/gemma-3-270m'

tokenizer, model = load_model(model_loc)

data = read_excel_sheets(data_loc, ['docs', 'no context', 'metadata'])

# Get the full texts from docs
docs = data['docs']
texts = docs.tail(1).copy().reset_index()

# Get the texts, will be the last row in docs
known_text = texts.loc[0, 'known']
unknown_text = texts.loc[0, 'unknown']

# Pull only the needed columns from metadata
metadata = data['metadata']
metadata_subset = metadata.loc[:, : 'target']

no_context = data['no context']

# Get the n-grams in a way necessary to compute scores
n_gram_dict = {}

for phrase_num, df in no_context.groupby("phrase_num"):
    # Get the reference phrase (there should be only one)
    ref_series = df.loc[df["phrase_type"] == "reference", "phrase"]
    reference_phrase = ref_series.iloc[0] if not ref_series.empty else None

    # Get all paraphrases as a list
    paraphrases = df.loc[df["phrase_type"] == "paraphrase", "phrase"].tolist()

    n_gram_dict[phrase_num] = {
        "phrase": reference_phrase,
        "paraphrases": paraphrases
    }

# Score the n-grams vs the text
print("Processing known text")
known_scored = get_scored_df(n_gram_dict, known_text, tokenizer, model)

print("Processing unknown text")
unknown_scored = get_scored_df(n_gram_dict, unknown_text, tokenizer, model)

print("Processing no context text")
no_context_scored = get_scored_df_no_context(n_gram_dict, tokenizer, model)

create_excel_template(
    known=known_scored,
    unknown=unknown_scored,
    no_context=no_context_scored,
    metadata=metadata_subset,
    docs=docs,
    path=write_path,
    known_sheet = "known",
    unknown_sheet = "unknown",
    nc_sheet = "no context",
    metadata_sheet = "metadata",
    docs_sheet = "docs",
    llr_sheet = "LLR",
    use_xlookup = False
)
# Out:
# Processing Phrase - phrase_01
# Processing Phrase - phrase_02
# Processing Phrase - phrase_03
# Processing Phrase - phrase_04
# Processing Phrase - phrase_05
# Processing Phrase - phrase_06
# Processing Phrase - phrase_07
# Processing Phrase - phrase_08
# Processing Phrase - phrase_09
# Processing Phrase - phrase_10
# Processing Phrase - phrase_11
# Processing Phrase - phrase_12
# Processing Phrase - phrase_01
# Processing Phrase - phrase_02
# Processing Phrase - phrase_03
# Processing Phrase - phrase_04
# Processing Phrase - phrase_05
# Processing Phrase - phrase_06
# Processing Phrase - phrase_07
# Processing Phrase - phrase_08
# Processing Phrase - phrase_09
# Processing Phrase - phrase_10
# Processing Phrase - phrase_11
# Processing Phrase - phrase_12
# Processing Phrase - phrase_01
# → [1/51] Processing reference…
# → [2/51] Processing paraphrase…
# → [3/51] Processing paraphrase…
# → [4/51] Processing paraphrase…
# → [5/51] Processing paraphrase…
# → [6/51] Processing paraphrase…
# → [7/51] Processing paraphrase…
# → [8/51] Processing paraphrase…
# → [9/51] Processing paraphrase…
# → [10/51] Processing paraphrase…
# → [11/51] Processing paraphrase…
# → [12/51] Processing paraphrase…
# → [13/51] Processing paraphrase…
# → [14/51] Processing paraphrase…
# → [15/51] Processing paraphrase…
# → [16/51] Processing paraphrase…
# → [17/51] Processing paraphrase…
# → [18/51] Processing paraphrase…
# → [19/51] Processing paraphrase…
# → [20/51] Processing paraphrase…
# → [21/51] Processing paraphrase…
# → [22/51] Processing paraphrase…
# → [23/51] Processing paraphrase…
# → [24/51] Processing paraphrase…
# → [25/51] Processing paraphrase…
# → [26/51] Processing paraphrase…
# → [27/51] Processing paraphrase…
# → [28/51] Processing paraphrase…
# → [29/51] Processing paraphrase…
# → [30/51] Processing paraphrase…
# → [31/51] Processing paraphrase…
# → [32/51] Processing paraphrase…
# → [33/51] Processing paraphrase…
# → [34/51] Processing paraphrase…
# → [35/51] Processing paraphrase…
# → [36/51] Processing paraphrase…
# → [37/51] Processing paraphrase…
# → [38/51] Processing paraphrase…
# → [39/51] Processing paraphrase…
# → [40/51] Processing paraphrase…
# → [41/51] Processing paraphrase…
# → [42/51] Processing paraphrase…
# → [43/51] Processing paraphrase…
# → [44/51] Processing paraphrase…
# → [45/51] Processing paraphrase…
# → [46/51] Processing paraphrase…
# → [47/51] Processing paraphrase…
# → [48/51] Processing paraphrase…
# → [49/51] Processing paraphrase…
# → [50/51] Processing paraphrase…
# → [51/51] Processing paraphrase…
# Processing Phrase - phrase_02
# → [1/24] Processing reference…
# → [2/24] Processing paraphrase…
# → [3/24] Processing paraphrase…
# → [4/24] Processing paraphrase…
# → [5/24] Processing paraphrase…
# → [6/24] Processing paraphrase…
# → [7/24] Processing paraphrase…
# → [8/24] Processing paraphrase…
# → [9/24] Processing paraphrase…
# → [10/24] Processing paraphrase…
# → [11/24] Processing paraphrase…
# → [12/24] Processing paraphrase…
# → [13/24] Processing paraphrase…
# → [14/24] Processing paraphrase…
# → [15/24] Processing paraphrase…
# → [16/24] Processing paraphrase…
# → [17/24] Processing paraphrase…
# → [18/24] Processing paraphrase…
# → [19/24] Processing paraphrase…
# → [20/24] Processing paraphrase…
# → [21/24] Processing paraphrase…
# → [22/24] Processing paraphrase…
# → [23/24] Processing paraphrase…
# → [24/24] Processing paraphrase…
# Processing Phrase - phrase_03
# → [1/29] Processing reference…
# → [2/29] Processing paraphrase…
# → [3/29] Processing paraphrase…
# → [4/29] Processing paraphrase…
# → [5/29] Processing paraphrase…
# → [6/29] Processing paraphrase…
# → [7/29] Processing paraphrase…
# → [8/29] Processing paraphrase…
# → [9/29] Processing paraphrase…
# → [10/29] Processing paraphrase…
# → [11/29] Processing paraphrase…
# → [12/29] Processing paraphrase…
# → [13/29] Processing paraphrase…
# → [14/29] Processing paraphrase…
# → [15/29] Processing paraphrase…
# → [16/29] Processing paraphrase…
# → [17/29] Processing paraphrase…
# → [18/29] Processing paraphrase…
# → [19/29] Processing paraphrase…
# → [20/29] Processing paraphrase…
# → [21/29] Processing paraphrase…
# → [22/29] Processing paraphrase…
# → [23/29] Processing paraphrase…
# → [24/29] Processing paraphrase…
# → [25/29] Processing paraphrase…
# → [26/29] Processing paraphrase…
# → [27/29] Processing paraphrase…
# → [28/29] Processing paraphrase…
# → [29/29] Processing paraphrase…
# Processing Phrase - phrase_04
# → [1/50] Processing reference…
# → [2/50] Processing paraphrase…
# → [3/50] Processing paraphrase…
# → [4/50] Processing paraphrase…
# → [5/50] Processing paraphrase…
# → [6/50] Processing paraphrase…
# → [7/50] Processing paraphrase…
# → [8/50] Processing paraphrase…
# → [9/50] Processing paraphrase…
# → [10/50] Processing paraphrase…
# → [11/50] Processing paraphrase…
# → [12/50] Processing paraphrase…
# → [13/50] Processing paraphrase…
# → [14/50] Processing paraphrase…
# → [15/50] Processing paraphrase…
# → [16/50] Processing paraphrase…
# → [17/50] Processing paraphrase…
# → [18/50] Processing paraphrase…
# → [19/50] Processing paraphrase…
# → [20/50] Processing paraphrase…
# → [21/50] Processing paraphrase…
# → [22/50] Processing paraphrase…
# → [23/50] Processing paraphrase…
# → [24/50] Processing paraphrase…
# → [25/50] Processing paraphrase…
# → [26/50] Processing paraphrase…
# → [27/50] Processing paraphrase…
# → [28/50] Processing paraphrase…
# → [29/50] Processing paraphrase…
# → [30/50] Processing paraphrase…
# → [31/50] Processing paraphrase…
# → [32/50] Processing paraphrase…
# → [33/50] Processing paraphrase…
# → [34/50] Processing paraphrase…
# → [35/50] Processing paraphrase…
# → [36/50] Processing paraphrase…
# → [37/50] Processing paraphrase…
# → [38/50] Processing paraphrase…
# → [39/50] Processing paraphrase…
# → [40/50] Processing paraphrase…
# → [41/50] Processing paraphrase…
# → [42/50] Processing paraphrase…
# → [43/50] Processing paraphrase…
# → [44/50] Processing paraphrase…
# → [45/50] Processing paraphrase…
# → [46/50] Processing paraphrase…
# → [47/50] Processing paraphrase…
# → [48/50] Processing paraphrase…
# → [49/50] Processing paraphrase…
# → [50/50] Processing paraphrase…
# Processing Phrase - phrase_05
# → [1/19] Processing reference…
# → [2/19] Processing paraphrase…
# → [3/19] Processing paraphrase…
# → [4/19] Processing paraphrase…
# → [5/19] Processing paraphrase…
# → [6/19] Processing paraphrase…
# → [7/19] Processing paraphrase…
# → [8/19] Processing paraphrase…
# → [9/19] Processing paraphrase…
# → [10/19] Processing paraphrase…
# → [11/19] Processing paraphrase…
# → [12/19] Processing paraphrase…
# → [13/19] Processing paraphrase…
# → [14/19] Processing paraphrase…
# → [15/19] Processing paraphrase…
# → [16/19] Processing paraphrase…
# → [17/19] Processing paraphrase…
# → [18/19] Processing paraphrase…
# → [19/19] Processing paraphrase…
# Processing Phrase - phrase_06
# → [1/59] Processing reference…
# → [2/59] Processing paraphrase…
# → [3/59] Processing paraphrase…
# → [4/59] Processing paraphrase…
# → [5/59] Processing paraphrase…
# → [6/59] Processing paraphrase…
# → [7/59] Processing paraphrase…
# → [8/59] Processing paraphrase…
# → [9/59] Processing paraphrase…
# → [10/59] Processing paraphrase…
# → [11/59] Processing paraphrase…
# → [12/59] Processing paraphrase…
# → [13/59] Processing paraphrase…
# → [14/59] Processing paraphrase…
# → [15/59] Processing paraphrase…
# → [16/59] Processing paraphrase…
# → [17/59] Processing paraphrase…
# → [18/59] Processing paraphrase…
# → [19/59] Processing paraphrase…
# → [20/59] Processing paraphrase…
# → [21/59] Processing paraphrase…
# → [22/59] Processing paraphrase…
# → [23/59] Processing paraphrase…
# → [24/59] Processing paraphrase…
# → [25/59] Processing paraphrase…
# → [26/59] Processing paraphrase…
# → [27/59] Processing paraphrase…
# → [28/59] Processing paraphrase…
# → [29/59] Processing paraphrase…
# → [30/59] Processing paraphrase…
# → [31/59] Processing paraphrase…
# → [32/59] Processing paraphrase…
# → [33/59] Processing paraphrase…
# → [34/59] Processing paraphrase…
# → [35/59] Processing paraphrase…
# → [36/59] Processing paraphrase…
# → [37/59] Processing paraphrase…
# → [38/59] Processing paraphrase…
# → [39/59] Processing paraphrase…
# → [40/59] Processing paraphrase…
# → [41/59] Processing paraphrase…
# → [42/59] Processing paraphrase…
# → [43/59] Processing paraphrase…
# → [44/59] Processing paraphrase…
# → [45/59] Processing paraphrase…
# → [46/59] Processing paraphrase…
# → [47/59] Processing paraphrase…
# → [48/59] Processing paraphrase…
# → [49/59] Processing paraphrase…
# → [50/59] Processing paraphrase…
# → [51/59] Processing paraphrase…
# → [52/59] Processing paraphrase…
# → [53/59] Processing paraphrase…
# → [54/59] Processing paraphrase…
# → [55/59] Processing paraphrase…
# → [56/59] Processing paraphrase…
# → [57/59] Processing paraphrase…
# → [58/59] Processing paraphrase…
# → [59/59] Processing paraphrase…
# Processing Phrase - phrase_07
# → [1/3] Processing reference…
# → [2/3] Processing paraphrase…
# → [3/3] Processing paraphrase…
# Processing Phrase - phrase_08
# → [1/58] Processing reference…
# → [2/58] Processing paraphrase…
# → [3/58] Processing paraphrase…
# → [4/58] Processing paraphrase…
# → [5/58] Processing paraphrase…
# → [6/58] Processing paraphrase…
# → [7/58] Processing paraphrase…
# → [8/58] Processing paraphrase…
# → [9/58] Processing paraphrase…
# → [10/58] Processing paraphrase…
# → [11/58] Processing paraphrase…
# → [12/58] Processing paraphrase…
# → [13/58] Processing paraphrase…
# → [14/58] Processing paraphrase…
# → [15/58] Processing paraphrase…
# → [16/58] Processing paraphrase…
# → [17/58] Processing paraphrase…
# → [18/58] Processing paraphrase…
# → [19/58] Processing paraphrase…
# → [20/58] Processing paraphrase…
# → [21/58] Processing paraphrase…
# → [22/58] Processing paraphrase…
# → [23/58] Processing paraphrase…
# → [24/58] Processing paraphrase…
# → [25/58] Processing paraphrase…
# → [26/58] Processing paraphrase…
# → [27/58] Processing paraphrase…
# → [28/58] Processing paraphrase…
# → [29/58] Processing paraphrase…
# → [30/58] Processing paraphrase…
# → [31/58] Processing paraphrase…
# → [32/58] Processing paraphrase…
# → [33/58] Processing paraphrase…
# → [34/58] Processing paraphrase…
# → [35/58] Processing paraphrase…
# → [36/58] Processing paraphrase…
# → [37/58] Processing paraphrase…
# → [38/58] Processing paraphrase…
# → [39/58] Processing paraphrase…
# → [40/58] Processing paraphrase…
# → [41/58] Processing paraphrase…
# → [42/58] Processing paraphrase…
# → [43/58] Processing paraphrase…
# → [44/58] Processing paraphrase…
# → [45/58] Processing paraphrase…
# → [46/58] Processing paraphrase…
# → [47/58] Processing paraphrase…
# → [48/58] Processing paraphrase…
# → [49/58] Processing paraphrase…
# → [50/58] Processing paraphrase…
# → [51/58] Processing paraphrase…
# → [52/58] Processing paraphrase…
# → [53/58] Processing paraphrase…
# → [54/58] Processing paraphrase…
# → [55/58] Processing paraphrase…
# → [56/58] Processing paraphrase…
# → [57/58] Processing paraphrase…
# → [58/58] Processing paraphrase…
# Processing Phrase - phrase_09
# → [1/33] Processing reference…
# → [2/33] Processing paraphrase…
# → [3/33] Processing paraphrase…
# → [4/33] Processing paraphrase…
# → [5/33] Processing paraphrase…
# → [6/33] Processing paraphrase…
# → [7/33] Processing paraphrase…
# → [8/33] Processing paraphrase…
# → [9/33] Processing paraphrase…
# → [10/33] Processing paraphrase…
# → [11/33] Processing paraphrase…
# → [12/33] Processing paraphrase…
# → [13/33] Processing paraphrase…
# → [14/33] Processing paraphrase…
# → [15/33] Processing paraphrase…
# → [16/33] Processing paraphrase…
# → [17/33] Processing paraphrase…
# → [18/33] Processing paraphrase…
# → [19/33] Processing paraphrase…
# → [20/33] Processing paraphrase…
# → [21/33] Processing paraphrase…
# → [22/33] Processing paraphrase…
# → [23/33] Processing paraphrase…
# → [24/33] Processing paraphrase…
# → [25/33] Processing paraphrase…
# → [26/33] Processing paraphrase…
# → [27/33] Processing paraphrase…
# → [28/33] Processing paraphrase…
# → [29/33] Processing paraphrase…
# → [30/33] Processing paraphrase…
# → [31/33] Processing paraphrase…
# → [32/33] Processing paraphrase…
# → [33/33] Processing paraphrase…
# Processing Phrase - phrase_10
# → [1/15] Processing reference…
# → [2/15] Processing paraphrase…
# → [3/15] Processing paraphrase…
# → [4/15] Processing paraphrase…
# → [5/15] Processing paraphrase…
# → [6/15] Processing paraphrase…
# → [7/15] Processing paraphrase…
# → [8/15] Processing paraphrase…
# → [9/15] Processing paraphrase…
# → [10/15] Processing paraphrase…
# → [11/15] Processing paraphrase…
# → [12/15] Processing paraphrase…
# → [13/15] Processing paraphrase…
# → [14/15] Processing paraphrase…
# → [15/15] Processing paraphrase…
# Processing Phrase - phrase_11
# → [1/58] Processing reference…
# → [2/58] Processing paraphrase…
# → [3/58] Processing paraphrase…
# → [4/58] Processing paraphrase…
# → [5/58] Processing paraphrase…
# → [6/58] Processing paraphrase…
# → [7/58] Processing paraphrase…
# → [8/58] Processing paraphrase…
# → [9/58] Processing paraphrase…
# → [10/58] Processing paraphrase…
# → [11/58] Processing paraphrase…
# → [12/58] Processing paraphrase…
# → [13/58] Processing paraphrase…
# → [14/58] Processing paraphrase…
# → [15/58] Processing paraphrase…
# → [16/58] Processing paraphrase…
# → [17/58] Processing paraphrase…
# → [18/58] Processing paraphrase…
# → [19/58] Processing paraphrase…
# → [20/58] Processing paraphrase…
# → [21/58] Processing paraphrase…
# → [22/58] Processing paraphrase…
# → [23/58] Processing paraphrase…
# → [24/58] Processing paraphrase…
# → [25/58] Processing paraphrase…
# → [26/58] Processing paraphrase…
# → [27/58] Processing paraphrase…
# → [28/58] Processing paraphrase…
# → [29/58] Processing paraphrase…
# → [30/58] Processing paraphrase…
# → [31/58] Processing paraphrase…
# → [32/58] Processing paraphrase…
# → [33/58] Processing paraphrase…
# → [34/58] Processing paraphrase…
# → [35/58] Processing paraphrase…
# → [36/58] Processing paraphrase…
# → [37/58] Processing paraphrase…
# → [38/58] Processing paraphrase…
# → [39/58] Processing paraphrase…
# → [40/58] Processing paraphrase…
# → [41/58] Processing paraphrase…
# → [42/58] Processing paraphrase…
# → [43/58] Processing paraphrase…
# → [44/58] Processing paraphrase…
# → [45/58] Processing paraphrase…
# → [46/58] Processing paraphrase…
# → [47/58] Processing paraphrase…
# → [48/58] Processing paraphrase…
# → [49/58] Processing paraphrase…
# → [50/58] Processing paraphrase…
# → [51/58] Processing paraphrase…
# → [52/58] Processing paraphrase…
# → [53/58] Processing paraphrase…
# → [54/58] Processing paraphrase…
# → [55/58] Processing paraphrase…
# → [56/58] Processing paraphrase…
# → [57/58] Processing paraphrase…
# → [58/58] Processing paraphrase…
# Processing Phrase - phrase_12
# → [1/22] Processing reference…
# → [2/22] Processing paraphrase…
# → [3/22] Processing paraphrase…
# → [4/22] Processing paraphrase…
# → [5/22] Processing paraphrase…
# → [6/22] Processing paraphrase…
# → [7/22] Processing paraphrase…
# → [8/22] Processing paraphrase…
# → [9/22] Processing paraphrase…
# → [10/22] Processing paraphrase…
# → [11/22] Processing paraphrase…
# → [12/22] Processing paraphrase…
# → [13/22] Processing paraphrase…
# → [14/22] Processing paraphrase…
# → [15/22] Processing paraphrase…
# → [16/22] Processing paraphrase…
# → [17/22] Processing paraphrase…
# → [18/22] Processing paraphrase…
# → [19/22] Processing paraphrase…
# → [20/22] Processing paraphrase…
# → [21/22] Processing paraphrase…
# → [22/22] Processing paraphrase…
# PosixPath('/Volumes/BCross/paraphrase examples slurm/Wiki-test/gemma/hodja_nasreddin_text_1 vs hodja_nasreddin_text_3.xlsx')
