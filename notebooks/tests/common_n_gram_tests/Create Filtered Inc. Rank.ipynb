# %%
import ast
import os
import glob

from pathlib import Path

import numpy as np
import pandas as pd

# %%
def create_results_doc_pipeline(doc_loc, write_excel=True, save_dir=None, phrase_loc=None):
    """Pipeline to manually get the results from a document"""
    
    doc_name = os.path.basename(doc_loc)
    
    print(f"Processing Document: {doc_name}")
    # Read the sheets as dataframes
    docs = pd.read_excel(doc_loc, sheet_name="docs")
    known = pd.read_excel(doc_loc, sheet_name="known")
    unknown = pd.read_excel(doc_loc, sheet_name="unknown")
    no_context = pd.read_excel(doc_loc, sheet_name="no context")
    metadata = pd.read_excel(doc_loc, sheet_name="metadata")
    
    # Get phrases to keep
    if phrase_loc:
        phrase_list = pd.read_excel(phrase_loc)
        phrases_to_keep = phrase_list[phrase_list['keep_phrase'] == 1].copy()

        # Convert the stringified tuples into actual tuples, then into lists
        phrases_to_keep['tokens'] = phrases_to_keep['tokens'].apply(lambda x: list(ast.literal_eval(x)) if isinstance(x, str) else list(x))
        phrases_to_keep = phrases_to_keep[['phrase']]
        
        reference_phrases = no_context[no_context['phrase_type'] == 'reference'].copy()

        # Perform the merge using the tuple-based key
        merged_phrases = pd.merge(reference_phrases, phrases_to_keep, on='phrase', how='inner')
        merged_phrases = merged_phrases[['phrase_num']]

        no_context = pd.merge(no_context, merged_phrases, on='phrase_num', how='inner')
        known = pd.merge(known, merged_phrases, on='phrase_num', how='inner')
        unknown= pd.merge(unknown, merged_phrases, on='phrase_num', how='inner')
        
    # Get the base LLR table
    cols = ['phrase_num', 'phrase_occurence', 'original_phrase', 'tokens']
    key_cols = ['phrase_num', 'phrase_occurence', 'original_phrase']
    llr_base = (
        pd.concat([known[cols], unknown[cols]], ignore_index=True)
        .drop_duplicates(subset=key_cols, keep='first')
        .sort_values(cols, ascending=[True, True, True, True])  # explicit
        .reset_index(drop=True)
    )
    llr_base['num_tokens'] = llr_base['tokens'].map(len)
    
    # Now get the phrase statistics
    # 1) No context phrase stats
    no_context_phrase_stats = (
        no_context
        .assign(ref_log_prob = no_context['sum_log_probs']
                .where(no_context['phrase_type'].eq('reference')))
        .assign(ref_raw_prob=no_context['raw_prob']
            .where(no_context['phrase_type'].eq('reference')))
        .groupby('phrase_num', dropna=False)
        .agg(
            no_context_log_prob=('ref_log_prob', 'sum'),
            num_phrases=('phrase_num', 'size'),
            sum_raw_prob=('raw_prob', 'sum'),
            reference_prob=('ref_raw_prob', 'max')
        )
        .assign(
            phrases_kept=lambda d: d['num_phrases'],
            pmf_no_context=lambda d: d['reference_prob'].div(d['sum_raw_prob']),
            llr_no_context=lambda d: np.where(d['pmf_no_context'] > 0, -np.log10(d['pmf_no_context']), 0.0)
        )
        .drop(columns=['sum_raw_prob', 'reference_prob'])
    )

    # 2) Known phrase stats
    known_phrase_stats = (
        known
        .assign(ref_log_prob = known['sum_log_probs_phrase']
                .where(known['phrase_type'].eq('reference')))
        .assign(ref_raw_prob=known['raw_prob']
                .where(known['phrase_type'].eq('reference')))
        .groupby(['phrase_num', 'phrase_occurence'], dropna=False)
        .agg(
            known_log_prob=('ref_log_prob', 'sum'),
            sum_raw_prob=('raw_prob', 'sum'),
            reference_prob=('ref_raw_prob', 'max')
        )
        .assign(
            pmf_known=lambda d: d['reference_prob'].div(d['sum_raw_prob']),
            llr_known=lambda d: np.where(d['pmf_known'] > 0, -np.log10(d['pmf_known']), 0.0)
        )
        .drop(columns=['sum_raw_prob', 'reference_prob'])
    )

    # 3) Unknown phrase stats
    unknown_phrase_stats = (
        unknown
        .assign(ref_log_prob = unknown['sum_log_probs_phrase']
                .where(unknown['phrase_type'].eq('reference')))
        .assign(ref_raw_prob=unknown['raw_prob']
                .where(unknown['phrase_type'].eq('reference')))
        .groupby(['phrase_num', 'phrase_occurence'], dropna=False)
        .agg(
            unknown_log_prob=('ref_log_prob', 'sum'),
            sum_raw_prob=('raw_prob', 'sum'),
            reference_prob=('ref_raw_prob', 'max')
        )
        .assign(
            pmf_unknown=lambda d: d['reference_prob'].div(d['sum_raw_prob']),
            llr_unknown=lambda d: np.where(d['pmf_unknown'] > 0, -np.log10(d['pmf_unknown']), 0.0)
        )
        .drop(columns=['sum_raw_prob', 'reference_prob'])
    )
    
    # ---- START OF RANK TEST ---- #
    # Rank all phrases including the reference phrase
    unknown['rank_including_ref'] = (
        unknown
        .groupby(['phrase_num', 'phrase_occurence'])['sum_log_probs_phrase']
        .rank(ascending=False, method='first')   # or method='dense' if you prefer
    )

    # reference_log_probs: from the 'reference' row
    ref = (
        unknown[unknown['phrase_type'] == 'reference']
        .groupby(['phrase_num', 'phrase_occurence'])['sum_log_probs_phrase']
        .first()                 # or .iloc[0] via .agg('first')
        .rename('reference_log_probs')
    )

    # max_log_probs: from the top-ranked row (rank_including_ref == 1)
    top = (
        unknown[unknown['rank_including_ref'] == 1]
        .groupby(['phrase_num', 'phrase_occurence'])['sum_log_probs_phrase']
        .first()
        .rename('max_log_probs')
    )

    # combine into one dataframe
    agg_df = (
        pd.concat([ref, top], axis=1)
        .reset_index()
    )

    # difference
    agg_df['unknown_ref_vs_top_rank'] = agg_df['reference_log_probs'] - agg_df['max_log_probs']

    agg_df = agg_df.drop(columns=['reference_log_probs', 'max_log_probs']).reset_index()
    
    # ---- END OF RANK TEST ---- #

    # ---- START OF REF vs BEST-OF-REST (rank 0 vs rank 1) ---- #

    keys = ['phrase_num', 'phrase_occurence']
    
    ref = (
        unknown[unknown['rank'] == 0]
        .groupby(keys, dropna=False)['sum_log_probs_phrase']
        .first()
        .rename('ref_logp')
    )

    best_rest = (
        unknown[unknown['rank'] == 1]
        .groupby(keys, dropna=False)['sum_log_probs_phrase']
        .first()
        .rename('best_rest_logp')
    )

    agg_df_ref_vs_best = (
        pd.concat([ref, best_rest], axis=1)
        .reset_index()
    )

    # LLR(ref vs best alternative)
    agg_df_ref_vs_best['unknown_ref_vs_best_rest'] = agg_df_ref_vs_best['ref_logp'] - agg_df_ref_vs_best['best_rest_logp']

    agg_df_ref_vs_best = agg_df_ref_vs_best.drop(columns=['ref_logp', 'best_rest_logp'])

    # ---- END OF REF vs BEST-OF-REST ---- #
    
    # Create final LLR table
    LLR = (
        llr_base
        .assign(
            phrase_num=llr_base['phrase_num'].astype('string'),
            phrase_occurence=pd.to_numeric(llr_base['phrase_occurence'], errors='coerce').astype('Int64')
        )
        .merge(no_context_phrase_stats, on='phrase_num', how='left')
        .merge(known_phrase_stats, on=['phrase_num','phrase_occurence'], how='left')
        .merge(unknown_phrase_stats, on=['phrase_num','phrase_occurence'], how='left')
        .merge(agg_df, on=['phrase_num','phrase_occurence'], how='left')
        .merge(agg_df_ref_vs_best, on=['phrase_num','phrase_occurence'], how='left')
    )
    LLR['known_vs_no_context_log_prob'] = LLR['known_log_prob'] - LLR['no_context_log_prob'] 
    LLR['unknown_vs_no_context_log_prob'] = LLR['unknown_log_prob'] - LLR['no_context_log_prob'] 

    LLR = LLR[['phrase_num', 'phrase_occurence', 'original_phrase', 'tokens', 'num_tokens',
               'num_phrases', 'phrases_kept', 'no_context_log_prob',
               'known_log_prob', 'unknown_log_prob', 'known_vs_no_context_log_prob', 'unknown_vs_no_context_log_prob',
               'pmf_no_context', 'pmf_known', 'pmf_unknown', 'llr_no_context', 'llr_known',
               'llr_unknown', 'unknown_ref_vs_top_rank', 'unknown_ref_vs_best_rest']]
    
    # Summarise the LLR table for the metadata
    LLR_summary = pd.DataFrame([{
        'num_phrases': LLR['phrase_num'].nunique(),
        'phrases_kept': LLR.loc[LLR['phrases_kept'] > 0, 'phrase_num'].nunique(),
        'known_log_prob': LLR['known_log_prob'].sum(skipna=True),
        'unknown_log_prob': LLR['unknown_log_prob'].sum(skipna=True),
        'llr_no_context': LLR['llr_no_context'].sum(skipna=True),
        'llr_known': LLR['llr_known'].sum(skipna=True),
        'llr_unknown': LLR['llr_unknown'].sum(skipna=True),
        'llr_unknown_vs_top_rank': LLR['unknown_ref_vs_top_rank'].sum(skipna=True),
        'unknown_ref_vs_best_rest': LLR['unknown_ref_vs_best_rest'].sum(skipna=True)
    }])

    LLR_summary = LLR_summary.assign(
        normalised_llr_no_context=lambda d: d['llr_no_context'] / d['phrases_kept'],
        normalised_llr_known=lambda d: d['llr_known'] / d['phrases_kept'],
        normalised_llr_unknown=lambda d: d['llr_unknown'] / d['phrases_kept']
    )
    
    # Create final metadata table
    # 1. Drop any overlapping columns in metadata
    overlapping_cols = LLR_summary.columns.intersection(metadata.columns)
    metadata_final = metadata.drop(columns=overlapping_cols, errors='ignore')

    # 2. Concatenate new values
    metadata_final = pd.concat([metadata_final, LLR_summary], axis=1)
    
    if write_excel:
        
        print("Writing file")
        path = Path(save_dir + '/' + doc_name)
        
        # Choose writer mode safely
        writer_mode = "a" if path.exists() else "w"
        writer_kwargs = {"engine": "openpyxl", "mode": writer_mode}
        if writer_mode == "a":
            writer_kwargs["if_sheet_exists"] = "replace"  # only valid in append mode
        

        with pd.ExcelWriter(path, **writer_kwargs) as writer:
            # Write sheets
            docs.to_excel(writer, index=False, sheet_name="docs")
            known.to_excel(writer, index=False, sheet_name="known")
            unknown.to_excel(writer, index=False, sheet_name="unknown")
            no_context.to_excel(writer, index=False, sheet_name="no context")
            LLR.to_excel(writer, index=False, sheet_name="LLR")
            metadata_final.to_excel(writer, index=False, sheet_name="metadata")
            
            # wb = writer.book
            # wb._sheets = ["docs", "metadata", "no context", "known", "unknown", "LLR"]
    
    return metadata_final

# %%
def process_directory(
    read_dir,
    save_dir,
    result_save_loc=None,   # optional now
    phrase_loc="/Volumes/BCross/paraphrase examples slurm/wiki-phrase-list-reviewed.xlsx"
):

    print(f"Reading from: {read_dir}")
    print(f"Saving processed files to: {save_dir}")
    
    if result_save_loc:
        print(f"Final combined output: {result_save_loc}\n")
    else:
        print("No result_save_loc provided → combined file will NOT be saved.\n")

    os.makedirs(save_dir, exist_ok=True)

    # If result_save_loc exists, do not overwrite
    if result_save_loc and os.path.exists(result_save_loc):
        print(f"Output already exists: {result_save_loc}. Exiting.")
        return

    # Read all Excel files
    xlsx_files = glob.glob(os.path.join(read_dir, "*.xlsx"))
    print(f"Found {len(xlsx_files)} files\n")

    all_metadata = []

    for i, file_path in enumerate(xlsx_files, start=1):
        
        base_name = os.path.basename(file_path)
        
        # If NO combined output is being written, skip files whose processed output already exists
        if not result_save_loc:
            processed_out_path = os.path.join(save_dir, base_name)  # adjust if your pipeline uses a different naming scheme
            if os.path.exists(processed_out_path):
                print(f"Skipping file {i}/{len(xlsx_files)} (already processed): {base_name}")
                continue
        print(f"Processing file {i}/{len(xlsx_files)}: {base_name}")

        try:
            metadata = create_results_doc_pipeline(
                file_path,
                write_excel=True,
                save_dir=save_dir,
                phrase_loc=phrase_loc
            )
            all_metadata.append(metadata)

        except Exception as e:
            print(f"❌ Failed to process {file_path}\nError: {e}\n")
            continue

    # Combine metadata
    if all_metadata:
        full_metadata = pd.concat(all_metadata, ignore_index=True)
    else:
        full_metadata = pd.DataFrame()

    # Sort if index exists
    if "index" in full_metadata.columns:
        full_metadata = full_metadata.sort_values(by="index").reset_index(drop=True)

    print("\nAll files complete ✓")
    
    # Save if a path was provided
    if result_save_loc:
        full_metadata.to_excel(result_save_loc, index=False)
        print(f"\nCombined results saved to: {result_save_loc}")
    else:
        print("\nSkipping save because no result_save_loc was provided.")

        return full_metadata  # return result in all cases

# %%
# base_loc = '/Volumes/BCross/paraphrase examples slurm'
# data_loc = f"{base_loc}/Wiki-Test"

# # For Qwen
# # read_dir = f'{data_loc}/raw'
# # For everything else
# read_dir = f'{data_loc}/ModernBERT-large/gpt2 results/raw'
# save_dir = f'{data_loc}/ModernBERT-large/gpt2 results/filtered_inc_rank_v3'

# result_save_loc = f"{data_loc}/ModernBERT-base/results.xlsx"
# phrase_loc = f"{base_loc}/wiki-phrase-list-reviewed.xlsx"

# process_directory(
#     read_dir=read_dir,
#     save_dir=save_dir,
#     # result_save_loc=result_save_loc,
#     phrase_loc=phrase_loc)

# %%
base_data_dir = "/Volumes/BCross/av_datasets_experiments/ngram_masking"

data_types = ["test", "training"]
corpuses = ["ACL", "Enron", "Perverted Justice", "StackExchange",
            "The Telegraph", "TripAdvisor", "Wiki"]
paraphrasing_models = ["ModernBERT-base", "ModernBERT-large"]
scoring_models = ["gpt2"]

for dt in data_types:
    print(f"Working on {dt} data")
    for cp in corpuses:
        print(f"Working on the {cp} corpus")
        for pm in paraphrasing_models:
            print(f"Working on the {pm} paraphrasing model")
            for sm in scoring_models:
                print(f"Working on the {sm} scoring model")
                
                data_dir = f"{base_data_dir}/{dt}/{cp}/{pm}/{sm} results/raw"
                save_dir = f"{base_data_dir}/{dt}/{cp}/{pm}/{sm} results/raw_inc_rank"
                
                if not os.path.isdir(data_dir):
                    print(f"Skipping (missing): {data_dir}")
                    continue
                
                process_directory(
                    read_dir=data_dir,
                    save_dir=save_dir
                )
# Out:
# Working on test data
# Working on the ACL corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Reading from: /Volumes/BCross/av_datasets_experiments/ngram_masking/test/ACL/ModernBERT-base/gpt2 results/raw
# Saving processed files to: /Volumes/BCross/av_datasets_experiments/ngram_masking/test/ACL/ModernBERT-base/gpt2 results/raw_inc_rank
# No result_save_loc provided → combined file will NOT be saved.
#
# Found 5 files
#
# Skipping file 1/5 (already processed): levow_gina_anne_w12_1811_acl_2012 vs liberman_mark_w09_0102_acl_2009.xlsx
# Skipping file 2/5 (already processed): liberman_mark_w18_3801_acl_2018 vs liberman_mark_w09_0102_acl_2009.xlsx
# Skipping file 3/5 (already processed): kordoni_valia_p18_5005_acl_2018 vs kordoni_valia_e03_1044_acl_2003.xlsx
# Skipping file 4/5 (already processed): nishiguchi_sumiyo_w13_5414_acl_2013 vs nivre_joakim_w07_2220_acl_2007.xlsx
# Skipping file 5/5 (already processed): kokkinakis_dimitrios_s01_1022_acl_2001 vs kordoni_valia_e03_1044_acl_2003.xlsx
#
# All files complete ✓
#
# Skipping save because no result_save_loc was provided.
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Reading from: /Volumes/BCross/av_datasets_experiments/ngram_masking/test/ACL/ModernBERT-large/gpt2 results/raw
# Saving processed files to: /Volumes/BCross/av_datasets_experiments/ngram_masking/test/ACL/ModernBERT-large/gpt2 results/raw_inc_rank
# No result_save_loc provided → combined file will NOT be saved.
#
# Found 5 files
#
# Processing file 1/5: levow_gina_anne_w12_1811_acl_2012 vs liberman_mark_w09_0102_acl_2009.xlsx
# Processing Document: levow_gina_anne_w12_1811_acl_2012 vs liberman_mark_w09_0102_acl_2009.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/ACL/ModernBERT-large/gpt2 results/raw/levow_gina_anne_w12_1811_acl_2012 vs liberman_mark_w09_0102_acl_2009.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 2/5 (already processed): liberman_mark_w18_3801_acl_2018 vs liberman_mark_w09_0102_acl_2009.xlsx
# Skipping file 3/5 (already processed): kordoni_valia_p18_5005_acl_2018 vs kordoni_valia_e03_1044_acl_2003.xlsx
# Processing file 4/5: kokkinakis_dimitrios_s01_1022_acl_2001 vs kordoni_valia_e03_1044_acl_2003.xlsx
# Processing Document: kokkinakis_dimitrios_s01_1022_acl_2001 vs kordoni_valia_e03_1044_acl_2003.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/ACL/ModernBERT-large/gpt2 results/raw/kokkinakis_dimitrios_s01_1022_acl_2001 vs kordoni_valia_e03_1044_acl_2003.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 5/5 (already processed): nishiguchi_sumiyo_w13_5414_acl_2013 vs nivre_joakim_w07_2220_acl_2007.xlsx
#
# All files complete ✓
#
# Skipping save because no result_save_loc was provided.
# Working on the Enron corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Reading from: /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw
# Saving processed files to: /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw_inc_rank
# No result_save_loc provided → combined file will NOT be saved.
#
# Found 217 files
#
# Skipping file 1/217 (already processed): tana_jones_mail_2 vs tana_jones_mail_5.xlsx
# Skipping file 2/217 (already processed): rod_hayslett_mail_4 vs rosalee_fleming_mail_4.xlsx
# Skipping file 3/217 (already processed): susan_scott_mail_1 vs tana_jones_mail_5.xlsx
# Skipping file 4/217 (already processed): vince_kaminski_mail_2 vs w_white_mail_2.xlsx
# Skipping file 5/217 (already processed): scott_neal_mail_4 vs scott_neal_mail_2.xlsx
# Skipping file 6/217 (already processed): rosalee_fleming_mail_2 vs rosalee_fleming_mail_4.xlsx
# Skipping file 7/217 (already processed): mark_haedicke_mail_3 vs mark_haedicke_mail_2.xlsx
# Skipping file 8/217 (already processed): sally_beck_mail_2 vs sara_shackleton_mail_3.xlsx
# Skipping file 9/217 (already processed): lysa_akin_mail_1 vs lysa_akin_mail_3.xlsx
# Processing file 10/217: lynn_blair_mail_5 vs lynn_blair_mail_3.xlsx
# Processing Document: lynn_blair_mail_5 vs lynn_blair_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/lynn_blair_mail_5 vs lynn_blair_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Processing file 11/217: stanley_horton_mail_3 vs steven_kean_mail_3.xlsx
# Processing Document: stanley_horton_mail_3 vs steven_kean_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/stanley_horton_mail_3 vs steven_kean_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 12/217 (already processed): lindy_donoho_mail_1 vs lindy_donoho_mail_4.xlsx
# Skipping file 13/217 (already processed): kimberly_watson_mail_5 vs larry_campbell_mail_1.xlsx
# Skipping file 14/217 (already processed): m_forney_mail_5 vs m_love_mail_3.xlsx
# Skipping file 15/217 (already processed): liz_taylor_mail_4 vs liz_taylor_mail_2.xlsx
# Skipping file 16/217 (already processed): lysa_akin_mail_4 vs m_forney_mail_1.xlsx
# Skipping file 17/217 (already processed): mark_taylor_mail_3 vs mark_taylor_mail_2.xlsx
# Skipping file 18/217 (already processed): mark_haedicke_mail_1 vs mark_taylor_mail_2.xlsx
# Processing file 19/217: kevin_hyatt_mail_5 vs kevin_hyatt_mail_2.xlsx
# Processing Document: kevin_hyatt_mail_5 vs kevin_hyatt_mail_2.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/kevin_hyatt_mail_5 vs kevin_hyatt_mail_2.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 20/217 (already processed): louise_kitchen_mail_5 vs lynn_blair_mail_3.xlsx
# Skipping file 21/217 (already processed): sara_shackleton_mail_2 vs sara_shackleton_mail_3.xlsx
# Skipping file 22/217 (already processed): m_forney_mail_3 vs m_love_mail_3.xlsx
# Skipping file 23/217 (already processed): m_presto_mail_1 vs m_presto_mail_3.xlsx
# Skipping file 24/217 (already processed): shelley_corman_mail_2 vs sherri_reinartz_mail_3.xlsx
# Skipping file 25/217 (already processed): tana_jones_mail_4 vs tracy_geaccone_mail_3.xlsx
# Skipping file 26/217 (already processed): rick_buy_mail_2 vs rob_gay_mail_4.xlsx
# Skipping file 27/217 (already processed): lindy_donoho_mail_3 vs liz_taylor_mail_2.xlsx
# Skipping file 28/217 (already processed): michelle_lokay_mail_1 vs michelle_lokay_mail_3.xlsx
# Skipping file 29/217 (already processed): rick_buy_mail_4 vs rick_buy_mail_3.xlsx
# Skipping file 30/217 (already processed): steven_kean_mail_4 vs steven_kean_mail_3.xlsx
# Skipping file 31/217 (already processed): maureen_mcvicker_mail_5 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 32/217 (already processed): lysa_akin_mail_4 vs lysa_akin_mail_3.xlsx
# Skipping file 33/217 (already processed): mike_mcconnell_mail_4 vs paul_y_barbo_mail_4.xlsx
# Processing file 34/217: shelley_corman_mail_3 vs sherri_reinartz_mail_3.xlsx
# Processing Document: shelley_corman_mail_3 vs sherri_reinartz_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/shelley_corman_mail_3 vs sherri_reinartz_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 35/217 (already processed): richard_sanders_mail_1 vs rick_buy_mail_3.xlsx
# Skipping file 36/217 (already processed): marie_heard_mail_5 vs marie_heard_mail_3.xlsx
# Skipping file 37/217 (already processed): m_love_mail_2 vs m_presto_mail_3.xlsx
# Skipping file 38/217 (already processed): rick_buy_mail_4 vs rob_gay_mail_4.xlsx
# Processing file 39/217: lynn_blair_mail_4 vs lynn_blair_mail_3.xlsx
# Processing Document: lynn_blair_mail_4 vs lynn_blair_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/lynn_blair_mail_4 vs lynn_blair_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 40/217 (already processed): lindy_donoho_mail_5 vs liz_taylor_mail_2.xlsx
# Skipping file 41/217 (already processed): vince_kaminski_mail_4 vs vince_kaminski_mail_1.xlsx
# Processing file 42/217: lynn_blair_mail_2 vs lynn_blair_mail_3.xlsx
# Processing Document: lynn_blair_mail_2 vs lynn_blair_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/lynn_blair_mail_2 vs lynn_blair_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 43/217 (already processed): lysa_akin_mail_5 vs lysa_akin_mail_3.xlsx
# Skipping file 44/217 (already processed): rob_gay_mail_1 vs rob_gay_mail_4.xlsx
# Skipping file 45/217 (already processed): tracy_geaccone_mail_2 vs twanda_sweet_mail_4.xlsx
# Skipping file 46/217 (already processed): mark_taylor_mail_4 vs mark_taylor_mail_2.xlsx
# Skipping file 47/217 (already processed): lindy_donoho_mail_3 vs lindy_donoho_mail_4.xlsx
# Skipping file 48/217 (already processed): m_presto_mail_2 vs m_presto_mail_3.xlsx
# Skipping file 49/217 (already processed): w_white_mail_1 vs kevin_hyatt_mail_2.xlsx
# Skipping file 50/217 (already processed): tracy_geaccone_mail_5 vs twanda_sweet_mail_4.xlsx
# Skipping file 51/217 (already processed): twanda_sweet_mail_2 vs twanda_sweet_mail_4.xlsx
# Skipping file 52/217 (already processed): kimberly_watson_mail_2 vs larry_campbell_mail_1.xlsx
# Skipping file 53/217 (already processed): larry_campbell_mail_2 vs lindy_donoho_mail_4.xlsx
# Skipping file 54/217 (already processed): sara_shackleton_mail_5 vs sara_shackleton_mail_3.xlsx
# Skipping file 55/217 (already processed): mark_haedicke_mail_4 vs mark_haedicke_mail_2.xlsx
# Skipping file 56/217 (already processed): lindy_donoho_mail_5 vs lindy_donoho_mail_4.xlsx
# Skipping file 57/217 (already processed): rob_gay_mail_2 vs rod_hayslett_mail_1.xlsx
# Skipping file 58/217 (already processed): tana_jones_mail_1 vs tana_jones_mail_5.xlsx
# Skipping file 59/217 (already processed): lindy_donoho_mail_1 vs liz_taylor_mail_2.xlsx
# Skipping file 60/217 (already processed): rosalee_fleming_mail_3 vs rosalee_fleming_mail_4.xlsx
# Skipping file 61/217 (already processed): v_weldon_mail_4 vs vince_kaminski_mail_1.xlsx
# Skipping file 62/217 (already processed): scott_neal_mail_4 vs sean_crandall_mail_4.xlsx
# Skipping file 63/217 (already processed): rob_gay_mail_1 vs rod_hayslett_mail_1.xlsx
# Skipping file 64/217 (already processed): lindy_donoho_mail_2 vs lindy_donoho_mail_4.xlsx
# Skipping file 65/217 (already processed): kimberly_watson_mail_1 vs larry_campbell_mail_1.xlsx
# Skipping file 66/217 (already processed): twanda_sweet_mail_3 vs v_weldon_mail_5.xlsx
# Skipping file 67/217 (already processed): sara_shackleton_mail_1 vs scott_neal_mail_2.xlsx
# Skipping file 68/217 (already processed): mike_mcconnell_mail_1 vs paul_y_barbo_mail_4.xlsx
# Skipping file 69/217 (already processed): tana_jones_mail_2 vs tracy_geaccone_mail_3.xlsx
# Skipping file 70/217 (already processed): w_white_mail_4 vs w_white_mail_2.xlsx
# Skipping file 71/217 (already processed): rob_gay_mail_2 vs rob_gay_mail_4.xlsx
# Skipping file 72/217 (already processed): mark_haedicke_mail_4 vs mark_taylor_mail_2.xlsx
# Processing file 73/217: kevin_hyatt_mail_3 vs kevin_hyatt_mail_2.xlsx
# Processing Document: kevin_hyatt_mail_3 vs kevin_hyatt_mail_2.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/kevin_hyatt_mail_3 vs kevin_hyatt_mail_2.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 74/217 (already processed): scott_neal_mail_3 vs scott_neal_mail_2.xlsx
# Skipping file 75/217 (already processed): michelle_lokay_mail_2 vs michelle_lokay_mail_3.xlsx
# Skipping file 76/217 (already processed): v_weldon_mail_2 vs vince_kaminski_mail_1.xlsx
# Skipping file 77/217 (already processed): richard_sanders_mail_2 vs richard_sanders_mail_3.xlsx
# Skipping file 78/217 (already processed): sara_shackleton_mail_2 vs scott_neal_mail_2.xlsx
# Processing file 79/217: lynn_blair_mail_1 vs lysa_akin_mail_3.xlsx
# Processing Document: lynn_blair_mail_1 vs lysa_akin_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/lynn_blair_mail_1 vs lysa_akin_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 80/217 (already processed): v_weldon_mail_3 vs vince_kaminski_mail_1.xlsx
# Skipping file 81/217 (already processed): sean_crandall_mail_5 vs sean_crandall_mail_4.xlsx
# Skipping file 82/217 (already processed): v_weldon_mail_1 vs v_weldon_mail_5.xlsx
# Processing file 83/217: rick_buy_mail_1 vs rick_buy_mail_3.xlsx
# Processing Document: rick_buy_mail_1 vs rick_buy_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/rick_buy_mail_1 vs rick_buy_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 84/217 (already processed): matt_smith_mail_4 vs maureen_mcvicker_mail_3.xlsx
# Processing file 85/217: tracy_geaccone_mail_1 vs twanda_sweet_mail_4.xlsx
# Processing Document: tracy_geaccone_mail_1 vs twanda_sweet_mail_4.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/tracy_geaccone_mail_1 vs twanda_sweet_mail_4.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 86/217 (already processed): vince_kaminski_mail_3 vs vince_kaminski_mail_1.xlsx
# Skipping file 87/217 (already processed): sean_crandall_mail_1 vs sean_crandall_mail_4.xlsx
# Skipping file 88/217 (already processed): paul_y_barbo_mail_3 vs paul_y_barbo_mail_4.xlsx
# Skipping file 89/217 (already processed): sally_beck_mail_4 vs sara_shackleton_mail_3.xlsx
# Skipping file 90/217 (already processed): vince_kaminski_mail_4 vs w_white_mail_2.xlsx
# Skipping file 91/217 (already processed): tracy_geaccone_mail_4 vs twanda_sweet_mail_4.xlsx
# Skipping file 92/217 (already processed): liz_taylor_mail_1 vs louise_kitchen_mail_4.xlsx
# Skipping file 93/217 (already processed): marie_heard_mail_1 vs marie_heard_mail_3.xlsx
# Skipping file 94/217 (already processed): susan_pereira_mail_4 vs susan_pereira_mail_3.xlsx
# Skipping file 95/217 (already processed): paul_y_barbo_mail_1 vs paul_y_barbo_mail_4.xlsx
# Skipping file 96/217 (already processed): larry_campbell_mail_3 vs lindy_donoho_mail_4.xlsx
# Skipping file 97/217 (already processed): liz_taylor_mail_3 vs liz_taylor_mail_2.xlsx
# Processing file 98/217: lynn_blair_mail_2 vs lysa_akin_mail_3.xlsx
# Processing Document: lynn_blair_mail_2 vs lysa_akin_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/lynn_blair_mail_2 vs lysa_akin_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 99/217 (already processed): v_weldon_mail_4 vs v_weldon_mail_5.xlsx
# Skipping file 100/217 (already processed): v_weldon_mail_1 vs vince_kaminski_mail_1.xlsx
# Skipping file 101/217 (already processed): richard_sanders_mail_4 vs rick_buy_mail_3.xlsx
# Skipping file 102/217 (already processed): rick_buy_mail_1 vs rob_gay_mail_4.xlsx
# Skipping file 103/217 (already processed): louise_kitchen_mail_2 vs louise_kitchen_mail_4.xlsx
# Skipping file 104/217 (already processed): mark_taylor_mail_1 vs mark_taylor_mail_2.xlsx
# Skipping file 105/217 (already processed): martin_cuilla_mail_3 vs mary_hain_mail_3.xlsx
# Skipping file 106/217 (already processed): lindy_donoho_mail_2 vs liz_taylor_mail_2.xlsx
# Skipping file 107/217 (already processed): rod_hayslett_mail_5 vs rosalee_fleming_mail_4.xlsx
# Skipping file 108/217 (already processed): maureen_mcvicker_mail_1 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 109/217 (already processed): lynn_blair_mail_5 vs lysa_akin_mail_3.xlsx
# Skipping file 110/217 (already processed): paul_y_barbo_mail_1 vs phillip_love_mail_1.xlsx
# Skipping file 111/217 (already processed): mark_haedicke_mail_3 vs mark_taylor_mail_2.xlsx
# Skipping file 112/217 (already processed): louise_kitchen_mail_1 vs louise_kitchen_mail_4.xlsx
# Skipping file 113/217 (already processed): tracy_geaccone_mail_2 vs tracy_geaccone_mail_3.xlsx
# Skipping file 114/217 (already processed): martin_cuilla_mail_1 vs mary_hain_mail_3.xlsx
# Skipping file 115/217 (already processed): liz_taylor_mail_3 vs louise_kitchen_mail_4.xlsx
# Processing file 116/217: kevin_hyatt_mail_1 vs kevin_hyatt_mail_2.xlsx
# Processing Document: kevin_hyatt_mail_1 vs kevin_hyatt_mail_2.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/kevin_hyatt_mail_1 vs kevin_hyatt_mail_2.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 117/217 (already processed): phillip_love_mail_3 vs richard_sanders_mail_3.xlsx
# Skipping file 118/217 (already processed): m_forney_mail_4 vs m_love_mail_3.xlsx
# Skipping file 119/217 (already processed): mary_hain_mail_1 vs mary_hain_mail_3.xlsx
# Skipping file 120/217 (already processed): tracy_geaccone_mail_5 vs tracy_geaccone_mail_3.xlsx
# Skipping file 121/217 (already processed): twanda_sweet_mail_3 vs twanda_sweet_mail_4.xlsx
# Skipping file 122/217 (already processed): stanley_horton_mail_4 vs stanley_horton_mail_1.xlsx
# Skipping file 123/217 (already processed): louise_kitchen_mail_1 vs lynn_blair_mail_3.xlsx
# Skipping file 124/217 (already processed): tana_jones_mail_1 vs tracy_geaccone_mail_3.xlsx
# Skipping file 125/217 (already processed): sara_shackleton_mail_4 vs scott_neal_mail_2.xlsx
# Skipping file 126/217 (already processed): tana_jones_mail_4 vs tana_jones_mail_5.xlsx
# Processing file 127/217: m_love_mail_4 vs m_presto_mail_3.xlsx
# Processing Document: m_love_mail_4 vs m_presto_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/m_love_mail_4 vs m_presto_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 128/217 (already processed): marie_heard_mail_4 vs marie_heard_mail_3.xlsx
# Skipping file 129/217 (already processed): steven_kean_mail_2 vs susan_pereira_mail_3.xlsx
# Skipping file 130/217 (already processed): lynn_blair_mail_1 vs lynn_blair_mail_3.xlsx
# Skipping file 131/217 (already processed): sally_beck_mail_1 vs sara_shackleton_mail_3.xlsx
# Skipping file 132/217 (already processed): lysa_akin_mail_1 vs m_forney_mail_1.xlsx
# Skipping file 133/217 (already processed): louise_kitchen_mail_5 vs louise_kitchen_mail_4.xlsx
# Skipping file 134/217 (already processed): larry_campbell_mail_3 vs larry_campbell_mail_1.xlsx
# Skipping file 135/217 (already processed): maureen_mcvicker_mail_4 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 136/217 (already processed): stanley_horton_mail_2 vs steven_kean_mail_3.xlsx
# Processing file 137/217: kevin_hyatt_mail_4 vs kevin_hyatt_mail_2.xlsx
# Processing Document: kevin_hyatt_mail_4 vs kevin_hyatt_mail_2.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/kevin_hyatt_mail_4 vs kevin_hyatt_mail_2.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 138/217 (already processed): sara_shackleton_mail_5 vs scott_neal_mail_2.xlsx
# Skipping file 139/217 (already processed): liz_taylor_mail_1 vs liz_taylor_mail_2.xlsx
# Skipping file 140/217 (already processed): richard_sanders_mail_1 vs richard_sanders_mail_3.xlsx
# Skipping file 141/217 (already processed): maureen_mcvicker_mail_2 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 142/217 (already processed): lysa_akin_mail_2 vs lysa_akin_mail_3.xlsx
# Processing file 143/217: lynn_blair_mail_4 vs lysa_akin_mail_3.xlsx
# Processing Document: lynn_blair_mail_4 vs lysa_akin_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/lynn_blair_mail_4 vs lysa_akin_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 144/217 (already processed): martin_cuilla_mail_2 vs mary_hain_mail_3.xlsx
# Skipping file 145/217 (already processed): m_love_mail_5 vs m_love_mail_3.xlsx
# Skipping file 146/217 (already processed): rod_hayslett_mail_5 vs rod_hayslett_mail_1.xlsx
# Skipping file 147/217 (already processed): mark_haedicke_mail_5 vs mark_taylor_mail_2.xlsx
# Skipping file 148/217 (already processed): sara_shackleton_mail_4 vs sara_shackleton_mail_3.xlsx
# Skipping file 149/217 (already processed): tracy_geaccone_mail_4 vs tracy_geaccone_mail_3.xlsx
# Skipping file 150/217 (already processed): m_scott_mail_3 vs marie_heard_mail_3.xlsx
# Skipping file 151/217 (already processed): scott_neal_mail_3 vs sean_crandall_mail_4.xlsx
# Skipping file 152/217 (already processed): v_weldon_mail_2 vs v_weldon_mail_5.xlsx
# Skipping file 153/217 (already processed): m_love_mail_2 vs m_love_mail_3.xlsx
# Skipping file 154/217 (already processed): m_love_mail_5 vs m_presto_mail_3.xlsx
# Skipping file 155/217 (already processed): larry_campbell_mail_4 vs lindy_donoho_mail_4.xlsx
# Skipping file 156/217 (already processed): v_weldon_mail_3 vs v_weldon_mail_5.xlsx
# Skipping file 157/217 (already processed): mark_taylor_mail_1 vs martin_cuilla_mail_4.xlsx
# Skipping file 158/217 (already processed): michelle_lokay_mail_4 vs michelle_lokay_mail_3.xlsx
# Skipping file 159/217 (already processed): twanda_sweet_mail_1 vs v_weldon_mail_5.xlsx
# Skipping file 160/217 (already processed): tracy_geaccone_mail_1 vs tracy_geaccone_mail_3.xlsx
# Skipping file 161/217 (already processed): steven_kean_mail_1 vs susan_pereira_mail_3.xlsx
# Skipping file 162/217 (already processed): marie_heard_mail_2 vs marie_heard_mail_3.xlsx
# Skipping file 163/217 (already processed): shelley_corman_mail_1 vs sherri_reinartz_mail_3.xlsx
# Skipping file 164/217 (already processed): larry_campbell_mail_5 vs lindy_donoho_mail_4.xlsx
# Skipping file 165/217 (already processed): m_love_mail_4 vs m_love_mail_3.xlsx
# Skipping file 166/217 (already processed): paul_y_barbo_mail_2 vs paul_y_barbo_mail_4.xlsx
# Skipping file 167/217 (already processed): michelle_lokay_mail_5 vs michelle_lokay_mail_3.xlsx
# Skipping file 168/217 (already processed): kimberly_watson_mail_4 vs larry_campbell_mail_1.xlsx
# Skipping file 169/217 (already processed): tana_jones_mail_3 vs tana_jones_mail_5.xlsx
# Skipping file 170/217 (already processed): twanda_sweet_mail_2 vs v_weldon_mail_5.xlsx
# Skipping file 171/217 (already processed): paul_y_barbo_mail_3 vs phillip_love_mail_1.xlsx
# Skipping file 172/217 (already processed): michelle_cash_mail_5 vs michelle_lokay_mail_3.xlsx
# Skipping file 173/217 (already processed): mike_mcconnell_mail_2 vs paul_y_barbo_mail_4.xlsx
# Skipping file 174/217 (already processed): michelle_cash_mail_2 vs michelle_lokay_mail_3.xlsx
# Skipping file 175/217 (already processed): louise_kitchen_mail_3 vs lynn_blair_mail_3.xlsx
# Skipping file 176/217 (already processed): mark_taylor_mail_5 vs mark_taylor_mail_2.xlsx
# Skipping file 177/217 (already processed): susan_pereira_mail_1 vs susan_pereira_mail_3.xlsx
# Skipping file 178/217 (already processed): mary_hain_mail_5 vs mary_hain_mail_3.xlsx
# Skipping file 179/217 (already processed): steven_kean_mail_4 vs susan_pereira_mail_3.xlsx
# Skipping file 180/217 (already processed): rob_gay_mail_3 vs rod_hayslett_mail_1.xlsx
# Skipping file 181/217 (already processed): phillip_love_mail_4 vs phillip_love_mail_1.xlsx
# Skipping file 182/217 (already processed): larry_campbell_mail_4 vs larry_campbell_mail_1.xlsx
# Skipping file 183/217 (already processed): matt_smith_mail_3 vs maureen_mcvicker_mail_3.xlsx
# Processing file 184/217: michelle_cash_mail_4 vs michelle_lokay_mail_3.xlsx
# Processing Document: michelle_cash_mail_4 vs michelle_lokay_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/michelle_cash_mail_4 vs michelle_lokay_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 185/217 (already processed): m_forney_mail_2 vs m_love_mail_3.xlsx
# Skipping file 186/217 (already processed): phillip_love_mail_2 vs richard_sanders_mail_3.xlsx
# Skipping file 187/217 (already processed): sara_shackleton_mail_1 vs sara_shackleton_mail_3.xlsx
# Skipping file 188/217 (already processed): rob_gay_mail_3 vs rob_gay_mail_4.xlsx
# Processing file 189/217: m_presto_mail_4 vs m_presto_mail_3.xlsx
# Processing Document: m_presto_mail_4 vs m_presto_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-base/gpt2 results/raw/m_presto_mail_4 vs m_presto_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 190/217 (already processed): mary_hain_mail_4 vs mary_hain_mail_3.xlsx
# Skipping file 191/217 (already processed): phillip_love_mail_4 vs richard_sanders_mail_3.xlsx
# Skipping file 192/217 (already processed): vince_kaminski_mail_2 vs vince_kaminski_mail_1.xlsx
# Skipping file 193/217 (already processed): liz_taylor_mail_4 vs louise_kitchen_mail_4.xlsx
# Skipping file 194/217 (already processed): rod_hayslett_mail_3 vs rod_hayslett_mail_1.xlsx
# Skipping file 195/217 (already processed): michelle_cash_mail_3 vs michelle_lokay_mail_3.xlsx
# Skipping file 196/217 (already processed): rosalee_fleming_mail_1 vs rosalee_fleming_mail_4.xlsx
# Skipping file 197/217 (already processed): scott_neal_mail_1 vs scott_neal_mail_2.xlsx
# Skipping file 198/217 (already processed): m_love_mail_1 vs m_presto_mail_3.xlsx
# Skipping file 199/217 (already processed): larry_campbell_mail_2 vs larry_campbell_mail_1.xlsx
# Skipping file 200/217 (already processed): richard_sanders_mail_2 vs rick_buy_mail_3.xlsx
# Skipping file 201/217 (already processed): sean_crandall_mail_2 vs sean_crandall_mail_4.xlsx
# Skipping file 202/217 (already processed): phillip_love_mail_3 vs phillip_love_mail_1.xlsx
# Skipping file 203/217 (already processed): rod_hayslett_mail_3 vs rosalee_fleming_mail_4.xlsx
# Skipping file 204/217 (already processed): louise_kitchen_mail_2 vs lynn_blair_mail_3.xlsx
# Skipping file 205/217 (already processed): rick_buy_mail_2 vs rick_buy_mail_3.xlsx
# Skipping file 206/217 (already processed): vince_kaminski_mail_3 vs w_white_mail_2.xlsx
# Skipping file 207/217 (already processed): scott_neal_mail_1 vs sean_crandall_mail_4.xlsx
# Skipping file 208/217 (already processed): rod_hayslett_mail_4 vs rod_hayslett_mail_1.xlsx
# Skipping file 209/217 (already processed): susan_scott_mail_3 vs tana_jones_mail_5.xlsx
# Skipping file 210/217 (already processed): twanda_sweet_mail_1 vs twanda_sweet_mail_4.xlsx
# Skipping file 211/217 (already processed): tana_jones_mail_3 vs tracy_geaccone_mail_3.xlsx
# Skipping file 212/217 (already processed): m_love_mail_1 vs m_love_mail_3.xlsx
# Skipping file 213/217 (already processed): larry_campbell_mail_5 vs larry_campbell_mail_1.xlsx
# Skipping file 214/217 (already processed): susan_pereira_mail_2 vs susan_pereira_mail_3.xlsx
# Skipping file 215/217 (already processed): louise_kitchen_mail_3 vs louise_kitchen_mail_4.xlsx
# Skipping file 216/217 (already processed): steven_kean_mail_2 vs steven_kean_mail_3.xlsx
# Skipping file 217/217 (already processed): stanley_horton_mail_4 vs steven_kean_mail_3.xlsx
#
# All files complete ✓
#
# Skipping save because no result_save_loc was provided.
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Reading from: /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-large/gpt2 results/raw
# Saving processed files to: /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-large/gpt2 results/raw_inc_rank
# No result_save_loc provided → combined file will NOT be saved.
#
# Found 238 files
#
# Skipping file 1/238 (already processed): lysa_akin_mail_1 vs lysa_akin_mail_3.xlsx
# Skipping file 2/238 (already processed): lynn_blair_mail_5 vs lynn_blair_mail_3.xlsx
# Skipping file 3/238 (already processed): lindy_donoho_mail_1 vs lindy_donoho_mail_4.xlsx
# Skipping file 4/238 (already processed): kimberly_watson_mail_5 vs larry_campbell_mail_1.xlsx
# Skipping file 5/238 (already processed): liz_taylor_mail_4 vs liz_taylor_mail_2.xlsx
# Skipping file 6/238 (already processed): m_forney_mail_5 vs m_love_mail_3.xlsx
# Skipping file 7/238 (already processed): lysa_akin_mail_4 vs m_forney_mail_1.xlsx
# Skipping file 8/238 (already processed): mark_haedicke_mail_1 vs mark_taylor_mail_2.xlsx
# Skipping file 9/238 (already processed): kevin_hyatt_mail_5 vs kevin_hyatt_mail_2.xlsx
# Processing file 10/238: louise_kitchen_mail_5 vs lynn_blair_mail_3.xlsx
# Processing Document: louise_kitchen_mail_5 vs lynn_blair_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-large/gpt2 results/raw/louise_kitchen_mail_5 vs lynn_blair_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 11/238 (already processed): m_forney_mail_3 vs m_love_mail_3.xlsx
# Skipping file 12/238 (already processed): m_presto_mail_1 vs m_presto_mail_3.xlsx
# Skipping file 13/238 (already processed): lindy_donoho_mail_3 vs liz_taylor_mail_2.xlsx
# Skipping file 14/238 (already processed): lysa_akin_mail_4 vs lysa_akin_mail_3.xlsx
# Skipping file 15/238 (already processed): marie_heard_mail_5 vs marie_heard_mail_3.xlsx
# Skipping file 16/238 (already processed): m_love_mail_2 vs m_presto_mail_3.xlsx
# Skipping file 17/238 (already processed): lynn_blair_mail_4 vs lynn_blair_mail_3.xlsx
# Skipping file 18/238 (already processed): lindy_donoho_mail_5 vs liz_taylor_mail_2.xlsx
# Skipping file 19/238 (already processed): lysa_akin_mail_5 vs lysa_akin_mail_3.xlsx
# Skipping file 20/238 (already processed): lindy_donoho_mail_3 vs lindy_donoho_mail_4.xlsx
# Skipping file 21/238 (already processed): m_presto_mail_2 vs m_presto_mail_3.xlsx
# Skipping file 22/238 (already processed): kimberly_watson_mail_2 vs larry_campbell_mail_1.xlsx
# Skipping file 23/238 (already processed): larry_campbell_mail_2 vs lindy_donoho_mail_4.xlsx
# Skipping file 24/238 (already processed): lindy_donoho_mail_5 vs lindy_donoho_mail_4.xlsx
# Skipping file 25/238 (already processed): lindy_donoho_mail_1 vs liz_taylor_mail_2.xlsx
# Skipping file 26/238 (already processed): lindy_donoho_mail_2 vs lindy_donoho_mail_4.xlsx
# Skipping file 27/238 (already processed): kimberly_watson_mail_1 vs larry_campbell_mail_1.xlsx
# Skipping file 28/238 (already processed): mark_haedicke_mail_4 vs mark_taylor_mail_2.xlsx
# Skipping file 29/238 (already processed): kevin_hyatt_mail_3 vs kevin_hyatt_mail_2.xlsx
# Skipping file 30/238 (already processed): lynn_blair_mail_1 vs lysa_akin_mail_3.xlsx
# Skipping file 31/238 (already processed): liz_taylor_mail_1 vs louise_kitchen_mail_4.xlsx
# Skipping file 32/238 (already processed): larry_campbell_mail_3 vs lindy_donoho_mail_4.xlsx
# Skipping file 33/238 (already processed): liz_taylor_mail_3 vs liz_taylor_mail_2.xlsx
# Skipping file 34/238 (already processed): lynn_blair_mail_2 vs lysa_akin_mail_3.xlsx
# Skipping file 35/238 (already processed): lindy_donoho_mail_2 vs liz_taylor_mail_2.xlsx
# Skipping file 36/238 (already processed): lynn_blair_mail_5 vs lysa_akin_mail_3.xlsx
# Skipping file 37/238 (already processed): mark_haedicke_mail_3 vs mark_taylor_mail_2.xlsx
# Skipping file 38/238 (already processed): louise_kitchen_mail_1 vs louise_kitchen_mail_4.xlsx
# Skipping file 39/238 (already processed): liz_taylor_mail_3 vs louise_kitchen_mail_4.xlsx
# Skipping file 40/238 (already processed): kevin_hyatt_mail_1 vs kevin_hyatt_mail_2.xlsx
# Skipping file 41/238 (already processed): lysa_akin_mail_1 vs m_forney_mail_1.xlsx
# Skipping file 42/238 (already processed): louise_kitchen_mail_5 vs louise_kitchen_mail_4.xlsx
# Skipping file 43/238 (already processed): larry_campbell_mail_3 vs larry_campbell_mail_1.xlsx
# Skipping file 44/238 (already processed): kevin_hyatt_mail_4 vs kevin_hyatt_mail_2.xlsx
# Skipping file 45/238 (already processed): liz_taylor_mail_1 vs liz_taylor_mail_2.xlsx
# Skipping file 46/238 (already processed): lynn_blair_mail_4 vs lysa_akin_mail_3.xlsx
# Skipping file 47/238 (already processed): m_love_mail_2 vs m_love_mail_3.xlsx
# Skipping file 48/238 (already processed): m_love_mail_5 vs m_presto_mail_3.xlsx
# Skipping file 49/238 (already processed): larry_campbell_mail_4 vs lindy_donoho_mail_4.xlsx
# Skipping file 50/238 (already processed): kimberly_watson_mail_4 vs larry_campbell_mail_1.xlsx
# Skipping file 51/238 (already processed): louise_kitchen_mail_3 vs lynn_blair_mail_3.xlsx
# Skipping file 52/238 (already processed): mary_hain_mail_5 vs mary_hain_mail_3.xlsx
# Skipping file 53/238 (already processed): larry_campbell_mail_4 vs larry_campbell_mail_1.xlsx
# Skipping file 54/238 (already processed): m_presto_mail_4 vs m_presto_mail_3.xlsx
# Skipping file 55/238 (already processed): liz_taylor_mail_4 vs louise_kitchen_mail_4.xlsx
# Skipping file 56/238 (already processed): larry_campbell_mail_2 vs larry_campbell_mail_1.xlsx
# Skipping file 57/238 (already processed): m_love_mail_1 vs m_presto_mail_3.xlsx
# Skipping file 58/238 (already processed): larry_campbell_mail_5 vs larry_campbell_mail_1.xlsx
# Skipping file 59/238 (already processed): louise_kitchen_mail_3 vs louise_kitchen_mail_4.xlsx
# Skipping file 60/238 (already processed): marie_heard_mail_1 vs marie_heard_mail_3.xlsx
# Skipping file 61/238 (already processed): martin_cuilla_mail_2 vs mary_hain_mail_3.xlsx
# Skipping file 62/238 (already processed): mark_taylor_mail_3 vs mark_taylor_mail_2.xlsx
# Skipping file 63/238 (already processed): louise_kitchen_mail_1 vs lynn_blair_mail_3.xlsx
# Skipping file 64/238 (already processed): m_love_mail_5 vs m_love_mail_3.xlsx
# Skipping file 65/238 (already processed): michelle_lokay_mail_1 vs michelle_lokay_mail_3.xlsx
# Skipping file 66/238 (already processed): mark_haedicke_mail_4 vs mark_haedicke_mail_2.xlsx
# Skipping file 67/238 (already processed): lynn_blair_mail_2 vs lynn_blair_mail_3.xlsx
# Skipping file 68/238 (already processed): maureen_mcvicker_mail_5 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 69/238 (already processed): mary_hain_mail_2 vs mary_hain_mail_3.xlsx
# Skipping file 70/238 (already processed): michelle_lokay_mail_2 vs michelle_lokay_mail_3.xlsx
# Skipping file 71/238 (already processed): paul_y_barbo_mail_3 vs paul_y_barbo_mail_4.xlsx
# Skipping file 72/238 (already processed): paul_y_barbo_mail_1 vs paul_y_barbo_mail_4.xlsx
# Skipping file 73/238 (already processed): louise_kitchen_mail_2 vs louise_kitchen_mail_4.xlsx
# Skipping file 74/238 (already processed): maureen_mcvicker_mail_1 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 75/238 (already processed): martin_cuilla_mail_1 vs mary_hain_mail_3.xlsx
# Skipping file 76/238 (already processed): mary_hain_mail_1 vs mary_hain_mail_3.xlsx
# Skipping file 77/238 (already processed): m_love_mail_4 vs m_presto_mail_3.xlsx
# Skipping file 78/238 (already processed): marie_heard_mail_4 vs marie_heard_mail_3.xlsx
# Skipping file 79/238 (already processed): lynn_blair_mail_1 vs lynn_blair_mail_3.xlsx
# Skipping file 80/238 (already processed): lysa_akin_mail_2 vs lysa_akin_mail_3.xlsx
# Skipping file 81/238 (already processed): m_scott_mail_3 vs marie_heard_mail_3.xlsx
# Skipping file 82/238 (already processed): mark_haedicke_mail_5 vs mark_taylor_mail_2.xlsx
# Skipping file 83/238 (already processed): mark_taylor_mail_1 vs martin_cuilla_mail_4.xlsx
# Skipping file 84/238 (already processed): michelle_lokay_mail_4 vs michelle_lokay_mail_3.xlsx
# Skipping file 85/238 (already processed): marie_heard_mail_2 vs marie_heard_mail_3.xlsx
# Skipping file 86/238 (already processed): m_love_mail_4 vs m_love_mail_3.xlsx
# Skipping file 87/238 (already processed): michelle_lokay_mail_5 vs michelle_lokay_mail_3.xlsx
# Skipping file 88/238 (already processed): paul_y_barbo_mail_3 vs phillip_love_mail_1.xlsx
# Skipping file 89/238 (already processed): michelle_cash_mail_5 vs michelle_lokay_mail_3.xlsx
# Skipping file 90/238 (already processed): michelle_cash_mail_2 vs michelle_lokay_mail_3.xlsx
# Skipping file 91/238 (already processed): m_forney_mail_2 vs m_love_mail_3.xlsx
# Skipping file 92/238 (already processed): mark_taylor_mail_5 vs mark_taylor_mail_2.xlsx
# Skipping file 93/238 (already processed): mary_hain_mail_4 vs mary_hain_mail_3.xlsx
# Skipping file 94/238 (already processed): louise_kitchen_mail_2 vs lynn_blair_mail_3.xlsx
# Skipping file 95/238 (already processed): mark_taylor_mail_1 vs mark_taylor_mail_2.xlsx
# Skipping file 96/238 (already processed): rob_gay_mail_2 vs rod_hayslett_mail_1.xlsx
# Processing file 97/238: matt_smith_mail_3 vs maureen_mcvicker_mail_3.xlsx
# Processing Document: matt_smith_mail_3 vs maureen_mcvicker_mail_3.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-large/gpt2 results/raw/matt_smith_mail_3 vs maureen_mcvicker_mail_3.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 98/238 (already processed): martin_cuilla_mail_3 vs mary_hain_mail_3.xlsx
# Skipping file 99/238 (already processed): mark_taylor_mail_4 vs mark_taylor_mail_2.xlsx
# Skipping file 100/238 (already processed): michelle_cash_mail_4 vs michelle_lokay_mail_3.xlsx
# Skipping file 101/238 (already processed): m_love_mail_1 vs m_love_mail_3.xlsx
# Skipping file 102/238 (already processed): richard_sanders_mail_1 vs rick_buy_mail_3.xlsx
# Skipping file 103/238 (already processed): rob_gay_mail_3 vs rod_hayslett_mail_1.xlsx
# Skipping file 104/238 (already processed): m_forney_mail_4 vs m_love_mail_3.xlsx
# Skipping file 105/238 (already processed): mark_haedicke_mail_3 vs mark_haedicke_mail_2.xlsx
# Skipping file 106/238 (already processed): rick_buy_mail_1 vs rob_gay_mail_4.xlsx
# Skipping file 107/238 (already processed): phillip_love_mail_2 vs richard_sanders_mail_3.xlsx
# Skipping file 108/238 (already processed): rod_hayslett_mail_3 vs rod_hayslett_mail_1.xlsx
# Skipping file 109/238 (already processed): phillip_love_mail_3 vs phillip_love_mail_1.xlsx
# Skipping file 110/238 (already processed): rod_hayslett_mail_4 vs rod_hayslett_mail_1.xlsx
# Skipping file 111/238 (already processed): rod_hayslett_mail_4 vs rosalee_fleming_mail_4.xlsx
# Skipping file 112/238 (already processed): susan_scott_mail_1 vs tana_jones_mail_5.xlsx
# Skipping file 113/238 (already processed): sally_beck_mail_2 vs sara_shackleton_mail_3.xlsx
# Skipping file 114/238 (already processed): scott_neal_mail_4 vs scott_neal_mail_2.xlsx
# Skipping file 115/238 (already processed): rosalee_fleming_mail_2 vs rosalee_fleming_mail_4.xlsx
# Skipping file 116/238 (already processed): sara_shackleton_mail_2 vs sara_shackleton_mail_3.xlsx
# Skipping file 117/238 (already processed): shelley_corman_mail_2 vs sherri_reinartz_mail_3.xlsx
# Skipping file 118/238 (already processed): rick_buy_mail_2 vs rob_gay_mail_4.xlsx
# Skipping file 119/238 (already processed): rick_buy_mail_4 vs rick_buy_mail_3.xlsx
# Skipping file 120/238 (already processed): steven_kean_mail_4 vs steven_kean_mail_3.xlsx
# Skipping file 121/238 (already processed): mike_mcconnell_mail_4 vs paul_y_barbo_mail_4.xlsx
# Skipping file 122/238 (already processed): shelley_corman_mail_3 vs sherri_reinartz_mail_3.xlsx
# Skipping file 123/238 (already processed): sherri_reinartz_mail_2 vs sherri_reinartz_mail_3.xlsx
# Processing file 124/238: rick_buy_mail_4 vs rob_gay_mail_4.xlsx
# Processing Document: rick_buy_mail_4 vs rob_gay_mail_4.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-large/gpt2 results/raw/rick_buy_mail_4 vs rob_gay_mail_4.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 125/238 (already processed): rob_gay_mail_1 vs rob_gay_mail_4.xlsx
# Skipping file 126/238 (already processed): tracy_geaccone_mail_2 vs twanda_sweet_mail_4.xlsx
# Skipping file 127/238 (already processed): w_white_mail_1 vs kevin_hyatt_mail_2.xlsx
# Skipping file 128/238 (already processed): tracy_geaccone_mail_5 vs twanda_sweet_mail_4.xlsx
# Skipping file 129/238 (already processed): sara_shackleton_mail_5 vs sara_shackleton_mail_3.xlsx
# Skipping file 130/238 (already processed): tana_jones_mail_1 vs tana_jones_mail_5.xlsx
# Skipping file 131/238 (already processed): sherri_reinartz_mail_4 vs sherri_reinartz_mail_3.xlsx
# Skipping file 132/238 (already processed): rosalee_fleming_mail_3 vs rosalee_fleming_mail_4.xlsx
# Skipping file 133/238 (already processed): scott_neal_mail_4 vs sean_crandall_mail_4.xlsx
# Skipping file 134/238 (already processed): rob_gay_mail_1 vs rod_hayslett_mail_1.xlsx
# Skipping file 135/238 (already processed): twanda_sweet_mail_3 vs v_weldon_mail_5.xlsx
# Skipping file 136/238 (already processed): sara_shackleton_mail_1 vs scott_neal_mail_2.xlsx
# Skipping file 137/238 (already processed): mike_mcconnell_mail_1 vs paul_y_barbo_mail_4.xlsx
# Processing file 138/238: rob_gay_mail_2 vs rob_gay_mail_4.xlsx
# Processing Document: rob_gay_mail_2 vs rob_gay_mail_4.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-large/gpt2 results/raw/rob_gay_mail_2 vs rob_gay_mail_4.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 139/238 (already processed): stacy_dickson_mail_3 vs stacy_dickson_mail_5.xlsx
# Skipping file 140/238 (already processed): scott_neal_mail_3 vs scott_neal_mail_2.xlsx
# Skipping file 141/238 (already processed): richard_sanders_mail_2 vs richard_sanders_mail_3.xlsx
# Skipping file 142/238 (already processed): sara_shackleton_mail_2 vs scott_neal_mail_2.xlsx
# Skipping file 143/238 (already processed): sean_crandall_mail_5 vs sean_crandall_mail_4.xlsx
# Skipping file 144/238 (already processed): stacy_dickson_mail_1 vs stanley_horton_mail_1.xlsx
# Skipping file 145/238 (already processed): rick_buy_mail_1 vs rick_buy_mail_3.xlsx
# Skipping file 146/238 (already processed): matt_smith_mail_4 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 147/238 (already processed): stacy_dickson_mail_4 vs stanley_horton_mail_1.xlsx
# Skipping file 148/238 (already processed): tracy_geaccone_mail_1 vs twanda_sweet_mail_4.xlsx
# Skipping file 149/238 (already processed): sean_crandall_mail_1 vs sean_crandall_mail_4.xlsx
# Skipping file 150/238 (already processed): sally_beck_mail_4 vs sara_shackleton_mail_3.xlsx
# Skipping file 151/238 (already processed): tracy_geaccone_mail_4 vs twanda_sweet_mail_4.xlsx
# Skipping file 152/238 (already processed): stacy_dickson_mail_2 vs stanley_horton_mail_1.xlsx
# Skipping file 153/238 (already processed): stacy_dickson_mail_4 vs stacy_dickson_mail_5.xlsx
# Skipping file 154/238 (already processed): susan_pereira_mail_4 vs susan_pereira_mail_3.xlsx
# Skipping file 155/238 (already processed): richard_sanders_mail_4 vs rick_buy_mail_3.xlsx
# Skipping file 156/238 (already processed): stacy_dickson_mail_2 vs stacy_dickson_mail_5.xlsx
# Skipping file 157/238 (already processed): rod_hayslett_mail_5 vs rosalee_fleming_mail_4.xlsx
# Skipping file 158/238 (already processed): paul_y_barbo_mail_1 vs phillip_love_mail_1.xlsx
# Skipping file 159/238 (already processed): shelley_corman_mail_4 vs sherri_reinartz_mail_3.xlsx
# Skipping file 160/238 (already processed): tracy_geaccone_mail_2 vs tracy_geaccone_mail_3.xlsx
# Skipping file 161/238 (already processed): phillip_love_mail_3 vs richard_sanders_mail_3.xlsx
# Skipping file 162/238 (already processed): tracy_geaccone_mail_5 vs tracy_geaccone_mail_3.xlsx
# Skipping file 163/238 (already processed): twanda_sweet_mail_3 vs twanda_sweet_mail_4.xlsx
# Skipping file 164/238 (already processed): stanley_horton_mail_4 vs stanley_horton_mail_1.xlsx
# Skipping file 165/238 (already processed): tana_jones_mail_1 vs tracy_geaccone_mail_3.xlsx
# Skipping file 166/238 (already processed): sara_shackleton_mail_4 vs scott_neal_mail_2.xlsx
# Skipping file 167/238 (already processed): steven_kean_mail_2 vs susan_pereira_mail_3.xlsx
# Skipping file 168/238 (already processed): sally_beck_mail_1 vs sara_shackleton_mail_3.xlsx
# Skipping file 169/238 (already processed): maureen_mcvicker_mail_4 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 170/238 (already processed): sara_shackleton_mail_5 vs scott_neal_mail_2.xlsx
# Skipping file 171/238 (already processed): richard_sanders_mail_1 vs richard_sanders_mail_3.xlsx
# Skipping file 172/238 (already processed): maureen_mcvicker_mail_2 vs maureen_mcvicker_mail_3.xlsx
# Skipping file 173/238 (already processed): rod_hayslett_mail_5 vs rod_hayslett_mail_1.xlsx
# Skipping file 174/238 (already processed): sara_shackleton_mail_4 vs sara_shackleton_mail_3.xlsx
# Skipping file 175/238 (already processed): tracy_geaccone_mail_4 vs tracy_geaccone_mail_3.xlsx
# Skipping file 176/238 (already processed): sherri_reinartz_mail_2 vs stacy_dickson_mail_5.xlsx
# Skipping file 177/238 (already processed): scott_neal_mail_3 vs sean_crandall_mail_4.xlsx
# Skipping file 178/238 (already processed): steven_kean_mail_1 vs susan_pereira_mail_3.xlsx
# Skipping file 179/238 (already processed): shelley_corman_mail_1 vs sherri_reinartz_mail_3.xlsx
# Skipping file 180/238 (already processed): stacy_dickson_mail_3 vs stanley_horton_mail_1.xlsx
# Skipping file 181/238 (already processed): paul_y_barbo_mail_2 vs paul_y_barbo_mail_4.xlsx
# Skipping file 182/238 (already processed): mike_mcconnell_mail_2 vs paul_y_barbo_mail_4.xlsx
# Skipping file 183/238 (already processed): stanley_horton_mail_2 vs stanley_horton_mail_1.xlsx
# Skipping file 184/238 (already processed): susan_pereira_mail_1 vs susan_pereira_mail_3.xlsx
# Skipping file 185/238 (already processed): steven_kean_mail_4 vs susan_pereira_mail_3.xlsx
# Skipping file 186/238 (already processed): phillip_love_mail_4 vs phillip_love_mail_1.xlsx
# Skipping file 187/238 (already processed): sara_shackleton_mail_1 vs sara_shackleton_mail_3.xlsx
# Skipping file 188/238 (already processed): sherri_reinartz_mail_1 vs sherri_reinartz_mail_3.xlsx
# Skipping file 189/238 (already processed): sherri_reinartz_mail_1 vs stacy_dickson_mail_5.xlsx
# Skipping file 190/238 (already processed): rob_gay_mail_3 vs rob_gay_mail_4.xlsx
# Skipping file 191/238 (already processed): phillip_love_mail_4 vs richard_sanders_mail_3.xlsx
# Processing file 192/238: rosalee_fleming_mail_1 vs rosalee_fleming_mail_4.xlsx
# Processing Document: rosalee_fleming_mail_1 vs rosalee_fleming_mail_4.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-large/gpt2 results/raw/rosalee_fleming_mail_1 vs rosalee_fleming_mail_4.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 193/238 (already processed): michelle_cash_mail_3 vs michelle_lokay_mail_3.xlsx
# Skipping file 194/238 (already processed): scott_neal_mail_1 vs scott_neal_mail_2.xlsx
# Skipping file 195/238 (already processed): richard_sanders_mail_2 vs rick_buy_mail_3.xlsx
# Processing file 196/238: sean_crandall_mail_2 vs sean_crandall_mail_4.xlsx
# Processing Document: sean_crandall_mail_2 vs sean_crandall_mail_4.xlsx
# ❌ Failed to process /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Enron/ModernBERT-large/gpt2 results/raw/sean_crandall_mail_2 vs sean_crandall_mail_4.xlsx
# Error: No such keys(s): 'io.excel.zip.reader'
#
# Skipping file 197/238 (already processed): rod_hayslett_mail_3 vs rosalee_fleming_mail_4.xlsx
# Skipping file 198/238 (already processed): rick_buy_mail_2 vs rick_buy_mail_3.xlsx
# Skipping file 199/238 (already processed): scott_neal_mail_1 vs sean_crandall_mail_4.xlsx
# Skipping file 200/238 (already processed): stacy_dickson_mail_1 vs stacy_dickson_mail_5.xlsx
# Skipping file 201/238 (already processed): sherri_reinartz_mail_4 vs stacy_dickson_mail_5.xlsx
# Skipping file 202/238 (already processed): susan_pereira_mail_2 vs susan_pereira_mail_3.xlsx
# Skipping file 203/238 (already processed): tana_jones_mail_2 vs tana_jones_mail_5.xlsx
# Skipping file 204/238 (already processed): vince_kaminski_mail_2 vs w_white_mail_2.xlsx
# Skipping file 205/238 (already processed): stanley_horton_mail_4 vs steven_kean_mail_3.xlsx
# Skipping file 206/238 (already processed): steven_kean_mail_2 vs steven_kean_mail_3.xlsx
# Skipping file 207/238 (already processed): stanley_horton_mail_3 vs steven_kean_mail_3.xlsx
# Skipping file 208/238 (already processed): tana_jones_mail_4 vs tracy_geaccone_mail_3.xlsx
# Skipping file 209/238 (already processed): w_white_mail_3 vs w_white_mail_2.xlsx
# Skipping file 210/238 (already processed): vince_kaminski_mail_4 vs vince_kaminski_mail_1.xlsx
# ...
# Processing Document: louisapeacock_text_1 vs louisearmitstead_text_1.xlsx
# Writing file
# Processing file 333/408: matthewd_ancona_text_2 vs matthewholehouse_text_2.xlsx
# Processing Document: matthewd_ancona_text_2 vs matthewholehouse_text_2.xlsx
# Writing file
# Processing file 334/408: mikepflanz_text_3 vs mirandaprynne_text_1.xlsx
# Processing Document: mikepflanz_text_3 vs mirandaprynne_text_1.xlsx
# Writing file
# Processing file 335/408: neilmccormick_text_1 vs neilmccormick_text_2.xlsx
# Processing Document: neilmccormick_text_1 vs neilmccormick_text_2.xlsx
# Writing file
# Processing file 336/408: lizphillips_text_1 vs lizphillips_text_3.xlsx
# Processing Document: lizphillips_text_1 vs lizphillips_text_3.xlsx
# Writing file
# Processing file 337/408: oliviaparker_text_3 vs patricksawer_text_3.xlsx
# Processing Document: oliviaparker_text_3 vs patricksawer_text_3.xlsx
# Writing file
# Processing file 338/408: rachelbridge_text_1 vs rachelward_text_1.xlsx
# Processing Document: rachelbridge_text_1 vs rachelward_text_1.xlsx
# Writing file
# Processing file 339/408: jemimalewis_text_2 vs jemimalewis_text_1.xlsx
# Processing Document: jemimalewis_text_2 vs jemimalewis_text_1.xlsx
# Writing file
# Processing file 340/408: peterfoster_text_2 vs peterfoster_text_1.xlsx
# Processing Document: peterfoster_text_2 vs peterfoster_text_1.xlsx
# Writing file
# Processing file 341/408: terrywogan_text_3 vs terrywogan_text_2.xlsx
# Processing Document: terrywogan_text_3 vs terrywogan_text_2.xlsx
# Writing file
# Processing file 342/408: katelaven_text_1 vs katepalmer_text_1.xlsx
# Processing Document: katelaven_text_1 vs katepalmer_text_1.xlsx
# Writing file
# Processing file 343/408: mehreenkhan_text_3 vs michaeldeacon_text_2.xlsx
# Processing Document: mehreenkhan_text_3 vs michaeldeacon_text_2.xlsx
# Writing file
# Processing file 344/408: lornabradbury_text_3 vs louisapeacock_text_3.xlsx
# Processing Document: lornabradbury_text_3 vs louisapeacock_text_3.xlsx
# Writing file
# Processing file 345/408: lauradonnelly_text_3 vs laurencedodds_text_2.xlsx
# Processing Document: lauradonnelly_text_3 vs laurencedodds_text_2.xlsx
# Writing file
# Processing file 346/408: theomerz_text_3 vs timmartin_text_1.xlsx
# Processing Document: theomerz_text_3 vs timmartin_text_1.xlsx
# Writing file
# Processing file 347/408: lornabradbury_text_3 vs lornabradbury_text_1.xlsx
# Processing Document: lornabradbury_text_3 vs lornabradbury_text_1.xlsx
# Writing file
# Processing file 348/408: lucydavies_text_2 vs lucykinder_text_3.xlsx
# Processing Document: lucydavies_text_2 vs lucykinder_text_3.xlsx
# Writing file
# Processing file 349/408: neilmidgley_text_3 vs neilmidgley_text_1.xlsx
# Processing Document: neilmidgley_text_3 vs neilmidgley_text_1.xlsx
# Writing file
# Processing file 350/408: sarahcrompton_text_1 vs sarahcrompton_text_2.xlsx
# Processing Document: sarahcrompton_text_1 vs sarahcrompton_text_2.xlsx
# Writing file
# Processing file 351/408: jamesquinn_text_3 vs jamestitcomb_text_2.xlsx
# Processing Document: jamesquinn_text_3 vs jamestitcomb_text_2.xlsx
# Writing file
# Processing file 352/408: michaelkerr_text_1 vs michaelkerr_text_2.xlsx
# Processing Document: michaelkerr_text_1 vs michaelkerr_text_2.xlsx
# Writing file
# Processing file 353/408: philipjohnston_text_1 vs philipjohnston_text_2.xlsx
# Processing Document: philipjohnston_text_1 vs philipjohnston_text_2.xlsx
# Writing file
# Processing file 354/408: lucycavendish_text_2 vs lucycavendish_text_1.xlsx
# Processing Document: lucycavendish_text_2 vs lucycavendish_text_1.xlsx
# Writing file
# Processing file 355/408: rosaprince_text_3 vs rosaprince_text_1.xlsx
# Processing Document: rosaprince_text_3 vs rosaprince_text_1.xlsx
# Writing file
# Processing file 356/408: johnbingham_text_1 vs johnbingham_text_2.xlsx
# Processing Document: johnbingham_text_1 vs johnbingham_text_2.xlsx
# Writing file
# Processing file 357/408: tobiasmews_text_2 vs tobiasmews_text_1.xlsx
# Processing Document: tobiasmews_text_2 vs tobiasmews_text_1.xlsx
# Writing file
# Processing file 358/408: malcolmmoore_text_2 vs malcolmpein_text_1.xlsx
# Processing Document: malcolmmoore_text_2 vs malcolmpein_text_1.xlsx
# Writing file
# Processing file 359/408: michaeldeacon_text_3 vs michaelhayman_text_3.xlsx
# Processing Document: michaeldeacon_text_3 vs michaelhayman_text_3.xlsx
# Writing file
# Processing file 360/408: rowanpelling_text_3 vs rupertchristiansen_text_3.xlsx
# Processing Document: rowanpelling_text_3 vs rupertchristiansen_text_3.xlsx
# Writing file
# Processing file 361/408: neilmccormick_text_3 vs neilmccormick_text_2.xlsx
# Processing Document: neilmccormick_text_3 vs neilmccormick_text_2.xlsx
# Writing file
# Processing file 362/408: propertyadvice_text_2 vs rachelbridge_text_2.xlsx
# Processing Document: propertyadvice_text_2 vs rachelbridge_text_2.xlsx
# Writing file
# Processing file 363/408: peterfoster_text_3 vs peterfoster_text_1.xlsx
# Processing Document: peterfoster_text_3 vs peterfoster_text_1.xlsx
# Writing file
# Processing file 364/408: katepalmer_text_2 vs katepalmer_text_1.xlsx
# Processing Document: katepalmer_text_2 vs katepalmer_text_1.xlsx
# Writing file
# Processing file 365/408: richarddorment_text_1 vs richardevans_text_1.xlsx
# Processing Document: richarddorment_text_1 vs richardevans_text_1.xlsx
# Writing file
# Processing file 366/408: jamescracknell_text_2 vs jamescracknell_text_1.xlsx
# Processing Document: jamescracknell_text_2 vs jamescracknell_text_1.xlsx
# Writing file
# Processing file 367/408: philipsherwell_text_1 vs philipsherwell_text_3.xlsx
# Processing Document: philipsherwell_text_1 vs philipsherwell_text_3.xlsx
# Writing file
# Processing file 368/408: laurencedodds_text_1 vs leahhyslop_text_1.xlsx
# Processing Document: laurencedodds_text_1 vs leahhyslop_text_1.xlsx
# Writing file
# Processing file 369/408: maryriddell_text_2 vs matthewd_ancona_text_1.xlsx
# Processing Document: maryriddell_text_2 vs matthewd_ancona_text_1.xlsx
# Writing file
# Processing file 370/408: martinchilton_text_2 vs martinevans_text_2.xlsx
# Processing Document: martinchilton_text_2 vs martinevans_text_2.xlsx
# Writing file
# Processing file 371/408: michaeldeacon_text_3 vs michaeldeacon_text_2.xlsx
# Processing Document: michaeldeacon_text_3 vs michaeldeacon_text_2.xlsx
# Writing file
# Processing file 372/408: louisapeacock_text_2 vs louisapeacock_text_3.xlsx
# Processing Document: louisapeacock_text_2 vs louisapeacock_text_3.xlsx
# Writing file
# Processing file 373/408: justinharper_text_1 vs justinharper_text_3.xlsx
# Processing Document: justinharper_text_1 vs justinharper_text_3.xlsx
# Writing file
# Processing file 374/408: michaelhayman_text_2 vs michaelkerr_text_2.xlsx
# Processing Document: michaelhayman_text_2 vs michaelkerr_text_2.xlsx
# Writing file
# Processing file 375/408: neilmccormick_text_3 vs neilmidgley_text_1.xlsx
# Processing Document: neilmccormick_text_3 vs neilmidgley_text_1.xlsx
# Writing file
# Processing file 376/408: stevieparle_text_3 vs szupingchan_text_3.xlsx
# Processing Document: stevieparle_text_3 vs szupingchan_text_3.xlsx
# Writing file
# Processing file 377/408: paulclements_text_3 vs paulhayward_text_2.xlsx
# Processing Document: paulclements_text_3 vs paulhayward_text_2.xlsx
# Writing file
# Processing file 378/408: victoriamoore_text_1 vs victoriamoore_text_2.xlsx
# Processing Document: victoriamoore_text_1 vs victoriamoore_text_2.xlsx
# Writing file
# Processing file 379/408: martinevans_text_1 vs martinevans_text_2.xlsx
# Processing Document: martinevans_text_1 vs martinevans_text_2.xlsx
# Writing file
# Processing file 380/408: matthewnorman_text_3 vs matthewnorman_text_1.xlsx
# Processing Document: matthewnorman_text_3 vs matthewnorman_text_1.xlsx
# Writing file
# Processing file 381/408: stevenswinford_text_2 vs stevenswinford_text_3.xlsx
# Processing Document: stevenswinford_text_2 vs stevenswinford_text_3.xlsx
# Writing file
# Processing file 382/408: nickallen_text_3 vs nickcollins_text_3.xlsx
# Processing Document: nickallen_text_3 vs nickcollins_text_3.xlsx
# Writing file
# Processing file 383/408: szupingchan_text_2 vs szupingchan_text_3.xlsx
# Processing Document: szupingchan_text_2 vs szupingchan_text_3.xlsx
# Writing file
# Processing file 384/408: sarahrainey_text_3 vs sarahrainey_text_2.xlsx
# Processing Document: sarahrainey_text_3 vs sarahrainey_text_2.xlsx
# Writing file
# Processing file 385/408: scottlaidler_text_3 vs scyldberry_text_3.xlsx
# Processing Document: scottlaidler_text_3 vs scyldberry_text_3.xlsx
# Writing file
# Processing file 386/408: rachelbridge_text_1 vs rachelbridge_text_2.xlsx
# Processing Document: rachelbridge_text_1 vs rachelbridge_text_2.xlsx
# Writing file
# Processing file 387/408: sookim_text_1 vs sookim_text_3.xlsx
# Processing Document: sookim_text_1 vs sookim_text_3.xlsx
# Writing file
# Processing file 388/408: simonbriggs_text_3 vs simonhart_text_3.xlsx
# Processing Document: simonbriggs_text_3 vs simonhart_text_3.xlsx
# Writing file
# Processing file 389/408: sookim_text_2 vs sophiecurtis_text_1.xlsx
# Processing Document: sookim_text_2 vs sophiecurtis_text_1.xlsx
# Writing file
# Processing file 390/408: lynnetruss_text_1 vs lynnetruss_text_2.xlsx
# Processing Document: lynnetruss_text_1 vs lynnetruss_text_2.xlsx
# Writing file
# Processing file 391/408: katrionamacgregor_text_2 vs katrionamacgregor_text_3.xlsx
# Processing Document: katrionamacgregor_text_2 vs katrionamacgregor_text_3.xlsx
# Writing file
# Processing file 392/408: nickhoult_text_2 vs nicksquires_text_1.xlsx
# Processing Document: nickhoult_text_2 vs nicksquires_text_1.xlsx
# Writing file
# Processing file 393/408: janetdaley_text_1 vs jasonburt_text_3.xlsx
# Processing Document: janetdaley_text_1 vs jasonburt_text_3.xlsx
# Writing file
# Processing file 394/408: lauradonnelly_text_2 vs lauradonnelly_text_1.xlsx
# Processing Document: lauradonnelly_text_2 vs lauradonnelly_text_1.xlsx
# Writing file
# Processing file 395/408: neilmccormick_text_1 vs neilmidgley_text_1.xlsx
# Processing Document: neilmccormick_text_1 vs neilmidgley_text_1.xlsx
# Writing file
# Processing file 396/408: rogerbootle_text_1 vs rosaprince_text_1.xlsx
# Processing Document: rogerbootle_text_1 vs rosaprince_text_1.xlsx
# Writing file
# Processing file 397/408: oliverpickup_text_3 vs oliverpritchett_text_1.xlsx
# Processing Document: oliverpickup_text_3 vs oliverpritchett_text_1.xlsx
# Writing file
# Processing file 398/408: jennymccartney_text_2 vs jennymccartney_text_1.xlsx
# Processing Document: jennymccartney_text_2 vs jennymccartney_text_1.xlsx
# Writing file
# Processing file 399/408: philipallen_text_2 vs philipjohnston_text_2.xlsx
# Processing Document: philipallen_text_2 vs philipjohnston_text_2.xlsx
# Writing file
# Processing file 400/408: jamesquinn_text_3 vs jamesquinn_text_1.xlsx
# Processing Document: jamesquinn_text_3 vs jamesquinn_text_1.xlsx
# Writing file
# Processing file 401/408: paulhayward_text_3 vs paulhayward_text_2.xlsx
# Processing Document: paulhayward_text_3 vs paulhayward_text_2.xlsx
# Writing file
# Processing file 402/408: tomhoggins_text_2 vs tomhoggins_text_1.xlsx
# Processing Document: tomhoggins_text_2 vs tomhoggins_text_1.xlsx
# Writing file
# Processing file 403/408: terrywogan_text_1 vs terrywogan_text_2.xlsx
# Processing Document: terrywogan_text_1 vs terrywogan_text_2.xlsx
# Writing file
# Processing file 404/408: stevenswinford_text_2 vs stevieparle_text_2.xlsx
# Processing Document: stevenswinford_text_2 vs stevieparle_text_2.xlsx
# Writing file
# Processing file 405/408: tomrowley_text_3 vs tomstevenson_text_3.xlsx
# Processing Document: tomrowley_text_3 vs tomstevenson_text_3.xlsx
# Writing file
# Processing file 406/408: sarahcrompton_text_3 vs sarahcrompton_text_2.xlsx
# Processing Document: sarahcrompton_text_3 vs sarahcrompton_text_2.xlsx
# Writing file
# Processing file 407/408: oliverduggan_text_2 vs oliverduggan_text_1.xlsx
# Processing Document: oliverduggan_text_2 vs oliverduggan_text_1.xlsx
# Writing file
# Processing file 408/408: joanbakewell_text_2 vs joanbakewell_text_1.xlsx
# Processing Document: joanbakewell_text_2 vs joanbakewell_text_1.xlsx
# Writing file
#
# All files complete ✓
#
# Skipping save because no result_save_loc was provided.
# Working on the TripAdvisor corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/test/TripAdvisor/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/test/TripAdvisor/ModernBERT-large/gpt2 results/raw
# Working on the Wiki corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Wiki/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/test/Wiki/ModernBERT-large/gpt2 results/raw
# Working on training data
# Working on the ACL corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/ACL/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/ACL/ModernBERT-large/gpt2 results/raw
# Working on the Enron corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/Enron/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/Enron/ModernBERT-large/gpt2 results/raw
# Working on the Perverted Justice corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/Perverted Justice/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/Perverted Justice/ModernBERT-large/gpt2 results/raw
# Working on the StackExchange corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/StackExchange/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/StackExchange/ModernBERT-large/gpt2 results/raw
# Working on the The Telegraph corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/The Telegraph/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/The Telegraph/ModernBERT-large/gpt2 results/raw
# Working on the TripAdvisor corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/TripAdvisor/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/TripAdvisor/ModernBERT-large/gpt2 results/raw
# Working on the Wiki corpus
# Working on the ModernBERT-base paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/Wiki/ModernBERT-base/gpt2 results/raw
# Working on the ModernBERT-large paraphrasing model
# Working on the gpt2 scoring model
# Skipping (missing): /Volumes/BCross/av_datasets_experiments/ngram_masking/training/Wiki/ModernBERT-large/gpt2 results/raw
