# %%
import ast
import os
import glob

from pathlib import Path

import numpy as np
import pandas as pd

# %%
def create_results_doc_pipeline(doc_loc, write_excel=True, save_dir=None, phrase_loc=None):
    """Pipeline to manually get the results from a document"""
    
    doc_name = os.path.basename(doc_loc)
    
    print(f"Processing Document: {doc_name}")
    # Read the sheets as dataframes
    docs = pd.read_excel(doc_loc, sheet_name="docs")
    known = pd.read_excel(doc_loc, sheet_name="known")
    unknown = pd.read_excel(doc_loc, sheet_name="unknown")
    no_context = pd.read_excel(doc_loc, sheet_name="no context")
    metadata = pd.read_excel(doc_loc, sheet_name="metadata")
    
    # Get phrases to keep
    if phrase_loc:
        phrase_list = pd.read_excel(phrase_loc)
        phrases_to_keep = phrase_list[phrase_list['keep_phrase'] == 1].copy()

        # Convert the stringified tuples into actual tuples, then into lists
        phrases_to_keep['tokens'] = phrases_to_keep['tokens'].apply(lambda x: list(ast.literal_eval(x)) if isinstance(x, str) else list(x))
        phrases_to_keep = phrases_to_keep[['phrase']]
        
        reference_phrases = no_context[no_context['phrase_type'] == 'reference'].copy()

        # Perform the merge using the tuple-based key
        merged_phrases = pd.merge(reference_phrases, phrases_to_keep, on='phrase', how='inner')
        merged_phrases = merged_phrases[['phrase_num']]

        no_context = pd.merge(no_context, merged_phrases, on='phrase_num', how='inner')
        known = pd.merge(known, merged_phrases, on='phrase_num', how='inner')
        unknown= pd.merge(unknown, merged_phrases, on='phrase_num', how='inner')
        
    # Get the base LLR table
    cols = ['phrase_num', 'phrase_occurence', 'original_phrase']
    llr_base = (
        pd.concat([known[cols], unknown[cols]], ignore_index=True)
        .drop_duplicates()
        .sort_values(cols, ascending=[True, True, True])  # explicit
        .reset_index(drop=True)
    )
    
    # Now get the phrase statistics
    # 1) No context phrase stats
    no_context_phrase_stats = (
        no_context
        .assign(ref_log_prob = no_context['sum_log_probs']
                .where(no_context['phrase_type'].eq('reference')))
        .assign(ref_raw_prob=no_context['raw_prob']
            .where(no_context['phrase_type'].eq('reference')))
        .groupby('phrase_num', dropna=False)
        .agg(
            no_context_log_prob=('ref_log_prob', 'sum'),
            num_phrases=('phrase_num', 'size'),
            sum_raw_prob=('raw_prob', 'sum'),
            reference_prob=('ref_raw_prob', 'max')
        )
        .assign(
            phrases_kept=lambda d: d['num_phrases'],
            pmf_no_context=lambda d: d['reference_prob'].div(d['sum_raw_prob']),
            llr_no_context=lambda d: np.where(d['pmf_no_context'] > 0, -np.log10(d['pmf_no_context']), 0.0)
        )
        .drop(columns=['sum_raw_prob', 'reference_prob'])
    )

    # 2) Known phrase stats
    known_phrase_stats = (
        known
        .assign(ref_log_prob = known['sum_log_probs_phrase']
                .where(known['phrase_type'].eq('reference')))
        .assign(ref_raw_prob=known['raw_prob']
                .where(known['phrase_type'].eq('reference')))
        .groupby(['phrase_num', 'phrase_occurence'], dropna=False)
        .agg(
            known_log_prob=('ref_log_prob', 'sum'),
            sum_raw_prob=('raw_prob', 'sum'),
            reference_prob=('ref_raw_prob', 'max')
        )
        .assign(
            pmf_known=lambda d: d['reference_prob'].div(d['sum_raw_prob']),
            llr_known=lambda d: np.where(d['pmf_known'] > 0, -np.log10(d['pmf_known']), 0.0)
        )
        .drop(columns=['sum_raw_prob', 'reference_prob'])
    )

    # 3) Unknown phrase stats
    unknown_phrase_stats = (
        unknown
        .assign(ref_log_prob = unknown['sum_log_probs_phrase']
                .where(unknown['phrase_type'].eq('reference')))
        .assign(ref_raw_prob=unknown['raw_prob']
                .where(unknown['phrase_type'].eq('reference')))
        .groupby(['phrase_num', 'phrase_occurence'], dropna=False)
        .agg(
            unknown_log_prob=('ref_log_prob', 'sum'),
            sum_raw_prob=('raw_prob', 'sum'),
            reference_prob=('ref_raw_prob', 'max')
        )
        .assign(
            pmf_unknown=lambda d: d['reference_prob'].div(d['sum_raw_prob']),
            llr_unknown=lambda d: np.where(d['pmf_unknown'] > 0, -np.log10(d['pmf_unknown']), 0.0)
        )
        .drop(columns=['sum_raw_prob', 'reference_prob'])
    )
    
    # ---- START OF RANK TEST ---- #
    # Rank all phrases including the reference phrase
    unknown['rank_including_ref'] = (
        unknown
        .groupby(['phrase_num', 'phrase_occurence'])['sum_log_probs_phrase']
        .rank(ascending=False, method='first')   # or method='dense' if you prefer
    )

    # reference_log_probs: from the 'reference' row
    ref = (
        unknown[unknown['phrase_type'] == 'reference']
        .groupby(['phrase_num', 'phrase_occurence'])['sum_log_probs_phrase']
        .first()                 # or .iloc[0] via .agg('first')
        .rename('reference_log_probs')
    )

    # max_log_probs: from the top-ranked row (rank_including_ref == 1)
    top = (
        unknown[unknown['rank_including_ref'] == 1]
        .groupby(['phrase_num', 'phrase_occurence'])['sum_log_probs_phrase']
        .first()
        .rename('max_log_probs')
    )

    # combine into one dataframe
    agg_df = (
        pd.concat([ref, top], axis=1)
        .reset_index()
    )

    # difference
    agg_df['unknown_ref_vs_top_rank'] = agg_df['reference_log_probs'] - agg_df['max_log_probs']

    agg_df = agg_df.drop(columns=['reference_log_probs', 'max_log_probs']).reset_index()
    
    # ---- END OF RANK TEST ---- #

    # ---- START OF REF vs BEST-OF-REST (rank 0 vs rank 1) ---- #

    keys = ['phrase_num', 'phrase_occurence']
    
    ref = (
        unknown[unknown['rank'] == 0]
        .groupby(keys, dropna=False)['sum_log_probs_phrase']
        .first()
        .rename('ref_logp')
    )

    best_rest = (
        unknown[unknown['rank'] == 1]
        .groupby(keys, dropna=False)['sum_log_probs_phrase']
        .first()
        .rename('best_rest_logp')
    )

    agg_df_ref_vs_best = (
        pd.concat([ref, best_rest], axis=1)
        .reset_index()
    )

    # LLR(ref vs best alternative)
    agg_df_ref_vs_best['unknown_ref_vs_best_rest'] = agg_df_ref_vs_best['ref_logp'] - agg_df_ref_vs_best['best_rest_logp']

    agg_df_ref_vs_best = agg_df_ref_vs_best.drop(columns=['ref_logp', 'best_rest_logp'])

    # ---- END OF REF vs BEST-OF-REST ---- #
    
    # Create final LLR table
    LLR = (
        llr_base
        .assign(
            phrase_num=llr_base['phrase_num'].astype('string'),
            phrase_occurence=pd.to_numeric(llr_base['phrase_occurence'], errors='coerce').astype('Int64')
        )
        .merge(no_context_phrase_stats, on='phrase_num', how='left')
        .merge(known_phrase_stats, on=['phrase_num','phrase_occurence'], how='left')
        .merge(unknown_phrase_stats, on=['phrase_num','phrase_occurence'], how='left')
        .merge(agg_df, on=['phrase_num','phrase_occurence'], how='left')
        .merge(agg_df_ref_vs_best, on=['phrase_num','phrase_occurence'], how='left')
    )
    LLR['known_vs_no_context_log_prob'] = LLR['known_log_prob'] - LLR['no_context_log_prob'] 
    LLR['unknown_vs_no_context_log_prob'] = LLR['unknown_log_prob'] - LLR['no_context_log_prob'] 

    LLR = LLR[['phrase_num', 'phrase_occurence', 'original_phrase', 'num_phrases', 'phrases_kept', 'no_context_log_prob',
               'known_log_prob', 'unknown_log_prob', 'known_vs_no_context_log_prob', 'unknown_vs_no_context_log_prob',
               'pmf_no_context', 'pmf_known', 'pmf_unknown', 'llr_no_context', 'llr_known',
               'llr_unknown', 'unknown_ref_vs_top_rank', 'unknown_ref_vs_best_rest']]
    
    # Summarise the LLR table for the metadata
    LLR_summary = pd.DataFrame([{
        'num_phrases': LLR['phrase_num'].nunique(),
        'phrases_kept': LLR.loc[LLR['phrases_kept'] > 0, 'phrase_num'].nunique(),
        'known_log_prob': LLR['known_log_prob'].sum(skipna=True),
        'unknown_log_prob': LLR['unknown_log_prob'].sum(skipna=True),
        'llr_no_context': LLR['llr_no_context'].sum(skipna=True),
        'llr_known': LLR['llr_known'].sum(skipna=True),
        'llr_unknown': LLR['llr_unknown'].sum(skipna=True),
        'llr_unknown_vs_top_rank': LLR['unknown_ref_vs_top_rank'].sum(skipna=True),
        'unknown_ref_vs_best_rest': LLR['unknown_ref_vs_best_rest'].sum(skipna=True)
    }])

    LLR_summary = LLR_summary.assign(
        normalised_llr_no_context=lambda d: d['llr_no_context'] / d['phrases_kept'],
        normalised_llr_known=lambda d: d['llr_known'] / d['phrases_kept'],
        normalised_llr_unknown=lambda d: d['llr_unknown'] / d['phrases_kept']
    )
    
    # Create final metadata table
    # 1. Drop any overlapping columns in metadata
    overlapping_cols = LLR_summary.columns.intersection(metadata.columns)
    metadata_final = metadata.drop(columns=overlapping_cols, errors='ignore')

    # 2. Concatenate new values
    metadata_final = pd.concat([metadata_final, LLR_summary], axis=1)
    
    if write_excel:
        
        print("Writing file")
        path = Path(save_dir + '/' + doc_name)
        
        # Choose writer mode safely
        writer_mode = "a" if path.exists() else "w"
        writer_kwargs = {"engine": "openpyxl", "mode": writer_mode}
        if writer_mode == "a":
            writer_kwargs["if_sheet_exists"] = "replace"  # only valid in append mode
        

        with pd.ExcelWriter(path, **writer_kwargs) as writer:
            # Write sheets
            docs.to_excel(writer, index=False, sheet_name="docs")
            known.to_excel(writer, index=False, sheet_name="known")
            unknown.to_excel(writer, index=False, sheet_name="unknown")
            no_context.to_excel(writer, index=False, sheet_name="no context")
            LLR.to_excel(writer, index=False, sheet_name="LLR")
            metadata_final.to_excel(writer, index=False, sheet_name="metadata")
            
            # wb = writer.book
            # wb._sheets = ["docs", "metadata", "no context", "known", "unknown", "LLR"]
    
    return metadata_final

# %%
def process_directory(
    read_dir,
    save_dir,
    result_save_loc=None,   # optional now
    phrase_loc="/Volumes/BCross/paraphrase examples slurm/wiki-phrase-list-reviewed.xlsx"
):

    print(f"Reading from: {read_dir}")
    print(f"Saving processed files to: {save_dir}")
    
    if result_save_loc:
        print(f"Final combined output: {result_save_loc}\n")
    else:
        print("No result_save_loc provided → combined file will NOT be saved.\n")

    os.makedirs(save_dir, exist_ok=True)

    # If result_save_loc exists, do not overwrite
    if result_save_loc and os.path.exists(result_save_loc):
        print(f"Output already exists: {result_save_loc}. Exiting.")
        return

    # Read all Excel files
    xlsx_files = glob.glob(os.path.join(read_dir, "*.xlsx"))
    print(f"Found {len(xlsx_files)} files\n")

    all_metadata = []

    for i, file_path in enumerate(xlsx_files, start=1):
        print(f"Processing file {i}/{len(xlsx_files)}: {os.path.basename(file_path)}")

        try:
            metadata = create_results_doc_pipeline(
                file_path,
                write_excel=True,
                save_dir=save_dir,
                phrase_loc=phrase_loc
            )
            all_metadata.append(metadata)

        except Exception as e:
            print(f"❌ Failed to process {file_path}\nError: {e}\n")
            continue

    # Combine metadata
    if all_metadata:
        full_metadata = pd.concat(all_metadata, ignore_index=True)
    else:
        full_metadata = pd.DataFrame()

    # Sort if index exists
    if "index" in full_metadata.columns:
        full_metadata = full_metadata.sort_values(by="index").reset_index(drop=True)

    print("\nAll files complete ✓")
    
    # Save if a path was provided
    if result_save_loc:
        full_metadata.to_excel(result_save_loc, index=False)
        print(f"\nCombined results saved to: {result_save_loc}")
    else:
        print("\nSkipping save because no result_save_loc was provided.")

        return full_metadata  # return result in all cases

# %%
base_loc = '/Volumes/BCross/paraphrase examples slurm'
data_loc = f"{base_loc}/Wiki-Test"

# For Qwen
# read_dir = f'{data_loc}/raw'

# For everything else
read_dir = f'{data_loc}/ModernBERT-large/gpt2 results/raw'
save_dir = f'{data_loc}/ModernBERT-large/gpt2 results/filtered_inc_rank_v3'
result_save_loc = f"{data_loc}/ModernBERT-base/results.xlsx"
phrase_loc = f"{base_loc}/wiki-phrase-list-reviewed.xlsx"

process_directory(
    read_dir=read_dir,
    save_dir=save_dir,
    # result_save_loc=result_save_loc,
    phrase_loc=phrase_loc)
# Out:
# Reading from: /Volumes/BCross/paraphrase examples slurm/Wiki-Test/ModernBERT-large/gpt2 results/raw
# Saving processed files to: /Volumes/BCross/paraphrase examples slurm/Wiki-Test/ModernBERT-large/gpt2 results/filtered_inc_rank_v3
# No result_save_loc provided → combined file will NOT be saved.
#
# Found 616 files
#
# Processing file 1/616: legolas2186_text_2 vs legolas2186_text_3.xlsx
# Processing Document: legolas2186_text_2 vs legolas2186_text_3.xlsx
# Writing file
# Processing file 2/616: livelikemusic_text_5 vs livelikemusic_text_3.xlsx
# Processing Document: livelikemusic_text_5 vs livelikemusic_text_3.xlsx
# Writing file
# Processing file 3/616: rjecina_text_1 vs rjecina_text_11.xlsx
# Processing Document: rjecina_text_1 vs rjecina_text_11.xlsx
# Writing file
# Processing file 4/616: notpietru_text_1 vs obamafan70_text_5.xlsx
# Processing Document: notpietru_text_1 vs obamafan70_text_5.xlsx
# Writing file
# Processing file 5/616: obamafan70_text_3 vs orangemarlin_text_4.xlsx
# Processing Document: obamafan70_text_3 vs orangemarlin_text_4.xlsx
# Writing file
# Processing file 6/616: nil_einne_text_11 vs nirvana888_text_4.xlsx
# Processing Document: nil_einne_text_11 vs nirvana888_text_4.xlsx
# Writing file
# Processing file 7/616: o_fenian_text_2 vs paul_siebert_text_12.xlsx
# Processing Document: o_fenian_text_2 vs paul_siebert_text_12.xlsx
# Writing file
# Processing file 8/616: l_tak_text_10 vs lear_21_text_3.xlsx
# Processing Document: l_tak_text_10 vs lear_21_text_3.xlsx
# Writing file
# Processing file 9/616: hootmag_text_1 vs iain99_text_5.xlsx
# Processing Document: hootmag_text_1 vs iain99_text_5.xlsx
# Writing file
# Processing file 10/616: livitup_text_3 vs machine_elf_1735_text_3.xlsx
# Processing Document: livitup_text_3 vs machine_elf_1735_text_3.xlsx
# Writing file
# Processing file 11/616: salierethefish_text_1 vs salierethefish_text_5.xlsx
# Processing Document: salierethefish_text_1 vs salierethefish_text_5.xlsx
# Writing file
# Processing file 12/616: vedant_text_1 vs vedant_text_4.xlsx
# Processing Document: vedant_text_1 vs vedant_text_4.xlsx
# Writing file
# Processing file 13/616: secret_of_success_text_4 vs sennen_goroshi_text_3.xlsx
# Processing Document: secret_of_success_text_4 vs sennen_goroshi_text_3.xlsx
# Writing file
# Processing file 14/616: irvine22_text_1 vs itub_text_4.xlsx
# Processing Document: irvine22_text_1 vs itub_text_4.xlsx
# Writing file
# Processing file 15/616: the_four_deuces_text_10 vs the_four_deuces_text_4.xlsx
# Processing Document: the_four_deuces_text_10 vs the_four_deuces_text_4.xlsx
# Writing file
# Processing file 16/616: srisuren_text_12 vs srisuren_text_10.xlsx
# Processing Document: srisuren_text_12 vs srisuren_text_10.xlsx
# Writing file
# Processing file 17/616: iain99_text_3 vs iain99_text_5.xlsx
# Processing Document: iain99_text_3 vs iain99_text_5.xlsx
# Writing file
# Processing file 18/616: thekohser_text_10 vs theserialcomma_text_5.xlsx
# Processing Document: thekohser_text_10 vs theserialcomma_text_5.xlsx
# Writing file
# Processing file 19/616: nocal100_text_2 vs nocal100_text_5.xlsx
# Processing Document: nocal100_text_2 vs nocal100_text_5.xlsx
# Writing file
# Processing file 20/616: tvoz_text_11 vs tvoz_text_1.xlsx
# Processing Document: tvoz_text_11 vs tvoz_text_1.xlsx
# Writing file
# Processing file 21/616: kblott_text_5 vs killerchihuahua_text_3.xlsx
# Processing Document: kblott_text_5 vs killerchihuahua_text_3.xlsx
# Writing file
# Processing file 22/616: williamh_text_4 vs williamh_text_1.xlsx
# Processing Document: williamh_text_4 vs williamh_text_1.xlsx
# Writing file
# Processing file 23/616: jim_hardie_text_1 vs jmrh6_text_1.xlsx
# Processing Document: jim_hardie_text_1 vs jmrh6_text_1.xlsx
# Writing file
# Processing file 24/616: wiki_guy_16_text_6 vs wiki_guy_16_text_1.xlsx
# Processing Document: wiki_guy_16_text_6 vs wiki_guy_16_text_1.xlsx
# Writing file
# Processing file 25/616: peter_james_text_1 vs peter_james_text_4.xlsx
# Processing Document: peter_james_text_1 vs peter_james_text_4.xlsx
# Writing file
# Processing file 26/616: richard_daft_text_3 vs richard_daft_text_4.xlsx
# Processing Document: richard_daft_text_3 vs richard_daft_text_4.xlsx
# Writing file
# Processing file 27/616: intothefire_text_2 vs intothefire_text_12.xlsx
# Processing Document: intothefire_text_2 vs intothefire_text_12.xlsx
# Writing file
# Processing file 28/616: johnuniq_text_11 vs johnuniq_text_10.xlsx
# Processing Document: johnuniq_text_11 vs johnuniq_text_10.xlsx
# Writing file
# Processing file 29/616: snowded_text_12 vs soapfan2013_text_2.xlsx
# Processing Document: snowded_text_12 vs soapfan2013_text_2.xlsx
# Writing file
# Processing file 30/616: yoenit_text_1 vs zjarrirrethues_text_2.xlsx
# Processing Document: yoenit_text_1 vs zjarrirrethues_text_2.xlsx
# Writing file
# Processing file 31/616: machine_elf_1735_text_2 vs machine_elf_1735_text_3.xlsx
# Processing Document: machine_elf_1735_text_2 vs machine_elf_1735_text_3.xlsx
# Writing file
# Processing file 32/616: kblott_text_3 vs killerchihuahua_text_3.xlsx
# Processing Document: kblott_text_3 vs killerchihuahua_text_3.xlsx
# Writing file
# Processing file 33/616: scheinwerfermann_text_12 vs scheinwerfermann_text_10.xlsx
# Processing Document: scheinwerfermann_text_12 vs scheinwerfermann_text_10.xlsx
# Writing file
# Processing file 34/616: honestopl_text_5 vs hootmag_text_13.xlsx
# Processing Document: honestopl_text_5 vs hootmag_text_13.xlsx
# Writing file
# Processing file 35/616: thekohser_text_1 vs thekohser_text_11.xlsx
# Processing Document: thekohser_text_1 vs thekohser_text_11.xlsx
# Writing file
# Processing file 36/616: media_anthro_text_3 vs meowy_text_11.xlsx
# Processing Document: media_anthro_text_3 vs meowy_text_11.xlsx
# Writing file
# Processing file 37/616: paul_siebert_text_11 vs petersymonds_text_3.xlsx
# Processing Document: paul_siebert_text_11 vs petersymonds_text_3.xlsx
# Writing file
# Processing file 38/616: magog_the_ogre_text_3 vs magog_the_ogre_text_4.xlsx
# Processing Document: magog_the_ogre_text_3 vs magog_the_ogre_text_4.xlsx
# Writing file
# Processing file 39/616: njgw_text_2 vs njgw_text_5.xlsx
# Processing Document: njgw_text_2 vs njgw_text_5.xlsx
# Writing file
# Processing file 40/616: jbmurray_text_4 vs jbmurray_text_3.xlsx
# Processing Document: jbmurray_text_4 vs jbmurray_text_3.xlsx
# Writing file
# Processing file 41/616: volunteer_marek_text_10 vs vr_text_3.xlsx
# Processing Document: volunteer_marek_text_10 vs vr_text_3.xlsx
# Writing file
# Processing file 42/616: nigel_ish_text_1 vs nigel_ish_text_4.xlsx
# Processing Document: nigel_ish_text_1 vs nigel_ish_text_4.xlsx
# Writing file
# Processing file 43/616: zjarrirrethues_text_4 vs 142_196_88_228_text_2.xlsx
# Processing Document: zjarrirrethues_text_4 vs 142_196_88_228_text_2.xlsx
# Writing file
# Processing file 44/616: sgrayban_text_2 vs simoncursitor_text_4.xlsx
# Processing Document: sgrayban_text_2 vs simoncursitor_text_4.xlsx
# Writing file
# Processing file 45/616: u21980_text_4 vs updown_text_3.xlsx
# Processing Document: u21980_text_4 vs updown_text_3.xlsx
# Writing file
# Processing file 46/616: jim_hardie_text_3 vs jim_hardie_text_2.xlsx
# Processing Document: jim_hardie_text_3 vs jim_hardie_text_2.xlsx
# Writing file
# Processing file 47/616: tijfo098_text_3 vs tijfo098_text_2.xlsx
# Processing Document: tijfo098_text_3 vs tijfo098_text_2.xlsx
# Writing file
# Processing file 48/616: stephenbuxton_text_1 vs stillstanding_247_text_5.xlsx
# Processing Document: stephenbuxton_text_1 vs stillstanding_247_text_5.xlsx
# Writing file
# Processing file 49/616: ledenierhomme_text_2 vs ledenierhomme_text_3.xlsx
# Processing Document: ledenierhomme_text_2 vs ledenierhomme_text_3.xlsx
# Writing file
# Processing file 50/616: njgw_text_4 vs nocal100_text_5.xlsx
# Processing Document: njgw_text_4 vs nocal100_text_5.xlsx
# Writing file
# Processing file 51/616: icarus3_text_2 vs intangible_text_2.xlsx
# Processing Document: icarus3_text_2 vs intangible_text_2.xlsx
# Writing file
# Processing file 52/616: kashmiri_text_2 vs kashmiri_text_3.xlsx
# Processing Document: kashmiri_text_2 vs kashmiri_text_3.xlsx
# Writing file
# Processing file 53/616: tijfo098_text_5 vs tijfo098_text_2.xlsx
# Processing Document: tijfo098_text_5 vs tijfo098_text_2.xlsx
# Writing file
# Processing file 54/616: updown_text_1 vs updown_text_3.xlsx
# Processing Document: updown_text_1 vs updown_text_3.xlsx
# Writing file
# Processing file 55/616: pinkampersand_text_3 vs pinkampersand_text_4.xlsx
# Processing Document: pinkampersand_text_3 vs pinkampersand_text_4.xlsx
# Writing file
# Processing file 56/616: tintin1107_text_3 vs tintin1107_text_5.xlsx
# Processing Document: tintin1107_text_3 vs tintin1107_text_5.xlsx
# Writing file
# Processing file 57/616: obamafan70_text_4 vs orangemarlin_text_4.xlsx
# Processing Document: obamafan70_text_4 vs orangemarlin_text_4.xlsx
# Writing file
# Processing file 58/616: vedant_text_5 vs viewfinder_text_4.xlsx
# Processing Document: vedant_text_5 vs viewfinder_text_4.xlsx
# Writing file
# Processing file 59/616: mareklug_text_4 vs mareklug_text_5.xlsx
# Processing Document: mareklug_text_4 vs mareklug_text_5.xlsx
# Writing file
# Processing file 60/616: jc37_text_1 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing Document: jc37_text_1 vs jeffrey_vernon_merkey_text_10.xlsx
# Writing file
# Processing file 61/616: xtv_text_5 vs xtv_text_4.xlsx
# Processing Document: xtv_text_5 vs xtv_text_4.xlsx
# Writing file
# Processing file 62/616: icarus3_text_2 vs icarus3_text_4.xlsx
# Processing Document: icarus3_text_2 vs icarus3_text_4.xlsx
# Writing file
# Processing file 63/616: zjarrirrethues_text_5 vs 142_196_88_228_text_2.xlsx
# Processing Document: zjarrirrethues_text_5 vs 142_196_88_228_text_2.xlsx
# Writing file
# Processing file 64/616: livitup_text_4 vs machine_elf_1735_text_3.xlsx
# Processing Document: livitup_text_4 vs machine_elf_1735_text_3.xlsx
# Writing file
# Processing file 65/616: spaully_text_5 vs spaully_text_3.xlsx
# Processing Document: spaully_text_5 vs spaully_text_3.xlsx
# Writing file
# Processing file 66/616: vsevolodkrolikov_text_13 vs vsevolodkrolikov_text_1.xlsx
# Processing Document: vsevolodkrolikov_text_13 vs vsevolodkrolikov_text_1.xlsx
# Writing file
# Processing file 67/616: jasper_deng_text_1 vs jbmurray_text_3.xlsx
# Processing Document: jasper_deng_text_1 vs jbmurray_text_3.xlsx
# Writing file
# Processing file 68/616: secret_of_success_text_4 vs secret_of_success_text_3.xlsx
# Processing Document: secret_of_success_text_4 vs secret_of_success_text_3.xlsx
# Writing file
# Processing file 69/616: killerchihuahua_text_11 vs kudzu1_text_1.xlsx
# Processing Document: killerchihuahua_text_11 vs kudzu1_text_1.xlsx
# Writing file
# Processing file 70/616: icarus3_text_1 vs icarus3_text_4.xlsx
# Processing Document: icarus3_text_1 vs icarus3_text_4.xlsx
# Writing file
# Processing file 71/616: ledenierhomme_text_1 vs legolas2186_text_3.xlsx
# Processing Document: ledenierhomme_text_1 vs legolas2186_text_3.xlsx
# Writing file
# Processing file 72/616: tijfo098_text_3 vs tintin1107_text_5.xlsx
# Processing Document: tijfo098_text_3 vs tintin1107_text_5.xlsx
# Writing file
# Processing file 73/616: salierethefish_text_2 vs salierethefish_text_5.xlsx
# Processing Document: salierethefish_text_2 vs salierethefish_text_5.xlsx
# Writing file
# Processing file 74/616: jerekrischel_text_12 vs jerekrischel_text_13.xlsx
# Processing Document: jerekrischel_text_12 vs jerekrischel_text_13.xlsx
# Writing file
# Processing file 75/616: mathsci_text_2 vs maunus_text_1.xlsx
# Processing Document: mathsci_text_2 vs maunus_text_1.xlsx
# Writing file
# Processing file 76/616: phead128_text_4 vs pinkampersand_text_4.xlsx
# Processing Document: phead128_text_4 vs pinkampersand_text_4.xlsx
# Writing file
# Processing file 77/616: soapfan2013_text_1 vs spaully_text_3.xlsx
# Processing Document: soapfan2013_text_1 vs spaully_text_3.xlsx
# Writing file
# Processing file 78/616: nil_einne_text_12 vs nil_einne_text_10.xlsx
# Processing Document: nil_einne_text_12 vs nil_einne_text_10.xlsx
# Writing file
# Processing file 79/616: jasper_deng_text_2 vs jasper_deng_text_4.xlsx
# Processing Document: jasper_deng_text_2 vs jasper_deng_text_4.xlsx
# Writing file
# Processing file 80/616: kashmiri_text_2 vs kblott_text_1.xlsx
# Processing Document: kashmiri_text_2 vs kblott_text_1.xlsx
# Writing file
# Processing file 81/616: magog_the_ogre_text_1 vs magog_the_ogre_text_4.xlsx
# Processing Document: magog_the_ogre_text_1 vs magog_the_ogre_text_4.xlsx
# Writing file
# Processing file 82/616: nirvana888_text_1 vs njgw_text_5.xlsx
# Processing Document: nirvana888_text_1 vs njgw_text_5.xlsx
# Writing file
# Processing file 83/616: phead128_text_4 vs phead128_text_2.xlsx
# Processing Document: phead128_text_4 vs phead128_text_2.xlsx
# Writing file
# Processing file 84/616: sks2k6_text_4 vs snowded_text_1.xlsx
# Processing Document: sks2k6_text_4 vs snowded_text_1.xlsx
# Writing file
# Processing file 85/616: soapfan2013_text_4 vs soapfan2013_text_2.xlsx
# Processing Document: soapfan2013_text_4 vs soapfan2013_text_2.xlsx
# Writing file
# Processing file 86/616: nableezy_text_1 vs nableezy_text_2.xlsx
# Processing Document: nableezy_text_1 vs nableezy_text_2.xlsx
# Writing file
# Processing file 87/616: pro_lick_text_3 vs pro_lick_text_1.xlsx
# Processing Document: pro_lick_text_3 vs pro_lick_text_1.xlsx
# Writing file
# Processing file 88/616: secret_of_success_text_5 vs secret_of_success_text_3.xlsx
# Processing Document: secret_of_success_text_5 vs secret_of_success_text_3.xlsx
# Writing file
# Processing file 89/616: orangemarlin_text_1 vs orangemarlin_text_4.xlsx
# Processing Document: orangemarlin_text_1 vs orangemarlin_text_4.xlsx
# Writing file
# Processing file 90/616: notpietru_text_1 vs notpietru_text_2.xlsx
# Processing Document: notpietru_text_1 vs notpietru_text_2.xlsx
# Writing file
# Processing file 91/616: jmrh6_text_2 vs jmrh6_text_1.xlsx
# Processing Document: jmrh6_text_2 vs jmrh6_text_1.xlsx
# Writing file
# Processing file 92/616: paul_siebert_text_10 vs paul_siebert_text_12.xlsx
# Processing Document: paul_siebert_text_10 vs paul_siebert_text_12.xlsx
# Writing file
# Processing file 93/616: meowy_text_12 vs meowy_text_11.xlsx
# Processing Document: meowy_text_12 vs meowy_text_11.xlsx
# Writing file
# Processing file 94/616: obamafan70_text_4 vs obamafan70_text_5.xlsx
# Processing Document: obamafan70_text_4 vs obamafan70_text_5.xlsx
# Writing file
# Processing file 95/616: peter_james_text_3 vs peter_james_text_4.xlsx
# Processing Document: peter_james_text_3 vs peter_james_text_4.xlsx
# Writing file
# Processing file 96/616: sally_season_text_11 vs sally_season_text_1.xlsx
# Processing Document: sally_season_text_11 vs sally_season_text_1.xlsx
# Writing file
# Processing file 97/616: itub_text_2 vs itub_text_4.xlsx
# Processing Document: itub_text_2 vs itub_text_4.xlsx
# Writing file
# Processing file 98/616: intangible_text_3 vs intothefire_text_12.xlsx
# Processing Document: intangible_text_3 vs intothefire_text_12.xlsx
# Writing file
# Processing file 99/616: phead128_text_5 vs phead128_text_2.xlsx
# Processing Document: phead128_text_5 vs phead128_text_2.xlsx
# Writing file
# Processing file 100/616: protonk_text_1 vs protonk_text_13.xlsx
# Processing Document: protonk_text_1 vs protonk_text_13.xlsx
# Writing file
# Processing file 101/616: salix_alba_text_4 vs salix_alba_text_3.xlsx
# Processing Document: salix_alba_text_4 vs salix_alba_text_3.xlsx
# Writing file
# Processing file 102/616: xtv_text_2 vs xtv_text_4.xlsx
# Processing Document: xtv_text_2 vs xtv_text_4.xlsx
# Writing file
# Processing file 103/616: sgrayban_text_4 vs simoncursitor_text_4.xlsx
# Processing Document: sgrayban_text_4 vs simoncursitor_text_4.xlsx
# Writing file
# Processing file 104/616: soapfan2013_text_4 vs spaully_text_3.xlsx
# Processing Document: soapfan2013_text_4 vs spaully_text_3.xlsx
# Writing file
# Processing file 105/616: jerryfriedman_text_2 vs jimharlow99_text_10.xlsx
# Processing Document: jerryfriedman_text_2 vs jimharlow99_text_10.xlsx
# Writing file
# Processing file 106/616: volunteer_marek_text_3 vs volunteer_marek_text_4.xlsx
# Processing Document: volunteer_marek_text_3 vs volunteer_marek_text_4.xlsx
# Writing file
# Processing file 107/616: wobble_text_10 vs xtv_text_4.xlsx
# Processing Document: wobble_text_10 vs xtv_text_4.xlsx
# Writing file
# Processing file 108/616: snowded_text_2 vs soapfan2013_text_2.xlsx
# Processing Document: snowded_text_2 vs soapfan2013_text_2.xlsx
# Writing file
# Processing file 109/616: zjarrirrethues_text_5 vs zjarrirrethues_text_2.xlsx
# Processing Document: zjarrirrethues_text_5 vs zjarrirrethues_text_2.xlsx
# Writing file
# Processing file 110/616: nocrowx_text_3 vs nocrowx_text_4.xlsx
# Processing Document: nocrowx_text_3 vs nocrowx_text_4.xlsx
# Writing file
# Processing file 111/616: viewfinder_text_1 vs volunteer_marek_text_4.xlsx
# Processing Document: viewfinder_text_1 vs volunteer_marek_text_4.xlsx
# Writing file
# Processing file 112/616: jeffrey_vernon_merkey_text_11 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing Document: jeffrey_vernon_merkey_text_11 vs jeffrey_vernon_merkey_text_10.xlsx
# Writing file
# Processing file 113/616: petersymonds_text_4 vs peter_james_text_4.xlsx
# Processing Document: petersymonds_text_4 vs peter_james_text_4.xlsx
# Writing file
# Processing file 114/616: honestopl_text_5 vs honestopl_text_1.xlsx
# Processing Document: honestopl_text_5 vs honestopl_text_1.xlsx
# Writing file
# Processing file 115/616: pro_lick_text_2 vs protonk_text_13.xlsx
# Processing Document: pro_lick_text_2 vs protonk_text_13.xlsx
# Writing file
# Processing file 116/616: vedant_text_2 vs viewfinder_text_4.xlsx
# Processing Document: vedant_text_2 vs viewfinder_text_4.xlsx
# Writing file
# Processing file 117/616: scheinwerfermann_text_11 vs scheinwerfermann_text_10.xlsx
# Processing Document: scheinwerfermann_text_11 vs scheinwerfermann_text_10.xlsx
# Writing file
# Processing file 118/616: jerekrischel_text_11 vs jerryfriedman_text_3.xlsx
# Processing Document: jerekrischel_text_11 vs jerryfriedman_text_3.xlsx
# Writing file
# Processing file 119/616: rolandr_text_1 vs salierethefish_text_5.xlsx
# Processing Document: rolandr_text_1 vs salierethefish_text_5.xlsx
# Writing file
# Processing file 120/616: kblott_text_3 vs kblott_text_1.xlsx
# Processing Document: kblott_text_3 vs kblott_text_1.xlsx
# Writing file
# Processing file 121/616: rolandr_text_1 vs rolandr_text_3.xlsx
# Processing Document: rolandr_text_1 vs rolandr_text_3.xlsx
# Writing file
# Processing file 122/616: salix_alba_text_4 vs sally_season_text_1.xlsx
# Processing Document: salix_alba_text_4 vs sally_season_text_1.xlsx
# Writing file
# Processing file 123/616: ottava_rima_text_16 vs ottava_rima_text_15.xlsx
# Processing Document: ottava_rima_text_16 vs ottava_rima_text_15.xlsx
# Writing file
# Processing file 124/616: kudzu1_text_5 vs kudzu1_text_1.xlsx
# Processing Document: kudzu1_text_5 vs kudzu1_text_1.xlsx
# Writing file
# Processing file 125/616: iain99_text_1 vs iain99_text_5.xlsx
# Processing Document: iain99_text_1 vs iain99_text_5.xlsx
# Writing file
# Processing file 126/616: scheinwerfermann_text_11 vs sean_hoyland_text_3.xlsx
# Processing Document: scheinwerfermann_text_11 vs sean_hoyland_text_3.xlsx
# Writing file
# Processing file 127/616: william_m_connolley_text_5 vs wobble_text_13.xlsx
# Processing Document: william_m_connolley_text_5 vs wobble_text_13.xlsx
# Writing file
# Processing file 128/616: paul_siebert_text_1 vs petersymonds_text_3.xlsx
# Processing Document: paul_siebert_text_1 vs petersymonds_text_3.xlsx
# Writing file
# Processing file 129/616: spitfire_text_3 vs spitfire_text_5.xlsx
# Processing Document: spitfire_text_3 vs spitfire_text_5.xlsx
# Writing file
# Processing file 130/616: paul_siebert_text_1 vs paul_siebert_text_12.xlsx
# Processing Document: paul_siebert_text_1 vs paul_siebert_text_12.xlsx
# Writing file
# Processing file 131/616: irvine22_text_4 vs itub_text_4.xlsx
# Processing Document: irvine22_text_4 vs itub_text_4.xlsx
# Writing file
# Processing file 132/616: simoncursitor_text_3 vs sks2k6_text_3.xlsx
# Processing Document: simoncursitor_text_3 vs sks2k6_text_3.xlsx
# Writing file
# Processing file 133/616: salix_alba_text_1 vs sally_season_text_1.xlsx
# Processing Document: salix_alba_text_1 vs sally_season_text_1.xlsx
# Writing file
# Processing file 134/616: sally_season_text_2 vs sally_season_text_1.xlsx
# Processing Document: sally_season_text_2 vs sally_season_text_1.xlsx
# Writing file
# Processing file 135/616: jéské_couriano_text_1 vs jéské_couriano_text_4.xlsx
# Processing Document: jéské_couriano_text_1 vs jéské_couriano_text_4.xlsx
# Writing file
# Processing file 136/616: nableezy_text_1 vs nathan_text_10.xlsx
# Processing Document: nableezy_text_1 vs nathan_text_10.xlsx
# Writing file
# Processing file 137/616: meowy_text_1 vs mezzomezzo_text_5.xlsx
# Processing Document: meowy_text_1 vs mezzomezzo_text_5.xlsx
# Writing file
# Processing file 138/616: tijfo098_text_5 vs tintin1107_text_5.xlsx
# Processing Document: tijfo098_text_5 vs tintin1107_text_5.xlsx
# Writing file
# Processing file 139/616: hootmag_text_10 vs iain99_text_5.xlsx
# Processing Document: hootmag_text_10 vs iain99_text_5.xlsx
# Writing file
# Processing file 140/616: machine_elf_1735_text_4 vs magog_the_ogre_text_4.xlsx
# Processing Document: machine_elf_1735_text_4 vs magog_the_ogre_text_4.xlsx
# Writing file
# Processing file 141/616: protonk_text_1 vs ramdrake_text_5.xlsx
# Processing Document: protonk_text_1 vs ramdrake_text_5.xlsx
# Writing file
# Processing file 142/616: vr_text_1 vs vsevolodkrolikov_text_1.xlsx
# Processing Document: vr_text_1 vs vsevolodkrolikov_text_1.xlsx
# Writing file
# Processing file 143/616: tintin1107_text_3 vs tvoz_text_1.xlsx
# Processing Document: tintin1107_text_3 vs tvoz_text_1.xlsx
# Writing file
# Processing file 144/616: legolas2186_text_1 vs legolas2186_text_3.xlsx
# Processing Document: legolas2186_text_1 vs legolas2186_text_3.xlsx
# Writing file
# Processing file 145/616: legolas2186_text_1 vs livelikemusic_text_3.xlsx
# Processing Document: legolas2186_text_1 vs livelikemusic_text_3.xlsx
# Writing file
# Processing file 146/616: iain99_text_2 vs iain99_text_5.xlsx
# Processing Document: iain99_text_2 vs iain99_text_5.xlsx
# Writing file
# Processing file 147/616: ivoshandor_text_4 vs jasper_deng_text_4.xlsx
# Processing Document: ivoshandor_text_4 vs jasper_deng_text_4.xlsx
# Writing file
# Processing file 148/616: orangemarlin_text_5 vs orangemarlin_text_4.xlsx
# Processing Document: orangemarlin_text_5 vs orangemarlin_text_4.xlsx
# Writing file
# Processing file 149/616: lear_21_text_2 vs ledenierhomme_text_3.xlsx
# Processing Document: lear_21_text_2 vs ledenierhomme_text_3.xlsx
# Writing file
# Processing file 150/616: jmrh6_text_3 vs johnuniq_text_10.xlsx
# Processing Document: jmrh6_text_3 vs johnuniq_text_10.xlsx
# Writing file
# Processing file 151/616: machine_elf_1735_text_5 vs machine_elf_1735_text_3.xlsx
# Processing Document: machine_elf_1735_text_5 vs machine_elf_1735_text_3.xlsx
# Writing file
# Processing file 152/616: mareklug_text_3 vs mareklug_text_5.xlsx
# Processing Document: mareklug_text_3 vs mareklug_text_5.xlsx
# Writing file
# Processing file 153/616: tintin1107_text_1 vs tvoz_text_1.xlsx
# Processing Document: tintin1107_text_1 vs tvoz_text_1.xlsx
# Writing file
# Processing file 154/616: viewfinder_text_1 vs viewfinder_text_4.xlsx
# Processing Document: viewfinder_text_1 vs viewfinder_text_4.xlsx
# Writing file
# Processing file 155/616: machine_elf_1735_text_2 vs magog_the_ogre_text_4.xlsx
# Processing Document: machine_elf_1735_text_2 vs magog_the_ogre_text_4.xlsx
# Writing file
# Processing file 156/616: machine_elf_1735_text_5 vs magog_the_ogre_text_4.xlsx
# Processing Document: machine_elf_1735_text_5 vs magog_the_ogre_text_4.xlsx
# Writing file
# Processing file 157/616: njgw_text_3 vs nocal100_text_5.xlsx
# Processing Document: njgw_text_3 vs nocal100_text_5.xlsx
# Writing file
# Processing file 158/616: marine_69_71_text_2 vs mathsci_text_10.xlsx
# Processing Document: marine_69_71_text_2 vs mathsci_text_10.xlsx
# Writing file
# Processing file 159/616: the_four_deuces_text_1 vs tijfo098_text_2.xlsx
# Processing Document: the_four_deuces_text_1 vs tijfo098_text_2.xlsx
# Writing file
# Processing file 160/616: richard_daft_text_3 vs rjecina_text_11.xlsx
# Processing Document: richard_daft_text_3 vs rjecina_text_11.xlsx
# Writing file
# Processing file 161/616: hootmag_text_10 vs hootmag_text_13.xlsx
# Processing Document: hootmag_text_10 vs hootmag_text_13.xlsx
# Writing file
# Processing file 162/616: jerryfriedman_text_1 vs jimharlow99_text_10.xlsx
# Processing Document: jerryfriedman_text_1 vs jimharlow99_text_10.xlsx
# Writing file
# Processing file 163/616: media_anthro_text_1 vs meowy_text_11.xlsx
# Processing Document: media_anthro_text_1 vs meowy_text_11.xlsx
# Writing file
# Processing file 164/616: stephenbuxton_text_5 vs stephenbuxton_text_3.xlsx
# Processing Document: stephenbuxton_text_5 vs stephenbuxton_text_3.xlsx
# Writing file
# Processing file 165/616: wobble_text_11 vs xtv_text_4.xlsx
# Processing Document: wobble_text_11 vs xtv_text_4.xlsx
# Writing file
# Processing file 166/616: rjecina_text_10 vs rolandr_text_3.xlsx
# Processing Document: rjecina_text_10 vs rolandr_text_3.xlsx
# Writing file
# Processing file 167/616: notpietru_text_5 vs notpietru_text_2.xlsx
# Processing Document: notpietru_text_5 vs notpietru_text_2.xlsx
# Writing file
# Processing file 168/616: orangemarlin_text_5 vs ottava_rima_text_15.xlsx
# Processing Document: orangemarlin_text_5 vs ottava_rima_text_15.xlsx
# Writing file
# Processing file 169/616: hodja_nasreddin_text_11 vs hodja_nasreddin_text_3.xlsx
# Processing Document: hodja_nasreddin_text_11 vs hodja_nasreddin_text_3.xlsx
# Writing file
# Processing file 170/616: sks2k6_text_5 vs snowded_text_1.xlsx
# Processing Document: sks2k6_text_5 vs snowded_text_1.xlsx
# Writing file
# Processing file 171/616: jeffrey_vernon_merkey_text_1 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing Document: jeffrey_vernon_merkey_text_1 vs jeffrey_vernon_merkey_text_10.xlsx
# Writing file
# Processing file 172/616: volunteer_marek_text_2 vs volunteer_marek_text_4.xlsx
# Processing Document: volunteer_marek_text_2 vs volunteer_marek_text_4.xlsx
# Writing file
# Processing file 173/616: jim_hardie_text_4 vs jmrh6_text_1.xlsx
# Processing Document: jim_hardie_text_4 vs jmrh6_text_1.xlsx
# Writing file
# Processing file 174/616: ledenierhomme_text_4 vs ledenierhomme_text_3.xlsx
# Processing Document: ledenierhomme_text_4 vs ledenierhomme_text_3.xlsx
# Writing file
# Processing file 175/616: njgw_text_2 vs nocal100_text_5.xlsx
# Processing Document: njgw_text_2 vs nocal100_text_5.xlsx
# Writing file
# Processing file 176/616: the_four_deuces_text_3 vs tijfo098_text_2.xlsx
# Processing Document: the_four_deuces_text_3 vs tijfo098_text_2.xlsx
# Writing file
# Processing file 177/616: meowy_text_1 vs meowy_text_11.xlsx
# Processing Document: meowy_text_1 vs meowy_text_11.xlsx
# Writing file
# Processing file 178/616: sgrayban_text_4 vs sgrayban_text_5.xlsx
# Processing Document: sgrayban_text_4 vs sgrayban_text_5.xlsx
# Writing file
# Processing file 179/616: ottava_rima_text_14 vs ottava_rima_text_15.xlsx
# Processing Document: ottava_rima_text_14 vs ottava_rima_text_15.xlsx
# Writing file
# Processing file 180/616: thekohser_text_10 vs thekohser_text_11.xlsx
# Processing Document: thekohser_text_10 vs thekohser_text_11.xlsx
# Writing file
# Processing file 181/616: salix_alba_text_2 vs salix_alba_text_3.xlsx
# Processing Document: salix_alba_text_2 vs salix_alba_text_3.xlsx
# Writing file
# Processing file 182/616: william_m_connolley_text_4 vs wobble_text_13.xlsx
# Processing Document: william_m_connolley_text_4 vs wobble_text_13.xlsx
# Writing file
# Processing file 183/616: rjecina_text_13 vs rolandr_text_3.xlsx
# Processing Document: rjecina_text_13 vs rolandr_text_3.xlsx
# Writing file
# Processing file 184/616: livelikemusic_text_4 vs livelikemusic_text_3.xlsx
# Processing Document: livelikemusic_text_4 vs livelikemusic_text_3.xlsx
# Writing file
# Processing file 185/616: nableezy_text_11 vs nathan_text_10.xlsx
# Processing Document: nableezy_text_11 vs nathan_text_10.xlsx
# Writing file
# Processing file 186/616: kashmiri_text_1 vs kblott_text_1.xlsx
# Processing Document: kashmiri_text_1 vs kblott_text_1.xlsx
# Writing file
# Processing file 187/616: tvoz_text_2 vs u21980_text_5.xlsx
# Processing Document: tvoz_text_2 vs u21980_text_5.xlsx
# Writing file
# Processing file 188/616: ivoshandor_text_5 vs ivoshandor_text_1.xlsx
# Processing Document: ivoshandor_text_5 vs ivoshandor_text_1.xlsx
# Writing file
# Processing file 189/616: sgrayban_text_3 vs simoncursitor_text_4.xlsx
# Processing Document: sgrayban_text_3 vs simoncursitor_text_4.xlsx
# Writing file
# Processing file 190/616: kblott_text_4 vs kblott_text_1.xlsx
# Processing Document: kblott_text_4 vs kblott_text_1.xlsx
# Writing file
# Processing file 191/616: pinkampersand_text_1 vs pro_lick_text_1.xlsx
# Processing Document: pinkampersand_text_1 vs pro_lick_text_1.xlsx
# Writing file
# Processing file 192/616: l_tak_text_2 vs lear_21_text_3.xlsx
# Processing Document: l_tak_text_2 vs lear_21_text_3.xlsx
# Writing file
# Processing file 193/616: nathan_text_2 vs nathan_text_10.xlsx
# Processing Document: nathan_text_2 vs nathan_text_10.xlsx
# Writing file
# Processing file 194/616: honestopl_text_4 vs hootmag_text_13.xlsx
# Processing Document: honestopl_text_4 vs hootmag_text_13.xlsx
# Writing file
# Processing file 195/616: legolas2186_text_4 vs livelikemusic_text_3.xlsx
# Processing Document: legolas2186_text_4 vs livelikemusic_text_3.xlsx
# Writing file
# Processing file 196/616: petersymonds_text_4 vs petersymonds_text_3.xlsx
# Processing Document: petersymonds_text_4 vs petersymonds_text_3.xlsx
# Writing file
# Processing file 197/616: stillstanding_247_text_4 vs stillstanding_247_text_5.xlsx
# Processing Document: stillstanding_247_text_4 vs stillstanding_247_text_5.xlsx
# Writing file
# Processing file 198/616: srisuren_text_12 vs stephenbuxton_text_3.xlsx
# Processing Document: srisuren_text_12 vs stephenbuxton_text_3.xlsx
# Writing file
# Processing file 199/616: t34ch_text_3 vs t34ch_text_4.xlsx
# Processing Document: t34ch_text_3 vs t34ch_text_4.xlsx
# Writing file
# Processing file 200/616: xtv_text_3 vs yoenit_text_2.xlsx
# Processing Document: xtv_text_3 vs yoenit_text_2.xlsx
# Writing file
# Processing file 201/616: nocal100_text_4 vs nocal100_text_5.xlsx
# Processing Document: nocal100_text_4 vs nocal100_text_5.xlsx
# Writing file
# Processing file 202/616: williamh_text_2 vs williamh_text_1.xlsx
# Processing Document: williamh_text_2 vs williamh_text_1.xlsx
# Writing file
# Processing file 203/616: swift_silent_text_4 vs t34ch_text_4.xlsx
# Processing Document: swift_silent_text_4 vs t34ch_text_4.xlsx
# Writing file
# Processing file 204/616: jwanders_text_1 vs jéské_couriano_text_4.xlsx
# Processing Document: jwanders_text_1 vs jéské_couriano_text_4.xlsx
# Writing file
# Processing file 205/616: soapfan2013_text_3 vs soapfan2013_text_2.xlsx
# Processing Document: soapfan2013_text_3 vs soapfan2013_text_2.xlsx
# Writing file
# Processing file 206/616: swift_silent_text_1 vs swift_silent_text_2.xlsx
# Processing Document: swift_silent_text_1 vs swift_silent_text_2.xlsx
# Writing file
# Processing file 207/616: xtv_text_3 vs xtv_text_4.xlsx
# Processing Document: xtv_text_3 vs xtv_text_4.xlsx
# Writing file
# Processing file 208/616: kblott_text_5 vs kblott_text_1.xlsx
# Processing Document: kblott_text_5 vs kblott_text_1.xlsx
# Writing file
# Processing file 209/616: l_tak_text_1 vs lear_21_text_3.xlsx
# Processing Document: l_tak_text_1 vs lear_21_text_3.xlsx
# Writing file
# Processing file 210/616: vedant_text_1 vs viewfinder_text_4.xlsx
# Processing Document: vedant_text_1 vs viewfinder_text_4.xlsx
# Writing file
# Processing file 211/616: orangemarlin_text_2 vs ottava_rima_text_15.xlsx
# Processing Document: orangemarlin_text_2 vs ottava_rima_text_15.xlsx
# Writing file
# Processing file 212/616: soapfan2013_text_1 vs soapfan2013_text_2.xlsx
# Processing Document: soapfan2013_text_1 vs soapfan2013_text_2.xlsx
# Writing file
# Processing file 213/616: o_fenian_text_1 vs o_fenian_text_4.xlsx
# Processing Document: o_fenian_text_1 vs o_fenian_text_4.xlsx
# Writing file
# Processing file 214/616: nil_einne_text_13 vs nil_einne_text_10.xlsx
# Processing Document: nil_einne_text_13 vs nil_einne_text_10.xlsx
# Writing file
# Processing file 215/616: peter_james_text_2 vs phead128_text_2.xlsx
# Processing Document: peter_james_text_2 vs phead128_text_2.xlsx
# Writing file
# Processing file 216/616: ottava_rima_text_1 vs ottava_rima_text_15.xlsx
# Processing Document: ottava_rima_text_1 vs ottava_rima_text_15.xlsx
# Writing file
# Processing file 217/616: peter_james_text_1 vs phead128_text_2.xlsx
# Processing Document: peter_james_text_1 vs phead128_text_2.xlsx
# Writing file
# Processing file 218/616: intothefire_text_10 vs intothefire_text_12.xlsx
# Processing Document: intothefire_text_10 vs intothefire_text_12.xlsx
# Writing file
# Processing file 219/616: livitup_text_1 vs machine_elf_1735_text_3.xlsx
# Processing Document: livitup_text_1 vs machine_elf_1735_text_3.xlsx
# Writing file
# Processing file 220/616: orangemarlin_text_1 vs ottava_rima_text_15.xlsx
# Processing Document: orangemarlin_text_1 vs ottava_rima_text_15.xlsx
# Writing file
# Processing file 221/616: sean_hoyland_text_2 vs sean_hoyland_text_3.xlsx
# Processing Document: sean_hoyland_text_2 vs sean_hoyland_text_3.xlsx
# Writing file
# Processing file 222/616: williamh_text_2 vs william_m_connolley_text_2.xlsx
# Processing Document: williamh_text_2 vs william_m_connolley_text_2.xlsx
# Writing file
# Processing file 223/616: jéské_couriano_text_1 vs kashmiri_text_3.xlsx
# Processing Document: jéské_couriano_text_1 vs kashmiri_text_3.xlsx
# Writing file
# Processing file 224/616: mangoe_text_10 vs mareklug_text_5.xlsx
# Processing Document: mangoe_text_10 vs mareklug_text_5.xlsx
# Writing file
# Processing file 225/616: pinkampersand_text_3 vs pro_lick_text_1.xlsx
# Processing Document: pinkampersand_text_3 vs pro_lick_text_1.xlsx
# Writing file
# Processing file 226/616: scheinwerfermann_text_13 vs sean_hoyland_text_3.xlsx
# Processing Document: scheinwerfermann_text_13 vs sean_hoyland_text_3.xlsx
# Writing file
# Processing file 227/616: ivoshandor_text_2 vs ivoshandor_text_1.xlsx
# Processing Document: ivoshandor_text_2 vs ivoshandor_text_1.xlsx
# Writing file
# Processing file 228/616: mareklug_text_1 vs marine_69_71_text_4.xlsx
# Processing Document: mareklug_text_1 vs marine_69_71_text_4.xlsx
# Writing file
# Processing file 229/616: vsevolodkrolikov_text_11 vs vsevolodkrolikov_text_1.xlsx
# Processing Document: vsevolodkrolikov_text_11 vs vsevolodkrolikov_text_1.xlsx
# Writing file
# Processing file 230/616: jbmurray_text_2 vs jbmurray_text_3.xlsx
# Processing Document: jbmurray_text_2 vs jbmurray_text_3.xlsx
# Writing file
# Processing file 231/616: jerekrischel_text_10 vs jerryfriedman_text_3.xlsx
# Processing Document: jerekrischel_text_10 vs jerryfriedman_text_3.xlsx
# Writing file
# Processing file 232/616: updown_text_2 vs vedant_text_4.xlsx
# Processing Document: updown_text_2 vs vedant_text_4.xlsx
# Writing file
# Processing file 233/616: ledenierhomme_text_2 vs legolas2186_text_3.xlsx
# Processing Document: ledenierhomme_text_2 vs legolas2186_text_3.xlsx
# Writing file
# Processing file 234/616: o_fenian_text_3 vs paul_siebert_text_12.xlsx
# Processing Document: o_fenian_text_3 vs paul_siebert_text_12.xlsx
# Writing file
# Processing file 235/616: spaully_text_2 vs spitfire_text_5.xlsx
# Processing Document: spaully_text_2 vs spitfire_text_5.xlsx
# Writing file
# Processing file 236/616: mathsci_text_2 vs mathsci_text_10.xlsx
# Processing Document: mathsci_text_2 vs mathsci_text_10.xlsx
# Writing file
# Processing file 237/616: killerchihuahua_text_1 vs kudzu1_text_1.xlsx
# Processing Document: killerchihuahua_text_1 vs kudzu1_text_1.xlsx
# Writing file
# Processing file 238/616: srisuren_text_13 vs stephenbuxton_text_3.xlsx
# Processing Document: srisuren_text_13 vs stephenbuxton_text_3.xlsx
# Writing file
# Processing file 239/616: pinkampersand_text_2 vs pinkampersand_text_4.xlsx
# Processing Document: pinkampersand_text_2 vs pinkampersand_text_4.xlsx
# Writing file
# Processing file 240/616: hodja_nasreddin_text_10 vs hodja_nasreddin_text_3.xlsx
# Processing Document: hodja_nasreddin_text_10 vs hodja_nasreddin_text_3.xlsx
# Writing file
# Processing file 241/616: swift_silent_text_5 vs swift_silent_text_2.xlsx
# Processing Document: swift_silent_text_5 vs swift_silent_text_2.xlsx
# Writing file
# Processing file 242/616: hootmag_text_12 vs iain99_text_5.xlsx
# Processing Document: hootmag_text_12 vs iain99_text_5.xlsx
# Writing file
# Processing file 243/616: nocal100_text_3 vs nocal100_text_5.xlsx
# Processing Document: nocal100_text_3 vs nocal100_text_5.xlsx
# Writing file
# Processing file 244/616: marine_69_71_text_3 vs mathsci_text_10.xlsx
# Processing Document: marine_69_71_text_3 vs mathsci_text_10.xlsx
# Writing file
# Processing file 245/616: magog_the_ogre_text_3 vs mangoe_text_1.xlsx
# Processing Document: magog_the_ogre_text_3 vs mangoe_text_1.xlsx
# Writing file
# Processing file 246/616: simoncursitor_text_3 vs simoncursitor_text_4.xlsx
# Processing Document: simoncursitor_text_3 vs simoncursitor_text_4.xlsx
# Writing file
# Processing file 247/616: jeffrey_vernon_merkey_text_11 vs jerekrischel_text_13.xlsx
# Processing Document: jeffrey_vernon_merkey_text_11 vs jerekrischel_text_13.xlsx
# Writing file
# Processing file 248/616: killerchihuahua_text_11 vs killerchihuahua_text_3.xlsx
# Processing Document: killerchihuahua_text_11 vs killerchihuahua_text_3.xlsx
# Writing file
# Processing file 249/616: t34ch_text_2 vs thekohser_text_11.xlsx
# Processing Document: t34ch_text_2 vs thekohser_text_11.xlsx
# Writing file
# Processing file 250/616: snowded_text_12 vs snowded_text_1.xlsx
# Processing Document: snowded_text_12 vs snowded_text_1.xlsx
# Writing file
# Processing file 251/616: jasper_deng_text_2 vs jbmurray_text_3.xlsx
# Processing Document: jasper_deng_text_2 vs jbmurray_text_3.xlsx
# Writing file
# Processing file 252/616: obamafan70_text_3 vs obamafan70_text_5.xlsx
# Processing Document: obamafan70_text_3 vs obamafan70_text_5.xlsx
# Writing file
# Processing file 253/616: legolas2186_text_2 vs livelikemusic_text_3.xlsx
# Processing Document: legolas2186_text_2 vs livelikemusic_text_3.xlsx
# Writing file
# Processing file 254/616: ramdrake_text_3 vs richard_daft_text_4.xlsx
# Processing Document: ramdrake_text_3 vs richard_daft_text_4.xlsx
# Writing file
# Processing file 255/616: sgrayban_text_2 vs sgrayban_text_5.xlsx
# Processing Document: sgrayban_text_2 vs sgrayban_text_5.xlsx
# Writing file
# Processing file 256/616: mcb_text_4 vs media_anthro_text_5.xlsx
# Processing Document: mcb_text_4 vs media_anthro_text_5.xlsx
# Writing file
# Processing file 257/616: sks2k6_text_1 vs sks2k6_text_3.xlsx
# Processing Document: sks2k6_text_1 vs sks2k6_text_3.xlsx
# Writing file
# Processing file 258/616: njgw_text_4 vs njgw_text_5.xlsx
# Processing Document: njgw_text_4 vs njgw_text_5.xlsx
# Writing file
# Processing file 259/616: itub_text_3 vs itub_text_4.xlsx
# Processing Document: itub_text_3 vs itub_text_4.xlsx
# Writing file
# Processing file 260/616: livelikemusic_text_2 vs livelikemusic_text_3.xlsx
# Processing Document: livelikemusic_text_2 vs livelikemusic_text_3.xlsx
# Writing file
# Processing file 261/616: wiki_guy_16_text_3 vs williamh_text_1.xlsx
# Processing Document: wiki_guy_16_text_3 vs williamh_text_1.xlsx
# Writing file
# Processing file 262/616: itub_text_5 vs ivoshandor_text_1.xlsx
# Processing Document: itub_text_5 vs ivoshandor_text_1.xlsx
# Writing file
# Processing file 263/616: nil_einne_text_12 vs nirvana888_text_4.xlsx
# Processing Document: nil_einne_text_12 vs nirvana888_text_4.xlsx
# Writing file
# Processing file 264/616: viewfinder_text_5 vs viewfinder_text_4.xlsx
# Processing Document: viewfinder_text_5 vs viewfinder_text_4.xlsx
# Writing file
# Processing file 265/616: intangible_text_1 vs intangible_text_2.xlsx
# Processing Document: intangible_text_1 vs intangible_text_2.xlsx
# Writing file
# Processing file 266/616: jim_hardie_text_4 vs jim_hardie_text_2.xlsx
# Processing Document: jim_hardie_text_4 vs jim_hardie_text_2.xlsx
# Writing file
# Processing file 267/616: livitup_text_3 vs livitup_text_5.xlsx
# Processing Document: livitup_text_3 vs livitup_text_5.xlsx
# Writing file
# Processing file 268/616: lear_21_text_1 vs ledenierhomme_text_3.xlsx
# Processing Document: lear_21_text_1 vs ledenierhomme_text_3.xlsx
# Writing file
# Processing file 269/616: thekohser_text_3 vs thekohser_text_11.xlsx
# Processing Document: thekohser_text_3 vs thekohser_text_11.xlsx
# Writing file
# Processing file 270/616: nocal100_text_4 vs nocrowx_text_4.xlsx
# Processing Document: nocal100_text_4 vs nocrowx_text_4.xlsx
# Writing file
# Processing file 271/616: mangoe_text_10 vs mangoe_text_1.xlsx
# Processing Document: mangoe_text_10 vs mangoe_text_1.xlsx
# Writing file
# Processing file 272/616: pinkampersand_text_2 vs pro_lick_text_1.xlsx
# Processing Document: pinkampersand_text_2 vs pro_lick_text_1.xlsx
# Writing file
# Processing file 273/616: ledenierhomme_text_4 vs legolas2186_text_3.xlsx
# Processing Document: ledenierhomme_text_4 vs legolas2186_text_3.xlsx
# Writing file
# Processing file 274/616: sean_hoyland_text_1 vs secret_of_success_text_3.xlsx
# Processing Document: sean_hoyland_text_1 vs secret_of_success_text_3.xlsx
# Writing file
# Processing file 275/616: ramdrake_text_1 vs ramdrake_text_5.xlsx
# Processing Document: ramdrake_text_1 vs ramdrake_text_5.xlsx
# Writing file
# Processing file 276/616: intangible_text_1 vs intothefire_text_12.xlsx
# Processing Document: intangible_text_1 vs intothefire_text_12.xlsx
# Writing file
# Processing file 277/616: paul_siebert_text_10 vs petersymonds_text_3.xlsx
# Processing Document: paul_siebert_text_10 vs petersymonds_text_3.xlsx
# Writing file
# Processing file 278/616: snowded_text_10 vs snowded_text_1.xlsx
# Processing Document: snowded_text_10 vs snowded_text_1.xlsx
# Writing file
# Processing file 279/616: viewfinder_text_5 vs volunteer_marek_text_4.xlsx
# Processing Document: viewfinder_text_5 vs volunteer_marek_text_4.xlsx
# Writing file
# Processing file 280/616: srisuren_text_13 vs srisuren_text_10.xlsx
# Processing Document: srisuren_text_13 vs srisuren_text_10.xlsx
# Writing file
# Processing file 281/616: vedant_text_2 vs vedant_text_4.xlsx
# Processing Document: vedant_text_2 vs vedant_text_4.xlsx
# Writing file
# Processing file 282/616: itub_text_2 vs ivoshandor_text_1.xlsx
# Processing Document: itub_text_2 vs ivoshandor_text_1.xlsx
# Writing file
# Processing file 283/616: sks2k6_text_5 vs sks2k6_text_3.xlsx
# Processing Document: sks2k6_text_5 vs sks2k6_text_3.xlsx
# Writing file
# Processing file 284/616: magog_the_ogre_text_1 vs mangoe_text_1.xlsx
# Processing Document: magog_the_ogre_text_1 vs mangoe_text_1.xlsx
# Writing file
# Processing file 285/616: johnuniq_text_1 vs jwanders_text_4.xlsx
# Processing Document: johnuniq_text_1 vs jwanders_text_4.xlsx
# Writing file
# Processing file 286/616: protonk_text_12 vs ramdrake_text_5.xlsx
# Processing Document: protonk_text_12 vs ramdrake_text_5.xlsx
# Writing file
# Processing file 287/616: l_tak_text_2 vs l_tak_text_4.xlsx
# Processing Document: l_tak_text_2 vs l_tak_text_4.xlsx
# Writing file
# Processing file 288/616: jwanders_text_1 vs jwanders_text_4.xlsx
# Processing Document: jwanders_text_1 vs jwanders_text_4.xlsx
# Writing file
# Processing file 289/616: rolandr_text_5 vs salierethefish_text_5.xlsx
# Processing Document: rolandr_text_5 vs salierethefish_text_5.xlsx
# Writing file
# Processing file 290/616: jimharlow99_text_13 vs jim_hardie_text_2.xlsx
# Processing Document: jimharlow99_text_13 vs jim_hardie_text_2.xlsx
# Writing file
# Processing file 291/616: spaully_text_4 vs spitfire_text_5.xlsx
# Processing Document: spaully_text_4 vs spitfire_text_5.xlsx
# Writing file
# Processing file 292/616: stillstanding_247_text_1 vs swift_silent_text_2.xlsx
# Processing Document: stillstanding_247_text_1 vs swift_silent_text_2.xlsx
# Writing file
# Processing file 293/616: snowded_text_2 vs snowded_text_1.xlsx
# Processing Document: snowded_text_2 vs snowded_text_1.xlsx
# Writing file
# Processing file 294/616: nableezy_text_12 vs nableezy_text_2.xlsx
# Processing Document: nableezy_text_12 vs nableezy_text_2.xlsx
# Writing file
# Processing file 295/616: jerryfriedman_text_4 vs jimharlow99_text_10.xlsx
# Processing Document: jerryfriedman_text_4 vs jimharlow99_text_10.xlsx
# Writing file
# Processing file 296/616: stephenbuxton_text_4 vs stephenbuxton_text_3.xlsx
# Processing Document: stephenbuxton_text_4 vs stephenbuxton_text_3.xlsx
# Writing file
# Processing file 297/616: petersymonds_text_1 vs peter_james_text_4.xlsx
# Processing Document: petersymonds_text_1 vs peter_james_text_4.xlsx
# Writing file
# Processing file 298/616: nirvana888_text_2 vs njgw_text_5.xlsx
# Processing Document: nirvana888_text_2 vs njgw_text_5.xlsx
# Writing file
# Processing file 299/616: vr_text_6 vs vsevolodkrolikov_text_1.xlsx
# Processing Document: vr_text_6 vs vsevolodkrolikov_text_1.xlsx
# Writing file
# Processing file 300/616: yoenit_text_4 vs zjarrirrethues_text_2.xlsx
# Processing Document: yoenit_text_4 vs zjarrirrethues_text_2.xlsx
# Writing file
# Processing file 301/616: jeffrey_vernon_merkey_text_3 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing Document: jeffrey_vernon_merkey_text_3 vs jeffrey_vernon_merkey_text_10.xlsx
# Writing file
# Processing file 302/616: wiki_guy_16_text_5 vs wiki_guy_16_text_1.xlsx
# Processing Document: wiki_guy_16_text_5 vs wiki_guy_16_text_1.xlsx
# Writing file
# Processing file 303/616: stillstanding_247_text_4 vs swift_silent_text_2.xlsx
# Processing Document: stillstanding_247_text_4 vs swift_silent_text_2.xlsx
# Writing file
# Processing file 304/616: vsevolodkrolikov_text_12 vs vsevolodkrolikov_text_1.xlsx
# Processing Document: vsevolodkrolikov_text_12 vs vsevolodkrolikov_text_1.xlsx
# Writing file
# Processing file 305/616: sks2k6_text_4 vs sks2k6_text_3.xlsx
# Processing Document: sks2k6_text_4 vs sks2k6_text_3.xlsx
# Writing file
# Processing file 306/616: sks2k6_text_1 vs snowded_text_1.xlsx
# Processing Document: sks2k6_text_1 vs snowded_text_1.xlsx
# Writing file
# Processing file 307/616: itub_text_3 vs ivoshandor_text_1.xlsx
# Processing Document: itub_text_3 vs ivoshandor_text_1.xlsx
# Writing file
# Processing file 308/616: mymoloboaccount_text_2 vs mystichumwipe_text_11.xlsx
# Processing Document: mymoloboaccount_text_2 vs mystichumwipe_text_11.xlsx
# Writing file
# Processing file 309/616: phead128_text_1 vs phead128_text_2.xlsx
# Processing Document: phead128_text_1 vs phead128_text_2.xlsx
# Writing file
# Processing file 310/616: lear_21_text_2 vs lear_21_text_3.xlsx
# Processing Document: lear_21_text_2 vs lear_21_text_3.xlsx
# Writing file
# Processing file 311/616: intothefire_text_2 vs irvine22_text_3.xlsx
# Processing Document: intothefire_text_2 vs irvine22_text_3.xlsx
# Writing file
# Processing file 312/616: jbmurray_text_2 vs jc37_text_4.xlsx
# Processing Document: jbmurray_text_2 vs jc37_text_4.xlsx
# Writing file
# Processing file 313/616: l_tak_text_10 vs l_tak_text_4.xlsx
# Processing Document: l_tak_text_10 vs l_tak_text_4.xlsx
# Writing file
# Processing file 314/616: media_anthro_text_3 vs media_anthro_text_5.xlsx
# Processing Document: media_anthro_text_3 vs media_anthro_text_5.xlsx
# Writing file
# Processing file 315/616: richard_daft_text_2 vs rjecina_text_11.xlsx
# Processing Document: richard_daft_text_2 vs rjecina_text_11.xlsx
# Writing file
# Processing file 316/616: jwanders_text_2 vs jwanders_text_4.xlsx
# Processing Document: jwanders_text_2 vs jwanders_text_4.xlsx
# Writing file
# Processing file 317/616: jimharlow99_text_12 vs jim_hardie_text_2.xlsx
# Processing Document: jimharlow99_text_12 vs jim_hardie_text_2.xlsx
# Writing file
# Processing file 318/616: nocrowx_text_5 vs nocrowx_text_4.xlsx
# Processing Document: nocrowx_text_5 vs nocrowx_text_4.xlsx
# Writing file
# Processing file 319/616: nil_einne_text_11 vs nil_einne_text_10.xlsx
# Processing Document: nil_einne_text_11 vs nil_einne_text_10.xlsx
# Writing file
# Processing file 320/616: mathsci_text_3 vs mathsci_text_10.xlsx
# Processing Document: mathsci_text_3 vs mathsci_text_10.xlsx
# Writing file
# Processing file 321/616: pinkampersand_text_1 vs pinkampersand_text_4.xlsx
# Processing Document: pinkampersand_text_1 vs pinkampersand_text_4.xlsx
# Writing file
# Processing file 322/616: spitfire_text_2 vs spitfire_text_5.xlsx
# Processing Document: spitfire_text_2 vs spitfire_text_5.xlsx
# Writing file
# Processing file 323/616: icarus3_text_3 vs icarus3_text_4.xlsx
# Processing Document: icarus3_text_3 vs icarus3_text_4.xlsx
# Writing file
# Processing file 324/616: jerryfriedman_text_4 vs jerryfriedman_text_3.xlsx
# Processing Document: jerryfriedman_text_4 vs jerryfriedman_text_3.xlsx
# Writing file
# Processing file 325/616: mymoloboaccount_text_3 vs mystichumwipe_text_11.xlsx
# Processing Document: mymoloboaccount_text_3 vs mystichumwipe_text_11.xlsx
# Writing file
# Processing file 326/616: secret_of_success_text_1 vs sennen_goroshi_text_3.xlsx
# ...
# Processing Document: jéské_couriano_text_3 vs kashmiri_text_3.xlsx
# Writing file
# Processing file 542/616: nil_einne_text_13 vs nirvana888_text_4.xlsx
# Processing Document: nil_einne_text_13 vs nirvana888_text_4.xlsx
# Writing file
# Processing file 543/616: jéské_couriano_text_5 vs jéské_couriano_text_4.xlsx
# Processing Document: jéské_couriano_text_5 vs jéské_couriano_text_4.xlsx
# Writing file
# Processing file 544/616: jbmurray_text_4 vs jc37_text_4.xlsx
# Processing Document: jbmurray_text_4 vs jc37_text_4.xlsx
# Writing file
# Processing file 545/616: rjecina_text_1 vs rolandr_text_3.xlsx
# Processing Document: rjecina_text_1 vs rolandr_text_3.xlsx
# Writing file
# Processing file 546/616: swift_silent_text_5 vs t34ch_text_4.xlsx
# Processing Document: swift_silent_text_5 vs t34ch_text_4.xlsx
# Writing file
# Processing file 547/616: mathsci_text_11 vs maunus_text_1.xlsx
# Processing Document: mathsci_text_11 vs maunus_text_1.xlsx
# Writing file
# Processing file 548/616: ramdrake_text_2 vs ramdrake_text_5.xlsx
# Processing Document: ramdrake_text_2 vs ramdrake_text_5.xlsx
# Writing file
# Processing file 549/616: vsevolodkrolikov_text_11 vs wiki_guy_16_text_1.xlsx
# Processing Document: vsevolodkrolikov_text_11 vs wiki_guy_16_text_1.xlsx
# Writing file
# Processing file 550/616: livitup_text_4 vs livitup_text_5.xlsx
# Processing Document: livitup_text_4 vs livitup_text_5.xlsx
# Writing file
# Processing file 551/616: the_four_deuces_text_1 vs the_four_deuces_text_4.xlsx
# Processing Document: the_four_deuces_text_1 vs the_four_deuces_text_4.xlsx
# Writing file
# Processing file 552/616: kudzu1_text_5 vs l_tak_text_4.xlsx
# Processing Document: kudzu1_text_5 vs l_tak_text_4.xlsx
# Writing file
# Processing file 553/616: t34ch_text_2 vs t34ch_text_4.xlsx
# Processing Document: t34ch_text_2 vs t34ch_text_4.xlsx
# Writing file
# Processing file 554/616: intothefire_text_1 vs intothefire_text_12.xlsx
# Processing Document: intothefire_text_1 vs intothefire_text_12.xlsx
# Writing file
# Processing file 555/616: nocrowx_text_2 vs nocrowx_text_4.xlsx
# Processing Document: nocrowx_text_2 vs nocrowx_text_4.xlsx
# Writing file
# Processing file 556/616: notpietru_text_4 vs notpietru_text_2.xlsx
# Processing Document: notpietru_text_4 vs notpietru_text_2.xlsx
# Writing file
# Processing file 557/616: jc37_text_10 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing Document: jc37_text_10 vs jeffrey_vernon_merkey_text_10.xlsx
# Writing file
# Processing file 558/616: hootmag_text_12 vs hootmag_text_13.xlsx
# Processing Document: hootmag_text_12 vs hootmag_text_13.xlsx
# Writing file
# Processing file 559/616: simoncursitor_text_2 vs sks2k6_text_3.xlsx
# Processing Document: simoncursitor_text_2 vs sks2k6_text_3.xlsx
# Writing file
# Processing file 560/616: irvine22_text_1 vs irvine22_text_3.xlsx
# Processing Document: irvine22_text_1 vs irvine22_text_3.xlsx
# Writing file
# Processing file 561/616: wiki_guy_16_text_6 vs williamh_text_1.xlsx
# Processing Document: wiki_guy_16_text_6 vs williamh_text_1.xlsx
# Writing file
# Processing file 562/616: srisuren_text_1 vs stephenbuxton_text_3.xlsx
# Processing Document: srisuren_text_1 vs stephenbuxton_text_3.xlsx
# Writing file
# Processing file 563/616: jmrh6_text_3 vs jmrh6_text_1.xlsx
# Processing Document: jmrh6_text_3 vs jmrh6_text_1.xlsx
# Writing file
# Processing file 564/616: machine_elf_1735_text_4 vs machine_elf_1735_text_3.xlsx
# Processing Document: machine_elf_1735_text_4 vs machine_elf_1735_text_3.xlsx
# Writing file
# Processing file 565/616: salix_alba_text_1 vs salix_alba_text_3.xlsx
# Processing Document: salix_alba_text_1 vs salix_alba_text_3.xlsx
# Writing file
# Processing file 566/616: wobble_text_1 vs wobble_text_13.xlsx
# Processing Document: wobble_text_1 vs wobble_text_13.xlsx
# Writing file
# Processing file 567/616: protonk_text_12 vs protonk_text_13.xlsx
# Processing Document: protonk_text_12 vs protonk_text_13.xlsx
# Writing file
# Processing file 568/616: nocrowx_text_5 vs notpietru_text_2.xlsx
# Processing Document: nocrowx_text_5 vs notpietru_text_2.xlsx
# Writing file
# Processing file 569/616: the_four_deuces_text_3 vs the_four_deuces_text_4.xlsx
# Processing Document: the_four_deuces_text_3 vs the_four_deuces_text_4.xlsx
# Writing file
# Processing file 570/616: jimharlow99_text_13 vs jimharlow99_text_10.xlsx
# Processing Document: jimharlow99_text_13 vs jimharlow99_text_10.xlsx
# Writing file
# Processing file 571/616: simoncursitor_text_1 vs sks2k6_text_3.xlsx
# Processing Document: simoncursitor_text_1 vs sks2k6_text_3.xlsx
# Writing file
# Processing file 572/616: jerekrischel_text_11 vs jerekrischel_text_13.xlsx
# Processing Document: jerekrischel_text_11 vs jerekrischel_text_13.xlsx
# Writing file
# Processing file 573/616: hodja_nasreddin_text_11 vs honestopl_text_1.xlsx
# Processing Document: hodja_nasreddin_text_11 vs honestopl_text_1.xlsx
# Writing file
# Processing file 574/616: volunteer_marek_text_3 vs vr_text_3.xlsx
# Processing Document: volunteer_marek_text_3 vs vr_text_3.xlsx
# Writing file
# Processing file 575/616: kudzu1_text_2 vs kudzu1_text_1.xlsx
# Processing Document: kudzu1_text_2 vs kudzu1_text_1.xlsx
# Writing file
# Processing file 576/616: spaully_text_5 vs spitfire_text_5.xlsx
# Processing Document: spaully_text_5 vs spitfire_text_5.xlsx
# Writing file
# Processing file 577/616: nathan_text_11 vs nathan_text_10.xlsx
# Processing Document: nathan_text_11 vs nathan_text_10.xlsx
# Writing file
# Processing file 578/616: srisuren_text_1 vs srisuren_text_10.xlsx
# Processing Document: srisuren_text_1 vs srisuren_text_10.xlsx
# Writing file
# Processing file 579/616: spaully_text_4 vs spaully_text_3.xlsx
# Processing Document: spaully_text_4 vs spaully_text_3.xlsx
# Writing file
# Processing file 580/616: johnuniq_text_1 vs johnuniq_text_10.xlsx
# Processing Document: johnuniq_text_1 vs johnuniq_text_10.xlsx
# Writing file
# Processing file 581/616: nocal100_text_2 vs nocrowx_text_4.xlsx
# Processing Document: nocal100_text_2 vs nocrowx_text_4.xlsx
# Writing file
# Processing file 582/616: william_m_connolley_text_4 vs william_m_connolley_text_2.xlsx
# Processing Document: william_m_connolley_text_4 vs william_m_connolley_text_2.xlsx
# Writing file
# Processing file 583/616: meowy_text_12 vs mezzomezzo_text_5.xlsx
# Processing Document: meowy_text_12 vs mezzomezzo_text_5.xlsx
# Writing file
# Processing file 584/616: yoenit_text_4 vs yoenit_text_2.xlsx
# Processing Document: yoenit_text_4 vs yoenit_text_2.xlsx
# Writing file
# Processing file 585/616: obamafan70_text_2 vs obamafan70_text_5.xlsx
# Processing Document: obamafan70_text_2 vs obamafan70_text_5.xlsx
# Writing file
# Processing file 586/616: jwanders_text_5 vs jéské_couriano_text_4.xlsx
# Processing Document: jwanders_text_5 vs jéské_couriano_text_4.xlsx
# Writing file
# Processing file 587/616: milomedes_text_10 vs milomedes_text_13.xlsx
# Processing Document: milomedes_text_10 vs milomedes_text_13.xlsx
# Writing file
# Processing file 588/616: phead128_text_1 vs pinkampersand_text_4.xlsx
# Processing Document: phead128_text_1 vs pinkampersand_text_4.xlsx
# Writing file
# Processing file 589/616: salierethefish_text_4 vs salierethefish_text_5.xlsx
# Processing Document: salierethefish_text_4 vs salierethefish_text_5.xlsx
# Writing file
# Processing file 590/616: livelikemusic_text_5 vs livitup_text_5.xlsx
# Processing Document: livelikemusic_text_5 vs livitup_text_5.xlsx
# Writing file
# Processing file 591/616: mangoe_text_4 vs mareklug_text_5.xlsx
# Processing Document: mangoe_text_4 vs mareklug_text_5.xlsx
# Writing file
# Processing file 592/616: magog_the_ogre_text_2 vs mangoe_text_1.xlsx
# Processing Document: magog_the_ogre_text_2 vs mangoe_text_1.xlsx
# Writing file
# Processing file 593/616: irvine22_text_2 vs irvine22_text_3.xlsx
# Processing Document: irvine22_text_2 vs irvine22_text_3.xlsx
# Writing file
# Processing file 594/616: xtv_text_2 vs yoenit_text_2.xlsx
# Processing Document: xtv_text_2 vs yoenit_text_2.xlsx
# Writing file
# Processing file 595/616: stillstanding_247_text_2 vs swift_silent_text_2.xlsx
# Processing Document: stillstanding_247_text_2 vs swift_silent_text_2.xlsx
# Writing file
# Processing file 596/616: meowy_text_10 vs meowy_text_11.xlsx
# Processing Document: meowy_text_10 vs meowy_text_11.xlsx
# Writing file
# Processing file 597/616: mareklug_text_4 vs marine_69_71_text_4.xlsx
# Processing Document: mareklug_text_4 vs marine_69_71_text_4.xlsx
# Writing file
# Processing file 598/616: zjarrirrethues_text_4 vs zjarrirrethues_text_2.xlsx
# Processing Document: zjarrirrethues_text_4 vs zjarrirrethues_text_2.xlsx
# Writing file
# Processing file 599/616: marine_69_71_text_5 vs marine_69_71_text_4.xlsx
# Processing Document: marine_69_71_text_5 vs marine_69_71_text_4.xlsx
# Writing file
# Processing file 600/616: livelikemusic_text_2 vs livitup_text_5.xlsx
# Processing Document: livelikemusic_text_2 vs livitup_text_5.xlsx
# Writing file
# Processing file 601/616: sean_hoyland_text_1 vs sean_hoyland_text_3.xlsx
# Processing Document: sean_hoyland_text_1 vs sean_hoyland_text_3.xlsx
# Writing file
# Processing file 602/616: updown_text_2 vs updown_text_3.xlsx
# Processing Document: updown_text_2 vs updown_text_3.xlsx
# Writing file
# Processing file 603/616: xtv_text_5 vs yoenit_text_2.xlsx
# Processing Document: xtv_text_5 vs yoenit_text_2.xlsx
# Writing file
# Processing file 604/616: ramdrake_text_2 vs richard_daft_text_4.xlsx
# Processing Document: ramdrake_text_2 vs richard_daft_text_4.xlsx
# Writing file
# Processing file 605/616: mareklug_text_1 vs mareklug_text_5.xlsx
# Processing Document: mareklug_text_1 vs mareklug_text_5.xlsx
# Writing file
# Processing file 606/616: stephenbuxton_text_1 vs stephenbuxton_text_3.xlsx
# Processing Document: stephenbuxton_text_1 vs stephenbuxton_text_3.xlsx
# Writing file
# Processing file 607/616: nathan_text_3 vs nathan_text_10.xlsx
# Processing Document: nathan_text_3 vs nathan_text_10.xlsx
# Writing file
# Processing file 608/616: irvine22_text_2 vs itub_text_4.xlsx
# Processing Document: irvine22_text_2 vs itub_text_4.xlsx
# Writing file
# Processing file 609/616: simoncursitor_text_1 vs simoncursitor_text_4.xlsx
# Processing Document: simoncursitor_text_1 vs simoncursitor_text_4.xlsx
# Writing file
# Processing file 610/616: intangible_text_5 vs intangible_text_2.xlsx
# Processing Document: intangible_text_5 vs intangible_text_2.xlsx
# Writing file
# Processing file 611/616: honestopl_text_3 vs honestopl_text_1.xlsx
# Processing Document: honestopl_text_3 vs honestopl_text_1.xlsx
# Writing file
# Processing file 612/616: legolas2186_text_4 vs legolas2186_text_3.xlsx
# Processing Document: legolas2186_text_4 vs legolas2186_text_3.xlsx
# Writing file
# Processing file 613/616: mcb_text_3 vs mcb_text_2.xlsx
# Processing Document: mcb_text_3 vs mcb_text_2.xlsx
# Writing file
# Processing file 614/616: intangible_text_5 vs intothefire_text_12.xlsx
# Processing Document: intangible_text_5 vs intothefire_text_12.xlsx
# Writing file
# Processing file 615/616: intangible_text_3 vs intangible_text_2.xlsx
# Processing Document: intangible_text_3 vs intangible_text_2.xlsx
# Writing file
# Processing file 616/616: nathan_text_11 vs nigel_ish_text_4.xlsx
# Processing Document: nathan_text_11 vs nigel_ish_text_4.xlsx
# Writing file
#
# All files complete ✓
#
# Skipping save because no result_save_loc was provided.
#      index  sample_id                             problem corpus  \
# 0        0          1  Hodja_Nasreddin vs Hodja_Nasreddin   Wiki
# 1        1          2  Hodja_Nasreddin vs Hodja_Nasreddin   Wiki
# 2        2          3  Hodja_Nasreddin vs Hodja_Nasreddin   Wiki
# 3        3          4        Hodja_Nasreddin vs HonestopL   Wiki
# 4        4          5        Hodja_Nasreddin vs HonestopL   Wiki
# ..     ...        ...                                 ...    ...
# 611    667        668    ZjarriRrethues vs 142.196.88.228   Wiki
# 612    668        669    ZjarriRrethues vs 142.196.88.228   Wiki
# 613    669        670    ZjarriRrethues vs ZjarriRrethues   Wiki
# 614    670        671    ZjarriRrethues vs ZjarriRrethues   Wiki
# 615    671        672    ZjarriRrethues vs ZjarriRrethues   Wiki
#
#         known_author   unknown_author          unknown_doc_id  \
# 0    Hodja_Nasreddin  Hodja_Nasreddin  hodja_nasreddin_text_3
# 1    Hodja_Nasreddin  Hodja_Nasreddin  hodja_nasreddin_text_3
# 2    Hodja_Nasreddin  Hodja_Nasreddin  hodja_nasreddin_text_3
# 3    Hodja_Nasreddin        HonestopL        honestopl_text_1
# 4    Hodja_Nasreddin        HonestopL        honestopl_text_1
# ..               ...              ...                     ...
# 611   ZjarriRrethues   142.196.88.228   142_196_88_228_text_2
# 612   ZjarriRrethues   142.196.88.228   142_196_88_228_text_2
# 613   ZjarriRrethues   ZjarriRrethues   zjarrirrethues_text_2
# 614   ZjarriRrethues   ZjarriRrethues   zjarrirrethues_text_2
# 615   ZjarriRrethues   ZjarriRrethues   zjarrirrethues_text_2
#
#                 known_doc_id  target  num_phrases  ...  known_log_prob  \
# 0     hodja_nasreddin_text_1    True           12  ...      -94.802674
# 1    hodja_nasreddin_text_10    True           11  ...      -82.992827
# 2    hodja_nasreddin_text_11    True            8  ...      -49.086520
# 3     hodja_nasreddin_text_1   False            8  ...      -66.596993
# 4    hodja_nasreddin_text_10   False            7  ...      -49.804151
# ..                       ...     ...          ...  ...             ...
# 611    zjarrirrethues_text_4   False            5  ...      -28.818235
# 612    zjarrirrethues_text_5   False            6  ...      -53.050993
# 613    zjarrirrethues_text_1    True            9  ...      -85.837280
# 614    zjarrirrethues_text_4    True           13  ...     -131.761348
# 615    zjarrirrethues_text_5    True           13  ...     -107.683820
#
#      unknown_log_prob  llr_no_context  llr_known  llr_unknown  \
# 0         -100.632861       19.590962  11.743081    10.633380
# 1          -83.322568       22.546681  11.643380     9.595564
# 2          -71.664797       10.791892   5.733034     6.693348
# 3          -71.588018       17.202432   9.351598     6.611619
# 4          -41.695350       13.543120   5.959475     4.498780
# ..                ...             ...        ...          ...
# 611        -59.272039       19.189928   5.354576     7.316360
# 612        -77.322432       34.128463   9.099270    10.200630
# 613        -69.836864       22.351969   9.807849    10.135595
# 614       -123.233849       38.555566  16.965157    12.172307
# 615       -107.302036       27.177697  15.190763    11.489383
#
#      llr_unknown_vs_top_rank  unknown_ref_vs_best_rest  \
# 0                  -9.775343                 -4.916896
# 1                 -10.908952                  7.442016
# 2                  -5.423525                  4.634485
# 3                  -6.337841                 -3.123308
# 4                  -2.327063                  5.433823
# ..                       ...                       ...
# 611                -8.091894                 24.915954
# 612               -14.152155                 11.186672
# 613               -12.228219                  9.965105
# 614               -14.319427                 11.892420
# 615               -13.225679                  8.313187
#
#      normalised_llr_no_context  normalised_llr_known  normalised_llr_unknown
# 0                     1.632580              0.978590                0.886115
# 1                     2.049698              1.058489                0.872324
# 2                     1.348987              0.716629                0.836669
# 3                     2.150304              1.168950                0.826452
# 4                     1.934731              0.851354                0.642683
# ..                         ...                   ...                     ...
# 611                   3.837986              1.070915                1.463272
# 612                   5.688077              1.516545                1.700105
# 613                   2.483552              1.089761                1.126177
# 614                   2.965813              1.305012                0.936331
# 615                   2.090592              1.168520                0.883799
#
# [616 rows x 21 columns]
