# %%
import sys
import os

import pandas as pd

from glob import glob
from from_root import from_root

sys.path.insert(0, str(from_root("src")))

from read_and_write_docs import read_excel_sheets

# %%
results_dir = '/Volumes/BCross/paraphrase examples slurm/llama results/filtered'
phrase_location = '/Volumes/BCross/paraphrase examples slurm/wiki-phrase-list-reviewed.xlsx'
save_location = '/Volumes/BCross/paraphrase examples slurm/llama results/token_level_results.xlsx'

# %%
def summarise_llr_by_token_level(document_location: str, phrase_document_location: str) -> pd.DataFrame:
    """
    Generate a token-level LLR summary from provided LLR and phrase data.

    Parameters:
    ----------
    document_location : str
        Path to the Excel file containing 'metadata' and 'LLR' sheets.
    phrase_document_location : str
        Path to the Excel file containing n-gram phrase data with a 'keep_phrase' column.

    Returns:
    -------
    pd.DataFrame
        A DataFrame where each row corresponds to a token-level threshold summary,
        combining metadata and computed LLR statistics.
    """
    # Read in both sheets from the Excel document
    excel_data = read_excel_sheets(document_location, sheet_names=['metadata', 'LLR'])
    llr = excel_data['LLR']
    metadata = excel_data['metadata']

    # Extract only the key metadata columns to attach later
    metadata_base = metadata[[
        'index', 'sample_id', 'problem', 'corpus',
        'known_author', 'unknown_author',
        'known_doc_id', 'unknown_doc_id', 'target'
    ]]

    # Load and filter ngram phrases, renaming for merge compatibility
    ngram_phrases = (
        pd.read_excel(phrase_document_location)
        .query("keep_phrase == 1")
        .drop(columns=['keep_phrase', 'tokens'])
        .rename(columns={"phrase": "original_phrase"})
    )

    # Merge LLR data with filtered phrase data
    llr_merged = llr.merge(ngram_phrases, on='original_phrase', how='inner')

    # Identify unique token thresholds to iterate over
    token_levels = llr_merged['num_tokens'].drop_duplicates().to_list()

    # Initialize the output summary table
    final_summary = pd.DataFrame()

    # Loop through each token threshold and compute stats
    for token_level in token_levels:
        llr_filtered = llr_merged.query(f"num_tokens >= {token_level}")

        # Compute basic LLR statistics
        LLR_summary = pd.DataFrame([{
            'min_token_size': token_level,
            'num_phrases': llr_filtered['phrase_num'].nunique(),
            'phrases_kept': llr_filtered.loc[llr_filtered['phrases_kept'] > 0, 'phrase_num'].nunique(),
            'llr_no_context': llr_filtered['llr_no_context'].sum(skipna=True),
            'llr_known': llr_filtered['llr_known'].sum(skipna=True),
            'llr_unknown': llr_filtered['llr_unknown'].sum(skipna=True),
            'unknown_ref_vs_top_rank': llr_filtered['unknown_ref_vs_top_rank'].sum(skipna=True),
        }])

        # Normalize the LLR values
        LLR_summary = LLR_summary.assign(
            normalised_llr_no_context=lambda d: d['llr_no_context'] / d['phrases_kept'],
            normalised_llr_known=lambda d: d['llr_known'] / d['phrases_kept'],
            normalised_llr_unknown=lambda d: d['llr_unknown'] / d['phrases_kept']
        )

        # Copy base metadata (just the first row if more than one)
        new_row = metadata_base.copy()
        if len(new_row) > 1:
            new_row = new_row.iloc[[0]]

        # Combine metadata and computed LLR stats
        new_row = pd.concat([new_row.reset_index(drop=True), LLR_summary.reset_index(drop=True)], axis=1)

        # Append to the final summary table
        final_summary = pd.concat([final_summary, new_row], ignore_index=True)

    return final_summary

# %%
def batch_summarize_llr(
    directory: str,
    phrase_document_location: str,
    save_location: str
):
    """
    Process all .xlsx files in a directory using summarize_llr_by_token_level,
    appending results and saving the final summary table to the specified location.

    Parameters:
    ----------
    directory : str
        Path to the directory containing Excel (.xlsx) files with 'metadata' and 'LLR' sheets.
    phrase_document_location : str
        Path to the Excel file with filtered phrase data.
    save_location : str
        Path (including filename) where the final summary Excel file will be saved.

    Returns:
    -------
    None
    """

    # Find all .xlsx files in the directory (non-hidden)
    excel_files = sorted(glob(os.path.join(directory, "*.xlsx")))
    all_summaries = []

    total_files = len(excel_files)

    for i, file_path in enumerate(excel_files, start=1):
        print(f"Processing file {i} of {total_files}: {os.path.basename(file_path)}")

        try:
            summary = summarise_llr_by_token_level(file_path, phrase_document_location)

            # Add a column to track the source file
            summary['source_file'] = os.path.basename(file_path)

            all_summaries.append(summary)

        except Exception as e:
            print(f"⚠️ Skipping {file_path} due to error: {e}")

    # Combine all results
    final_summary = pd.concat(all_summaries, ignore_index=True)

    # Save to Excel
    final_summary.to_excel(save_location, index=False)
    print(f"\n✅ Final summary saved to: {save_location}")

# %%
# model_list = ['gpt2', 'gemma', 'llama', 'qwen']

# for model in model_list:
#     print(f"Completing the scoring for {model}")
    
#     results_dir = f'/Volumes/BCross/paraphrase examples slurm/{model} results/filtered_inc_rank'
#     phrase_location = '/Volumes/BCross/paraphrase examples slurm/wiki-phrase-list-reviewed.xlsx'
#     save_location = f'/Volumes/BCross/paraphrase examples slurm/{model} results/token_level_results_inc_rank.xlsx'
    
#     batch_summarize_llr(
#         directory=results_dir,
#         phrase_document_location=phrase_location,
#         save_location=save_location
#     )

# %%
results_dir = '/Volumes/BCross/paraphrase examples slurm/Wiki-Test/ModernBERT-base/gpt2 results/filtered_inc_rank'
phrase_location = '/Volumes/BCross/paraphrase examples slurm/wiki-phrase-list-reviewed.xlsx'
save_location = '/Volumes/BCross/paraphrase examples slurm/Wiki-Test/ModernBERT-base/gpt2 results/token_level_results_inc_rank.xlsx'

batch_summarize_llr(
    directory=results_dir,
    phrase_document_location=phrase_location,
    save_location=save_location
)
# Out:
# Processing file 1 of 672: hodja_nasreddin_text_1 vs hodja_nasreddin_text_3.xlsx
# Processing file 2 of 672: hodja_nasreddin_text_1 vs honestopl_text_1.xlsx
# Processing file 3 of 672: hodja_nasreddin_text_10 vs hodja_nasreddin_text_3.xlsx
# Processing file 4 of 672: hodja_nasreddin_text_10 vs honestopl_text_1.xlsx
# Processing file 5 of 672: hodja_nasreddin_text_11 vs hodja_nasreddin_text_3.xlsx
# Processing file 6 of 672: hodja_nasreddin_text_11 vs honestopl_text_1.xlsx
# Processing file 7 of 672: honestopl_text_3 vs honestopl_text_1.xlsx
# Processing file 8 of 672: honestopl_text_3 vs hootmag_text_13.xlsx
# Processing file 9 of 672: honestopl_text_4 vs honestopl_text_1.xlsx
# Processing file 10 of 672: honestopl_text_4 vs hootmag_text_13.xlsx
# Processing file 11 of 672: honestopl_text_5 vs honestopl_text_1.xlsx
# Processing file 12 of 672: honestopl_text_5 vs hootmag_text_13.xlsx
# Processing file 13 of 672: hootmag_text_1 vs hootmag_text_13.xlsx
# Processing file 14 of 672: hootmag_text_1 vs iain99_text_5.xlsx
# Processing file 15 of 672: hootmag_text_10 vs hootmag_text_13.xlsx
# Processing file 16 of 672: hootmag_text_10 vs iain99_text_5.xlsx
# Processing file 17 of 672: hootmag_text_12 vs hootmag_text_13.xlsx
# Processing file 18 of 672: hootmag_text_12 vs iain99_text_5.xlsx
# Processing file 19 of 672: iain99_text_1 vs iain99_text_5.xlsx
# Processing file 20 of 672: iain99_text_1 vs icarus3_text_4.xlsx
# Processing file 21 of 672: iain99_text_2 vs iain99_text_5.xlsx
# Processing file 22 of 672: iain99_text_2 vs icarus3_text_4.xlsx
# Processing file 23 of 672: iain99_text_3 vs iain99_text_5.xlsx
# Processing file 24 of 672: iain99_text_3 vs icarus3_text_4.xlsx
# Processing file 25 of 672: icarus3_text_1 vs icarus3_text_4.xlsx
# Processing file 26 of 672: icarus3_text_1 vs intangible_text_2.xlsx
# Processing file 27 of 672: icarus3_text_2 vs icarus3_text_4.xlsx
# Processing file 28 of 672: icarus3_text_2 vs intangible_text_2.xlsx
# Processing file 29 of 672: icarus3_text_3 vs icarus3_text_4.xlsx
# Processing file 30 of 672: icarus3_text_3 vs intangible_text_2.xlsx
# Processing file 31 of 672: intangible_text_1 vs intangible_text_2.xlsx
# Processing file 32 of 672: intangible_text_1 vs intothefire_text_12.xlsx
# Processing file 33 of 672: intangible_text_3 vs intangible_text_2.xlsx
# Processing file 34 of 672: intangible_text_3 vs intothefire_text_12.xlsx
# Processing file 35 of 672: intangible_text_5 vs intangible_text_2.xlsx
# Processing file 36 of 672: intangible_text_5 vs intothefire_text_12.xlsx
# Processing file 37 of 672: intothefire_text_1 vs intothefire_text_12.xlsx
# Processing file 38 of 672: intothefire_text_1 vs irvine22_text_3.xlsx
# Processing file 39 of 672: intothefire_text_10 vs intothefire_text_12.xlsx
# Processing file 40 of 672: intothefire_text_10 vs irvine22_text_3.xlsx
# Processing file 41 of 672: intothefire_text_2 vs intothefire_text_12.xlsx
# Processing file 42 of 672: intothefire_text_2 vs irvine22_text_3.xlsx
# Processing file 43 of 672: irvine22_text_1 vs irvine22_text_3.xlsx
# Processing file 44 of 672: irvine22_text_1 vs itub_text_4.xlsx
# Processing file 45 of 672: irvine22_text_2 vs irvine22_text_3.xlsx
# Processing file 46 of 672: irvine22_text_2 vs itub_text_4.xlsx
# Processing file 47 of 672: irvine22_text_4 vs irvine22_text_3.xlsx
# Processing file 48 of 672: irvine22_text_4 vs itub_text_4.xlsx
# Processing file 49 of 672: itub_text_2 vs itub_text_4.xlsx
# Processing file 50 of 672: itub_text_2 vs ivoshandor_text_1.xlsx
# Processing file 51 of 672: itub_text_3 vs itub_text_4.xlsx
# Processing file 52 of 672: itub_text_3 vs ivoshandor_text_1.xlsx
# Processing file 53 of 672: itub_text_5 vs itub_text_4.xlsx
# Processing file 54 of 672: itub_text_5 vs ivoshandor_text_1.xlsx
# Processing file 55 of 672: ivoshandor_text_2 vs ivoshandor_text_1.xlsx
# Processing file 56 of 672: ivoshandor_text_2 vs jasper_deng_text_4.xlsx
# Processing file 57 of 672: ivoshandor_text_4 vs ivoshandor_text_1.xlsx
# Processing file 58 of 672: ivoshandor_text_4 vs jasper_deng_text_4.xlsx
# Processing file 59 of 672: ivoshandor_text_5 vs ivoshandor_text_1.xlsx
# Processing file 60 of 672: ivoshandor_text_5 vs jasper_deng_text_4.xlsx
# Processing file 61 of 672: jasper_deng_text_1 vs jasper_deng_text_4.xlsx
# Processing file 62 of 672: jasper_deng_text_1 vs jbmurray_text_3.xlsx
# Processing file 63 of 672: jasper_deng_text_2 vs jasper_deng_text_4.xlsx
# Processing file 64 of 672: jasper_deng_text_2 vs jbmurray_text_3.xlsx
# Processing file 65 of 672: jasper_deng_text_3 vs jasper_deng_text_4.xlsx
# Processing file 66 of 672: jasper_deng_text_3 vs jbmurray_text_3.xlsx
# Processing file 67 of 672: jbmurray_text_2 vs jbmurray_text_3.xlsx
# Processing file 68 of 672: jbmurray_text_2 vs jc37_text_4.xlsx
# Processing file 69 of 672: jbmurray_text_4 vs jbmurray_text_3.xlsx
# Processing file 70 of 672: jbmurray_text_4 vs jc37_text_4.xlsx
# Processing file 71 of 672: jbmurray_text_5 vs jbmurray_text_3.xlsx
# Processing file 72 of 672: jbmurray_text_5 vs jc37_text_4.xlsx
# Processing file 73 of 672: jc37_text_1 vs jc37_text_4.xlsx
# Processing file 74 of 672: jc37_text_1 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing file 75 of 672: jc37_text_10 vs jc37_text_4.xlsx
# Processing file 76 of 672: jc37_text_10 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing file 77 of 672: jc37_text_2 vs jc37_text_4.xlsx
# Processing file 78 of 672: jc37_text_2 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing file 79 of 672: jeffrey_vernon_merkey_text_1 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing file 80 of 672: jeffrey_vernon_merkey_text_1 vs jerekrischel_text_13.xlsx
# Processing file 81 of 672: jeffrey_vernon_merkey_text_11 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing file 82 of 672: jeffrey_vernon_merkey_text_11 vs jerekrischel_text_13.xlsx
# Processing file 83 of 672: jeffrey_vernon_merkey_text_3 vs jeffrey_vernon_merkey_text_10.xlsx
# Processing file 84 of 672: jeffrey_vernon_merkey_text_3 vs jerekrischel_text_13.xlsx
# Processing file 85 of 672: jerekrischel_text_10 vs jerekrischel_text_13.xlsx
# Processing file 86 of 672: jerekrischel_text_10 vs jerryfriedman_text_3.xlsx
# Processing file 87 of 672: jerekrischel_text_11 vs jerekrischel_text_13.xlsx
# Processing file 88 of 672: jerekrischel_text_11 vs jerryfriedman_text_3.xlsx
# Processing file 89 of 672: jerekrischel_text_12 vs jerekrischel_text_13.xlsx
# Processing file 90 of 672: jerekrischel_text_12 vs jerryfriedman_text_3.xlsx
# Processing file 91 of 672: jerryfriedman_text_1 vs jerryfriedman_text_3.xlsx
# Processing file 92 of 672: jerryfriedman_text_1 vs jimharlow99_text_10.xlsx
# Processing file 93 of 672: jerryfriedman_text_2 vs jerryfriedman_text_3.xlsx
# Processing file 94 of 672: jerryfriedman_text_2 vs jimharlow99_text_10.xlsx
# Processing file 95 of 672: jerryfriedman_text_4 vs jerryfriedman_text_3.xlsx
# Processing file 96 of 672: jerryfriedman_text_4 vs jimharlow99_text_10.xlsx
# Processing file 97 of 672: jéské_couriano_text_1 vs jéské_couriano_text_4.xlsx
# Processing file 98 of 672: jéské_couriano_text_1 vs kashmiri_text_3.xlsx
# Processing file 99 of 672: jéské_couriano_text_3 vs jéské_couriano_text_4.xlsx
# Processing file 100 of 672: jéské_couriano_text_3 vs kashmiri_text_3.xlsx
# Processing file 101 of 672: jéské_couriano_text_5 vs jéské_couriano_text_4.xlsx
# Processing file 102 of 672: jéské_couriano_text_5 vs kashmiri_text_3.xlsx
# Processing file 103 of 672: jim_hardie_text_1 vs jim_hardie_text_2.xlsx
# Processing file 104 of 672: jim_hardie_text_1 vs jmrh6_text_1.xlsx
# Processing file 105 of 672: jim_hardie_text_3 vs jim_hardie_text_2.xlsx
# Processing file 106 of 672: jim_hardie_text_3 vs jmrh6_text_1.xlsx
# Processing file 107 of 672: jim_hardie_text_4 vs jim_hardie_text_2.xlsx
# Processing file 108 of 672: jim_hardie_text_4 vs jmrh6_text_1.xlsx
# Processing file 109 of 672: jimharlow99_text_11 vs jim_hardie_text_2.xlsx
# Processing file 110 of 672: jimharlow99_text_11 vs jimharlow99_text_10.xlsx
# Processing file 111 of 672: jimharlow99_text_12 vs jim_hardie_text_2.xlsx
# Processing file 112 of 672: jimharlow99_text_12 vs jimharlow99_text_10.xlsx
# Processing file 113 of 672: jimharlow99_text_13 vs jim_hardie_text_2.xlsx
# Processing file 114 of 672: jimharlow99_text_13 vs jimharlow99_text_10.xlsx
# Processing file 115 of 672: jmrh6_text_2 vs jmrh6_text_1.xlsx
# Processing file 116 of 672: jmrh6_text_2 vs johnuniq_text_10.xlsx
# Processing file 117 of 672: jmrh6_text_3 vs jmrh6_text_1.xlsx
# Processing file 118 of 672: jmrh6_text_3 vs johnuniq_text_10.xlsx
# Processing file 119 of 672: jmrh6_text_4 vs jmrh6_text_1.xlsx
# Processing file 120 of 672: jmrh6_text_4 vs johnuniq_text_10.xlsx
# Processing file 121 of 672: johnuniq_text_1 vs johnuniq_text_10.xlsx
# Processing file 122 of 672: johnuniq_text_1 vs jwanders_text_4.xlsx
# Processing file 123 of 672: johnuniq_text_11 vs johnuniq_text_10.xlsx
# Processing file 124 of 672: johnuniq_text_11 vs jwanders_text_4.xlsx
# Processing file 125 of 672: johnuniq_text_13 vs johnuniq_text_10.xlsx
# Processing file 126 of 672: johnuniq_text_13 vs jwanders_text_4.xlsx
# Processing file 127 of 672: jwanders_text_1 vs jéské_couriano_text_4.xlsx
# Processing file 128 of 672: jwanders_text_1 vs jwanders_text_4.xlsx
# Processing file 129 of 672: jwanders_text_2 vs jéské_couriano_text_4.xlsx
# Processing file 130 of 672: jwanders_text_2 vs jwanders_text_4.xlsx
# Processing file 131 of 672: jwanders_text_5 vs jéské_couriano_text_4.xlsx
# Processing file 132 of 672: jwanders_text_5 vs jwanders_text_4.xlsx
# Processing file 133 of 672: kashmiri_text_1 vs kashmiri_text_3.xlsx
# Processing file 134 of 672: kashmiri_text_1 vs kblott_text_1.xlsx
# Processing file 135 of 672: kashmiri_text_2 vs kashmiri_text_3.xlsx
# Processing file 136 of 672: kashmiri_text_2 vs kblott_text_1.xlsx
# Processing file 137 of 672: kashmiri_text_4 vs kashmiri_text_3.xlsx
# Processing file 138 of 672: kashmiri_text_4 vs kblott_text_1.xlsx
# Processing file 139 of 672: kblott_text_3 vs kblott_text_1.xlsx
# Processing file 140 of 672: kblott_text_3 vs killerchihuahua_text_3.xlsx
# Processing file 141 of 672: kblott_text_4 vs kblott_text_1.xlsx
# Processing file 142 of 672: kblott_text_4 vs killerchihuahua_text_3.xlsx
# Processing file 143 of 672: kblott_text_5 vs kblott_text_1.xlsx
# Processing file 144 of 672: kblott_text_5 vs killerchihuahua_text_3.xlsx
# Processing file 145 of 672: killerchihuahua_text_1 vs killerchihuahua_text_3.xlsx
# Processing file 146 of 672: killerchihuahua_text_1 vs kudzu1_text_1.xlsx
# Processing file 147 of 672: killerchihuahua_text_11 vs killerchihuahua_text_3.xlsx
# Processing file 148 of 672: killerchihuahua_text_11 vs kudzu1_text_1.xlsx
# Processing file 149 of 672: killerchihuahua_text_2 vs killerchihuahua_text_3.xlsx
# Processing file 150 of 672: killerchihuahua_text_2 vs kudzu1_text_1.xlsx
# Processing file 151 of 672: kudzu1_text_2 vs kudzu1_text_1.xlsx
# Processing file 152 of 672: kudzu1_text_2 vs l_tak_text_4.xlsx
# Processing file 153 of 672: kudzu1_text_4 vs kudzu1_text_1.xlsx
# Processing file 154 of 672: kudzu1_text_4 vs l_tak_text_4.xlsx
# Processing file 155 of 672: kudzu1_text_5 vs kudzu1_text_1.xlsx
# Processing file 156 of 672: kudzu1_text_5 vs l_tak_text_4.xlsx
# Processing file 157 of 672: l_tak_text_1 vs l_tak_text_4.xlsx
# Processing file 158 of 672: l_tak_text_1 vs lear_21_text_3.xlsx
# Processing file 159 of 672: l_tak_text_10 vs l_tak_text_4.xlsx
# Processing file 160 of 672: l_tak_text_10 vs lear_21_text_3.xlsx
# Processing file 161 of 672: l_tak_text_2 vs l_tak_text_4.xlsx
# Processing file 162 of 672: l_tak_text_2 vs lear_21_text_3.xlsx
# Processing file 163 of 672: lear_21_text_1 vs lear_21_text_3.xlsx
# Processing file 164 of 672: lear_21_text_1 vs ledenierhomme_text_3.xlsx
# Processing file 165 of 672: lear_21_text_2 vs lear_21_text_3.xlsx
# Processing file 166 of 672: lear_21_text_2 vs ledenierhomme_text_3.xlsx
# Processing file 167 of 672: lear_21_text_5 vs lear_21_text_3.xlsx
# Processing file 168 of 672: lear_21_text_5 vs ledenierhomme_text_3.xlsx
# Processing file 169 of 672: ledenierhomme_text_1 vs ledenierhomme_text_3.xlsx
# Processing file 170 of 672: ledenierhomme_text_1 vs legolas2186_text_3.xlsx
# Processing file 171 of 672: ledenierhomme_text_2 vs ledenierhomme_text_3.xlsx
# Processing file 172 of 672: ledenierhomme_text_2 vs legolas2186_text_3.xlsx
# Processing file 173 of 672: ledenierhomme_text_4 vs ledenierhomme_text_3.xlsx
# Processing file 174 of 672: ledenierhomme_text_4 vs legolas2186_text_3.xlsx
# Processing file 175 of 672: legolas2186_text_1 vs legolas2186_text_3.xlsx
# Processing file 176 of 672: legolas2186_text_1 vs livelikemusic_text_3.xlsx
# Processing file 177 of 672: legolas2186_text_2 vs legolas2186_text_3.xlsx
# Processing file 178 of 672: legolas2186_text_2 vs livelikemusic_text_3.xlsx
# Processing file 179 of 672: legolas2186_text_4 vs legolas2186_text_3.xlsx
# Processing file 180 of 672: legolas2186_text_4 vs livelikemusic_text_3.xlsx
# Processing file 181 of 672: livelikemusic_text_2 vs livelikemusic_text_3.xlsx
# Processing file 182 of 672: livelikemusic_text_2 vs livitup_text_5.xlsx
# Processing file 183 of 672: livelikemusic_text_4 vs livelikemusic_text_3.xlsx
# Processing file 184 of 672: livelikemusic_text_4 vs livitup_text_5.xlsx
# Processing file 185 of 672: livelikemusic_text_5 vs livelikemusic_text_3.xlsx
# Processing file 186 of 672: livelikemusic_text_5 vs livitup_text_5.xlsx
# Processing file 187 of 672: livitup_text_1 vs livitup_text_5.xlsx
# Processing file 188 of 672: livitup_text_1 vs machine_elf_1735_text_3.xlsx
# Processing file 189 of 672: livitup_text_3 vs livitup_text_5.xlsx
# Processing file 190 of 672: livitup_text_3 vs machine_elf_1735_text_3.xlsx
# Processing file 191 of 672: livitup_text_4 vs livitup_text_5.xlsx
# Processing file 192 of 672: livitup_text_4 vs machine_elf_1735_text_3.xlsx
# Processing file 193 of 672: machine_elf_1735_text_2 vs machine_elf_1735_text_3.xlsx
# Processing file 194 of 672: machine_elf_1735_text_2 vs magog_the_ogre_text_4.xlsx
# Processing file 195 of 672: machine_elf_1735_text_4 vs machine_elf_1735_text_3.xlsx
# Processing file 196 of 672: machine_elf_1735_text_4 vs magog_the_ogre_text_4.xlsx
# Processing file 197 of 672: machine_elf_1735_text_5 vs machine_elf_1735_text_3.xlsx
# Processing file 198 of 672: machine_elf_1735_text_5 vs magog_the_ogre_text_4.xlsx
# Processing file 199 of 672: magog_the_ogre_text_1 vs magog_the_ogre_text_4.xlsx
# Processing file 200 of 672: magog_the_ogre_text_1 vs mangoe_text_1.xlsx
# Processing file 201 of 672: magog_the_ogre_text_2 vs magog_the_ogre_text_4.xlsx
# Processing file 202 of 672: magog_the_ogre_text_2 vs mangoe_text_1.xlsx
# Processing file 203 of 672: magog_the_ogre_text_3 vs magog_the_ogre_text_4.xlsx
# Processing file 204 of 672: magog_the_ogre_text_3 vs mangoe_text_1.xlsx
# Processing file 205 of 672: mangoe_text_10 vs mangoe_text_1.xlsx
# Processing file 206 of 672: mangoe_text_10 vs mareklug_text_5.xlsx
# Processing file 207 of 672: mangoe_text_3 vs mangoe_text_1.xlsx
# Processing file 208 of 672: mangoe_text_3 vs mareklug_text_5.xlsx
# Processing file 209 of 672: mangoe_text_4 vs mangoe_text_1.xlsx
# Processing file 210 of 672: mangoe_text_4 vs mareklug_text_5.xlsx
# Processing file 211 of 672: mareklug_text_1 vs mareklug_text_5.xlsx
# Processing file 212 of 672: mareklug_text_1 vs marine_69_71_text_4.xlsx
# Processing file 213 of 672: mareklug_text_3 vs mareklug_text_5.xlsx
# Processing file 214 of 672: mareklug_text_3 vs marine_69_71_text_4.xlsx
# Processing file 215 of 672: mareklug_text_4 vs mareklug_text_5.xlsx
# Processing file 216 of 672: mareklug_text_4 vs marine_69_71_text_4.xlsx
# Processing file 217 of 672: marine_69_71_text_2 vs marine_69_71_text_4.xlsx
# Processing file 218 of 672: marine_69_71_text_2 vs mathsci_text_10.xlsx
# Processing file 219 of 672: marine_69_71_text_3 vs marine_69_71_text_4.xlsx
# Processing file 220 of 672: marine_69_71_text_3 vs mathsci_text_10.xlsx
# Processing file 221 of 672: marine_69_71_text_5 vs marine_69_71_text_4.xlsx
# Processing file 222 of 672: marine_69_71_text_5 vs mathsci_text_10.xlsx
# Processing file 223 of 672: mathsci_text_11 vs mathsci_text_10.xlsx
# Processing file 224 of 672: mathsci_text_11 vs maunus_text_1.xlsx
# Processing file 225 of 672: mathsci_text_2 vs mathsci_text_10.xlsx
# Processing file 226 of 672: mathsci_text_2 vs maunus_text_1.xlsx
# Processing file 227 of 672: mathsci_text_3 vs mathsci_text_10.xlsx
# Processing file 228 of 672: mathsci_text_3 vs maunus_text_1.xlsx
# Processing file 229 of 672: maunus_text_2 vs maunus_text_1.xlsx
# Processing file 230 of 672: maunus_text_2 vs mayalld_text_3.xlsx
# Processing file 231 of 672: maunus_text_3 vs maunus_text_1.xlsx
# Processing file 232 of 672: maunus_text_3 vs mayalld_text_3.xlsx
# Processing file 233 of 672: maunus_text_4 vs maunus_text_1.xlsx
# Processing file 234 of 672: maunus_text_4 vs mayalld_text_3.xlsx
# Processing file 235 of 672: mayalld_text_1 vs mayalld_text_3.xlsx
# Processing file 236 of 672: mayalld_text_1 vs mcb_text_2.xlsx
# Processing file 237 of 672: mayalld_text_2 vs mayalld_text_3.xlsx
# Processing file 238 of 672: mayalld_text_2 vs mcb_text_2.xlsx
# Processing file 239 of 672: mayalld_text_4 vs mayalld_text_3.xlsx
# Processing file 240 of 672: mayalld_text_4 vs mcb_text_2.xlsx
# Processing file 241 of 672: mcb_text_1 vs mcb_text_2.xlsx
# Processing file 242 of 672: mcb_text_1 vs media_anthro_text_5.xlsx
# Processing file 243 of 672: mcb_text_3 vs mcb_text_2.xlsx
# Processing file 244 of 672: mcb_text_3 vs media_anthro_text_5.xlsx
# Processing file 245 of 672: mcb_text_4 vs mcb_text_2.xlsx
# Processing file 246 of 672: mcb_text_4 vs media_anthro_text_5.xlsx
# Processing file 247 of 672: media_anthro_text_1 vs media_anthro_text_5.xlsx
# Processing file 248 of 672: media_anthro_text_1 vs meowy_text_11.xlsx
# Processing file 249 of 672: media_anthro_text_3 vs media_anthro_text_5.xlsx
# Processing file 250 of 672: media_anthro_text_3 vs meowy_text_11.xlsx
# Processing file 251 of 672: media_anthro_text_4 vs media_anthro_text_5.xlsx
# Processing file 252 of 672: media_anthro_text_4 vs meowy_text_11.xlsx
# Processing file 253 of 672: meowy_text_1 vs meowy_text_11.xlsx
# Processing file 254 of 672: meowy_text_1 vs mezzomezzo_text_5.xlsx
# Processing file 255 of 672: meowy_text_10 vs meowy_text_11.xlsx
# Processing file 256 of 672: meowy_text_10 vs mezzomezzo_text_5.xlsx
# Processing file 257 of 672: meowy_text_12 vs meowy_text_11.xlsx
# Processing file 258 of 672: meowy_text_12 vs mezzomezzo_text_5.xlsx
# Processing file 259 of 672: mezzomezzo_text_2 vs mezzomezzo_text_5.xlsx
# Processing file 260 of 672: mezzomezzo_text_2 vs milomedes_text_13.xlsx
# Processing file 261 of 672: mezzomezzo_text_3 vs mezzomezzo_text_5.xlsx
# Processing file 262 of 672: mezzomezzo_text_3 vs milomedes_text_13.xlsx
# Processing file 263 of 672: mezzomezzo_text_4 vs mezzomezzo_text_5.xlsx
# Processing file 264 of 672: mezzomezzo_text_4 vs milomedes_text_13.xlsx
# Processing file 265 of 672: milomedes_text_1 vs milomedes_text_13.xlsx
# Processing file 266 of 672: milomedes_text_1 vs multixfer_text_1.xlsx
# Processing file 267 of 672: milomedes_text_10 vs milomedes_text_13.xlsx
# Processing file 268 of 672: milomedes_text_10 vs multixfer_text_1.xlsx
# Processing file 269 of 672: milomedes_text_11 vs milomedes_text_13.xlsx
# Processing file 270 of 672: milomedes_text_11 vs multixfer_text_1.xlsx
# Processing file 271 of 672: multixfer_text_2 vs multixfer_text_1.xlsx
# Processing file 272 of 672: multixfer_text_2 vs musical_linguist_text_11.xlsx
# Processing file 273 of 672: multixfer_text_3 vs multixfer_text_1.xlsx
# Processing file 274 of 672: multixfer_text_3 vs musical_linguist_text_11.xlsx
# Processing file 275 of 672: multixfer_text_5 vs multixfer_text_1.xlsx
# Processing file 276 of 672: multixfer_text_5 vs musical_linguist_text_11.xlsx
# Processing file 277 of 672: musical_linguist_text_1 vs musical_linguist_text_11.xlsx
# Processing file 278 of 672: musical_linguist_text_1 vs mymoloboaccount_text_10.xlsx
# Processing file 279 of 672: musical_linguist_text_10 vs musical_linguist_text_11.xlsx
# Processing file 280 of 672: musical_linguist_text_10 vs mymoloboaccount_text_10.xlsx
# Processing file 281 of 672: musical_linguist_text_13 vs musical_linguist_text_11.xlsx
# Processing file 282 of 672: musical_linguist_text_13 vs mymoloboaccount_text_10.xlsx
# Processing file 283 of 672: mymoloboaccount_text_2 vs mymoloboaccount_text_10.xlsx
# Processing file 284 of 672: mymoloboaccount_text_2 vs mystichumwipe_text_11.xlsx
# Processing file 285 of 672: mymoloboaccount_text_3 vs mymoloboaccount_text_10.xlsx
# Processing file 286 of 672: mymoloboaccount_text_3 vs mystichumwipe_text_11.xlsx
# Processing file 287 of 672: mymoloboaccount_text_4 vs mymoloboaccount_text_10.xlsx
# Processing file 288 of 672: mymoloboaccount_text_4 vs mystichumwipe_text_11.xlsx
# Processing file 289 of 672: mystichumwipe_text_1 vs mystichumwipe_text_11.xlsx
# Processing file 290 of 672: mystichumwipe_text_1 vs n419bh_text_4.xlsx
# Processing file 291 of 672: mystichumwipe_text_12 vs mystichumwipe_text_11.xlsx
# Processing file 292 of 672: mystichumwipe_text_12 vs n419bh_text_4.xlsx
# Processing file 293 of 672: mystichumwipe_text_13 vs mystichumwipe_text_11.xlsx
# Processing file 294 of 672: mystichumwipe_text_13 vs n419bh_text_4.xlsx
# Processing file 295 of 672: n419bh_text_1 vs n419bh_text_4.xlsx
# Processing file 296 of 672: n419bh_text_1 vs nableezy_text_2.xlsx
# Processing file 297 of 672: n419bh_text_3 vs n419bh_text_4.xlsx
# Processing file 298 of 672: n419bh_text_3 vs nableezy_text_2.xlsx
# Processing file 299 of 672: n419bh_text_5 vs n419bh_text_4.xlsx
# Processing file 300 of 672: n419bh_text_5 vs nableezy_text_2.xlsx
# Processing file 301 of 672: nableezy_text_1 vs nableezy_text_2.xlsx
# Processing file 302 of 672: nableezy_text_1 vs nathan_text_10.xlsx
# Processing file 303 of 672: nableezy_text_11 vs nableezy_text_2.xlsx
# Processing file 304 of 672: nableezy_text_11 vs nathan_text_10.xlsx
# Processing file 305 of 672: nableezy_text_12 vs nableezy_text_2.xlsx
# Processing file 306 of 672: nableezy_text_12 vs nathan_text_10.xlsx
# Processing file 307 of 672: nathan_text_11 vs nathan_text_10.xlsx
# Processing file 308 of 672: nathan_text_11 vs nigel_ish_text_4.xlsx
# Processing file 309 of 672: nathan_text_2 vs nathan_text_10.xlsx
# Processing file 310 of 672: nathan_text_2 vs nigel_ish_text_4.xlsx
# Processing file 311 of 672: nathan_text_3 vs nathan_text_10.xlsx
# Processing file 312 of 672: nathan_text_3 vs nigel_ish_text_4.xlsx
# Processing file 313 of 672: nigel_ish_text_1 vs nigel_ish_text_4.xlsx
# Processing file 314 of 672: nigel_ish_text_1 vs nil_einne_text_10.xlsx
# Processing file 315 of 672: nigel_ish_text_2 vs nigel_ish_text_4.xlsx
# Processing file 316 of 672: nigel_ish_text_2 vs nil_einne_text_10.xlsx
# Processing file 317 of 672: nigel_ish_text_5 vs nigel_ish_text_4.xlsx
# Processing file 318 of 672: nigel_ish_text_5 vs nil_einne_text_10.xlsx
# Processing file 319 of 672: nil_einne_text_11 vs nil_einne_text_10.xlsx
# Processing file 320 of 672: nil_einne_text_11 vs nirvana888_text_4.xlsx
# Processing file 321 of 672: nil_einne_text_12 vs nil_einne_text_10.xlsx
# Processing file 322 of 672: nil_einne_text_12 vs nirvana888_text_4.xlsx
# Processing file 323 of 672: nil_einne_text_13 vs nil_einne_text_10.xlsx
# Processing file 324 of 672: nil_einne_text_13 vs nirvana888_text_4.xlsx
# Processing file 325 of 672: nirvana888_text_1 vs nirvana888_text_4.xlsx
# Processing file 326 of 672: nirvana888_text_1 vs njgw_text_5.xlsx
# Processing file 327 of 672: nirvana888_text_2 vs nirvana888_text_4.xlsx
# Processing file 328 of 672: nirvana888_text_2 vs njgw_text_5.xlsx
# Processing file 329 of 672: nirvana888_text_5 vs nirvana888_text_4.xlsx
# Processing file 330 of 672: nirvana888_text_5 vs njgw_text_5.xlsx
# Processing file 331 of 672: njgw_text_2 vs njgw_text_5.xlsx
# Processing file 332 of 672: njgw_text_2 vs nocal100_text_5.xlsx
# Processing file 333 of 672: njgw_text_3 vs njgw_text_5.xlsx
# Processing file 334 of 672: njgw_text_3 vs nocal100_text_5.xlsx
# Processing file 335 of 672: njgw_text_4 vs njgw_text_5.xlsx
# Processing file 336 of 672: njgw_text_4 vs nocal100_text_5.xlsx
# Processing file 337 of 672: nocal100_text_2 vs nocal100_text_5.xlsx
# Processing file 338 of 672: nocal100_text_2 vs nocrowx_text_4.xlsx
# Processing file 339 of 672: nocal100_text_3 vs nocal100_text_5.xlsx
# Processing file 340 of 672: nocal100_text_3 vs nocrowx_text_4.xlsx
# Processing file 341 of 672: nocal100_text_4 vs nocal100_text_5.xlsx
# Processing file 342 of 672: nocal100_text_4 vs nocrowx_text_4.xlsx
# Processing file 343 of 672: nocrowx_text_2 vs nocrowx_text_4.xlsx
# Processing file 344 of 672: nocrowx_text_2 vs notpietru_text_2.xlsx
# Processing file 345 of 672: nocrowx_text_3 vs nocrowx_text_4.xlsx
# Processing file 346 of 672: nocrowx_text_3 vs notpietru_text_2.xlsx
# Processing file 347 of 672: nocrowx_text_5 vs nocrowx_text_4.xlsx
# Processing file 348 of 672: nocrowx_text_5 vs notpietru_text_2.xlsx
# Processing file 349 of 672: notpietru_text_1 vs notpietru_text_2.xlsx
# Processing file 350 of 672: notpietru_text_1 vs obamafan70_text_5.xlsx
# Processing file 351 of 672: notpietru_text_4 vs notpietru_text_2.xlsx
# Processing file 352 of 672: notpietru_text_4 vs obamafan70_text_5.xlsx
# Processing file 353 of 672: notpietru_text_5 vs notpietru_text_2.xlsx
# Processing file 354 of 672: notpietru_text_5 vs obamafan70_text_5.xlsx
# Processing file 355 of 672: o_fenian_text_1 vs o_fenian_text_4.xlsx
# Processing file 356 of 672: o_fenian_text_1 vs paul_siebert_text_12.xlsx
# Processing file 357 of 672: o_fenian_text_2 vs o_fenian_text_4.xlsx
# Processing file 358 of 672: o_fenian_text_2 vs paul_siebert_text_12.xlsx
# Processing file 359 of 672: o_fenian_text_3 vs o_fenian_text_4.xlsx
# Processing file 360 of 672: o_fenian_text_3 vs paul_siebert_text_12.xlsx
# Processing file 361 of 672: obamafan70_text_2 vs obamafan70_text_5.xlsx
# Processing file 362 of 672: obamafan70_text_2 vs orangemarlin_text_4.xlsx
# Processing file 363 of 672: obamafan70_text_3 vs obamafan70_text_5.xlsx
# Processing file 364 of 672: obamafan70_text_3 vs orangemarlin_text_4.xlsx
# Processing file 365 of 672: obamafan70_text_4 vs obamafan70_text_5.xlsx
# Processing file 366 of 672: obamafan70_text_4 vs orangemarlin_text_4.xlsx
# Processing file 367 of 672: orangemarlin_text_1 vs orangemarlin_text_4.xlsx
# Processing file 368 of 672: orangemarlin_text_1 vs ottava_rima_text_15.xlsx
# Processing file 369 of 672: orangemarlin_text_2 vs orangemarlin_text_4.xlsx
# Processing file 370 of 672: orangemarlin_text_2 vs ottava_rima_text_15.xlsx
# Processing file 371 of 672: orangemarlin_text_5 vs orangemarlin_text_4.xlsx
# Processing file 372 of 672: orangemarlin_text_5 vs ottava_rima_text_15.xlsx
# Processing file 373 of 672: ottava_rima_text_1 vs o_fenian_text_4.xlsx
# Processing file 374 of 672: ottava_rima_text_1 vs ottava_rima_text_15.xlsx
# Processing file 375 of 672: ottava_rima_text_14 vs o_fenian_text_4.xlsx
# Processing file 376 of 672: ottava_rima_text_14 vs ottava_rima_text_15.xlsx
# Processing file 377 of 672: ottava_rima_text_16 vs o_fenian_text_4.xlsx
# Processing file 378 of 672: ottava_rima_text_16 vs ottava_rima_text_15.xlsx
# Processing file 379 of 672: paul_siebert_text_1 vs paul_siebert_text_12.xlsx
# Processing file 380 of 672: paul_siebert_text_1 vs petersymonds_text_3.xlsx
# Processing file 381 of 672: paul_siebert_text_10 vs paul_siebert_text_12.xlsx
# Processing file 382 of 672: paul_siebert_text_10 vs petersymonds_text_3.xlsx
# Processing file 383 of 672: paul_siebert_text_11 vs paul_siebert_text_12.xlsx
# Processing file 384 of 672: paul_siebert_text_11 vs petersymonds_text_3.xlsx
# Processing file 385 of 672: peter_james_text_1 vs peter_james_text_4.xlsx
# Processing file 386 of 672: peter_james_text_1 vs phead128_text_2.xlsx
# Processing file 387 of 672: peter_james_text_2 vs peter_james_text_4.xlsx
# Processing file 388 of 672: peter_james_text_2 vs phead128_text_2.xlsx
# Processing file 389 of 672: peter_james_text_3 vs peter_james_text_4.xlsx
# Processing file 390 of 672: peter_james_text_3 vs phead128_text_2.xlsx
# Processing file 391 of 672: petersymonds_text_1 vs peter_james_text_4.xlsx
# Processing file 392 of 672: petersymonds_text_1 vs petersymonds_text_3.xlsx
# Processing file 393 of 672: petersymonds_text_2 vs peter_james_text_4.xlsx
# Processing file 394 of 672: petersymonds_text_2 vs petersymonds_text_3.xlsx
# Processing file 395 of 672: petersymonds_text_4 vs peter_james_text_4.xlsx
# Processing file 396 of 672: petersymonds_text_4 vs petersymonds_text_3.xlsx
# Processing file 397 of 672: phead128_text_1 vs phead128_text_2.xlsx
# Processing file 398 of 672: phead128_text_1 vs pinkampersand_text_4.xlsx
# Processing file 399 of 672: phead128_text_4 vs phead128_text_2.xlsx
# Processing file 400 of 672: phead128_text_4 vs pinkampersand_text_4.xlsx
# Processing file 401 of 672: phead128_text_5 vs phead128_text_2.xlsx
# Processing file 402 of 672: phead128_text_5 vs pinkampersand_text_4.xlsx
# Processing file 403 of 672: pinkampersand_text_1 vs pinkampersand_text_4.xlsx
# Processing file 404 of 672: pinkampersand_text_1 vs pro_lick_text_1.xlsx
# Processing file 405 of 672: pinkampersand_text_2 vs pinkampersand_text_4.xlsx
# Processing file 406 of 672: pinkampersand_text_2 vs pro_lick_text_1.xlsx
# Processing file 407 of 672: pinkampersand_text_3 vs pinkampersand_text_4.xlsx
# Processing file 408 of 672: pinkampersand_text_3 vs pro_lick_text_1.xlsx
# Processing file 409 of 672: pro_lick_text_2 vs pro_lick_text_1.xlsx
# Processing file 410 of 672: pro_lick_text_2 vs protonk_text_13.xlsx
# Processing file 411 of 672: pro_lick_text_3 vs pro_lick_text_1.xlsx
# Processing file 412 of 672: pro_lick_text_3 vs protonk_text_13.xlsx
# Processing file 413 of 672: pro_lick_text_5 vs pro_lick_text_1.xlsx
# Processing file 414 of 672: pro_lick_text_5 vs protonk_text_13.xlsx
# Processing file 415 of 672: protonk_text_1 vs protonk_text_13.xlsx
# Processing file 416 of 672: protonk_text_1 vs ramdrake_text_5.xlsx
# Processing file 417 of 672: protonk_text_10 vs protonk_text_13.xlsx
# Processing file 418 of 672: protonk_text_10 vs ramdrake_text_5.xlsx
# Processing file 419 of 672: protonk_text_12 vs protonk_text_13.xlsx
# Processing file 420 of 672: protonk_text_12 vs ramdrake_text_5.xlsx
# Processing file 421 of 672: ramdrake_text_1 vs ramdrake_text_5.xlsx
# Processing file 422 of 672: ramdrake_text_1 vs richard_daft_text_4.xlsx
# Processing file 423 of 672: ramdrake_text_2 vs ramdrake_text_5.xlsx
# Processing file 424 of 672: ramdrake_text_2 vs richard_daft_text_4.xlsx
# Processing file 425 of 672: ramdrake_text_3 vs ramdrake_text_5.xlsx
# Processing file 426 of 672: ramdrake_text_3 vs richard_daft_text_4.xlsx
# Processing file 427 of 672: richard_daft_text_2 vs richard_daft_text_4.xlsx
# Processing file 428 of 672: richard_daft_text_2 vs rjecina_text_11.xlsx
# Processing file 429 of 672: richard_daft_text_3 vs richard_daft_text_4.xlsx
# Processing file 430 of 672: richard_daft_text_3 vs rjecina_text_11.xlsx
# Processing file 431 of 672: richard_daft_text_5 vs richard_daft_text_4.xlsx
# Processing file 432 of 672: richard_daft_text_5 vs rjecina_text_11.xlsx
# Processing file 433 of 672: rjecina_text_1 vs rjecina_text_11.xlsx
# Processing file 434 of 672: rjecina_text_1 vs rolandr_text_3.xlsx
# Processing file 435 of 672: rjecina_text_10 vs rjecina_text_11.xlsx
# Processing file 436 of 672: rjecina_text_10 vs rolandr_text_3.xlsx
# Processing file 437 of 672: rjecina_text_13 vs rjecina_text_11.xlsx
# Processing file 438 of 672: rjecina_text_13 vs rolandr_text_3.xlsx
# Processing file 439 of 672: rolandr_text_1 vs rolandr_text_3.xlsx
# Processing file 440 of 672: rolandr_text_1 vs salierethefish_text_5.xlsx
# Processing file 441 of 672: rolandr_text_2 vs rolandr_text_3.xlsx
# Processing file 442 of 672: rolandr_text_2 vs salierethefish_text_5.xlsx
# Processing file 443 of 672: rolandr_text_5 vs rolandr_text_3.xlsx
# Processing file 444 of 672: rolandr_text_5 vs salierethefish_text_5.xlsx
# Processing file 445 of 672: salierethefish_text_1 vs salierethefish_text_5.xlsx
# Processing file 446 of 672: salierethefish_text_1 vs salix_alba_text_3.xlsx
# Processing file 447 of 672: salierethefish_text_2 vs salierethefish_text_5.xlsx
# Processing file 448 of 672: salierethefish_text_2 vs salix_alba_text_3.xlsx
# Processing file 449 of 672: salierethefish_text_4 vs salierethefish_text_5.xlsx
# Processing file 450 of 672: salierethefish_text_4 vs salix_alba_text_3.xlsx
# Processing file 451 of 672: salix_alba_text_1 vs salix_alba_text_3.xlsx
# Processing file 452 of 672: salix_alba_text_1 vs sally_season_text_1.xlsx
# Processing file 453 of 672: salix_alba_text_2 vs salix_alba_text_3.xlsx
# Processing file 454 of 672: salix_alba_text_2 vs sally_season_text_1.xlsx
# Processing file 455 of 672: salix_alba_text_4 vs salix_alba_text_3.xlsx
# Processing file 456 of 672: salix_alba_text_4 vs sally_season_text_1.xlsx
# Processing file 457 of 672: sally_season_text_11 vs sally_season_text_1.xlsx
# Processing file 458 of 672: sally_season_text_11 vs scheinwerfermann_text_10.xlsx
# Processing file 459 of 672: sally_season_text_12 vs sally_season_text_1.xlsx
# Processing file 460 of 672: sally_season_text_12 vs scheinwerfermann_text_10.xlsx
# Processing file 461 of 672: sally_season_text_2 vs sally_season_text_1.xlsx
# Processing file 462 of 672: sally_season_text_2 vs scheinwerfermann_text_10.xlsx
# Processing file 463 of 672: scheinwerfermann_text_11 vs scheinwerfermann_text_10.xlsx
# Processing file 464 of 672: scheinwerfermann_text_11 vs sean_hoyland_text_3.xlsx
# Processing file 465 of 672: scheinwerfermann_text_12 vs scheinwerfermann_text_10.xlsx
# Processing file 466 of 672: scheinwerfermann_text_12 vs sean_hoyland_text_3.xlsx
# Processing file 467 of 672: scheinwerfermann_text_13 vs scheinwerfermann_text_10.xlsx
# Processing file 468 of 672: scheinwerfermann_text_13 vs sean_hoyland_text_3.xlsx
# Processing file 469 of 672: sean_hoyland_text_1 vs sean_hoyland_text_3.xlsx
# Processing file 470 of 672: sean_hoyland_text_1 vs secret_of_success_text_3.xlsx
# Processing file 471 of 672: sean_hoyland_text_10 vs sean_hoyland_text_3.xlsx
# Processing file 472 of 672: sean_hoyland_text_10 vs secret_of_success_text_3.xlsx
# Processing file 473 of 672: sean_hoyland_text_2 vs sean_hoyland_text_3.xlsx
# Processing file 474 of 672: sean_hoyland_text_2 vs secret_of_success_text_3.xlsx
# Processing file 475 of 672: secret_of_success_text_1 vs secret_of_success_text_3.xlsx
# Processing file 476 of 672: secret_of_success_text_1 vs sennen_goroshi_text_3.xlsx
# Processing file 477 of 672: secret_of_success_text_4 vs secret_of_success_text_3.xlsx
# Processing file 478 of 672: secret_of_success_text_4 vs sennen_goroshi_text_3.xlsx
# Processing file 479 of 672: secret_of_success_text_5 vs secret_of_success_text_3.xlsx
# Processing file 480 of 672: secret_of_success_text_5 vs sennen_goroshi_text_3.xlsx
# Processing file 481 of 672: sennen_goroshi_text_1 vs sennen_goroshi_text_3.xlsx
# Processing file 482 of 672: sennen_goroshi_text_1 vs sgrayban_text_5.xlsx
# Processing file 483 of 672: sennen_goroshi_text_2 vs sennen_goroshi_text_3.xlsx
# Processing file 484 of 672: sennen_goroshi_text_2 vs sgrayban_text_5.xlsx
# Processing file 485 of 672: sennen_goroshi_text_4 vs sennen_goroshi_text_3.xlsx
# Processing file 486 of 672: sennen_goroshi_text_4 vs sgrayban_text_5.xlsx
# Processing file 487 of 672: sgrayban_text_2 vs sgrayban_text_5.xlsx
# Processing file 488 of 672: sgrayban_text_2 vs simoncursitor_text_4.xlsx
# Processing file 489 of 672: sgrayban_text_3 vs sgrayban_text_5.xlsx
# Processing file 490 of 672: sgrayban_text_3 vs simoncursitor_text_4.xlsx
# Processing file 491 of 672: sgrayban_text_4 vs sgrayban_text_5.xlsx
# Processing file 492 of 672: sgrayban_text_4 vs simoncursitor_text_4.xlsx
# Processing file 493 of 672: simoncursitor_text_1 vs simoncursitor_text_4.xlsx
# Processing file 494 of 672: simoncursitor_text_1 vs sks2k6_text_3.xlsx
# Processing file 495 of 672: simoncursitor_text_2 vs simoncursitor_text_4.xlsx
# Processing file 496 of 672: simoncursitor_text_2 vs sks2k6_text_3.xlsx
# Processing file 497 of 672: simoncursitor_text_3 vs simoncursitor_text_4.xlsx
# Processing file 498 of 672: simoncursitor_text_3 vs sks2k6_text_3.xlsx
# Processing file 499 of 672: sks2k6_text_1 vs sks2k6_text_3.xlsx
# Processing file 500 of 672: sks2k6_text_1 vs snowded_text_1.xlsx
# Processing file 501 of 672: sks2k6_text_4 vs sks2k6_text_3.xlsx
# Processing file 502 of 672: sks2k6_text_4 vs snowded_text_1.xlsx
# Processing file 503 of 672: sks2k6_text_5 vs sks2k6_text_3.xlsx
# Processing file 504 of 672: sks2k6_text_5 vs snowded_text_1.xlsx
# Processing file 505 of 672: snowded_text_10 vs snowded_text_1.xlsx
# Processing file 506 of 672: snowded_text_10 vs soapfan2013_text_2.xlsx
# Processing file 507 of 672: snowded_text_12 vs snowded_text_1.xlsx
# Processing file 508 of 672: snowded_text_12 vs soapfan2013_text_2.xlsx
# Processing file 509 of 672: snowded_text_2 vs snowded_text_1.xlsx
# Processing file 510 of 672: snowded_text_2 vs soapfan2013_text_2.xlsx
# Processing file 511 of 672: soapfan2013_text_1 vs soapfan2013_text_2.xlsx
# Processing file 512 of 672: soapfan2013_text_1 vs spaully_text_3.xlsx
# Processing file 513 of 672: soapfan2013_text_3 vs soapfan2013_text_2.xlsx
# Processing file 514 of 672: soapfan2013_text_3 vs spaully_text_3.xlsx
# Processing file 515 of 672: soapfan2013_text_4 vs soapfan2013_text_2.xlsx
# Processing file 516 of 672: soapfan2013_text_4 vs spaully_text_3.xlsx
# Processing file 517 of 672: spaully_text_2 vs spaully_text_3.xlsx
# Processing file 518 of 672: spaully_text_2 vs spitfire_text_5.xlsx
# Processing file 519 of 672: spaully_text_4 vs spaully_text_3.xlsx
# Processing file 520 of 672: spaully_text_4 vs spitfire_text_5.xlsx
# Processing file 521 of 672: spaully_text_5 vs spaully_text_3.xlsx
# Processing file 522 of 672: spaully_text_5 vs spitfire_text_5.xlsx
# Processing file 523 of 672: spitfire_text_1 vs spitfire_text_5.xlsx
# Processing file 524 of 672: spitfire_text_1 vs srisuren_text_10.xlsx
# Processing file 525 of 672: spitfire_text_2 vs spitfire_text_5.xlsx
# Processing file 526 of 672: spitfire_text_2 vs srisuren_text_10.xlsx
# Processing file 527 of 672: spitfire_text_3 vs spitfire_text_5.xlsx
# Processing file 528 of 672: spitfire_text_3 vs srisuren_text_10.xlsx
# Processing file 529 of 672: srisuren_text_1 vs srisuren_text_10.xlsx
# Processing file 530 of 672: srisuren_text_1 vs stephenbuxton_text_3.xlsx
# Processing file 531 of 672: srisuren_text_12 vs srisuren_text_10.xlsx
# Processing file 532 of 672: srisuren_text_12 vs stephenbuxton_text_3.xlsx
# Processing file 533 of 672: srisuren_text_13 vs srisuren_text_10.xlsx
# Processing file 534 of 672: srisuren_text_13 vs stephenbuxton_text_3.xlsx
# Processing file 535 of 672: stephenbuxton_text_1 vs stephenbuxton_text_3.xlsx
# Processing file 536 of 672: stephenbuxton_text_1 vs stillstanding_247_text_5.xlsx
# Processing file 537 of 672: stephenbuxton_text_4 vs stephenbuxton_text_3.xlsx
# Processing file 538 of 672: stephenbuxton_text_4 vs stillstanding_247_text_5.xlsx
# Processing file 539 of 672: stephenbuxton_text_5 vs stephenbuxton_text_3.xlsx
# Processing file 540 of 672: stephenbuxton_text_5 vs stillstanding_247_text_5.xlsx
# Processing file 541 of 672: stillstanding_247_text_1 vs stillstanding_247_text_5.xlsx
# Processing file 542 of 672: stillstanding_247_text_1 vs swift_silent_text_2.xlsx
# Processing file 543 of 672: stillstanding_247_text_2 vs stillstanding_247_text_5.xlsx
# Processing file 544 of 672: stillstanding_247_text_2 vs swift_silent_text_2.xlsx
# Processing file 545 of 672: stillstanding_247_text_4 vs stillstanding_247_text_5.xlsx
# Processing file 546 of 672: stillstanding_247_text_4 vs swift_silent_text_2.xlsx
# Processing file 547 of 672: swift_silent_text_1 vs swift_silent_text_2.xlsx
# Processing file 548 of 672: swift_silent_text_1 vs t34ch_text_4.xlsx
# Processing file 549 of 672: swift_silent_text_4 vs swift_silent_text_2.xlsx
# Processing file 550 of 672: swift_silent_text_4 vs t34ch_text_4.xlsx
# Processing file 551 of 672: swift_silent_text_5 vs swift_silent_text_2.xlsx
# Processing file 552 of 672: swift_silent_text_5 vs t34ch_text_4.xlsx
# Processing file 553 of 672: t34ch_text_1 vs t34ch_text_4.xlsx
# Processing file 554 of 672: t34ch_text_1 vs thekohser_text_11.xlsx
# Processing file 555 of 672: t34ch_text_2 vs t34ch_text_4.xlsx
# Processing file 556 of 672: t34ch_text_2 vs thekohser_text_11.xlsx
# Processing file 557 of 672: t34ch_text_3 vs t34ch_text_4.xlsx
# Processing file 558 of 672: t34ch_text_3 vs thekohser_text_11.xlsx
# Processing file 559 of 672: the_four_deuces_text_1 vs the_four_deuces_text_4.xlsx
# Processing file 560 of 672: the_four_deuces_text_1 vs tijfo098_text_2.xlsx
# Processing file 561 of 672: the_four_deuces_text_10 vs the_four_deuces_text_4.xlsx
# Processing file 562 of 672: the_four_deuces_text_10 vs tijfo098_text_2.xlsx
# Processing file 563 of 672: the_four_deuces_text_3 vs the_four_deuces_text_4.xlsx
# Processing file 564 of 672: the_four_deuces_text_3 vs tijfo098_text_2.xlsx
# Processing file 565 of 672: thekohser_text_1 vs thekohser_text_11.xlsx
# Processing file 566 of 672: thekohser_text_1 vs theserialcomma_text_5.xlsx
# Processing file 567 of 672: thekohser_text_10 vs thekohser_text_11.xlsx
# Processing file 568 of 672: thekohser_text_10 vs theserialcomma_text_5.xlsx
# Processing file 569 of 672: thekohser_text_3 vs thekohser_text_11.xlsx
# Processing file 570 of 672: thekohser_text_3 vs theserialcomma_text_5.xlsx
# Processing file 571 of 672: tijfo098_text_1 vs tijfo098_text_2.xlsx
# Processing file 572 of 672: tijfo098_text_1 vs tintin1107_text_5.xlsx
# Processing file 573 of 672: tijfo098_text_3 vs tijfo098_text_2.xlsx
# Processing file 574 of 672: tijfo098_text_3 vs tintin1107_text_5.xlsx
# Processing file 575 of 672: tijfo098_text_5 vs tijfo098_text_2.xlsx
# Processing file 576 of 672: tijfo098_text_5 vs tintin1107_text_5.xlsx
# Processing file 577 of 672: tintin1107_text_1 vs tintin1107_text_5.xlsx
# Processing file 578 of 672: tintin1107_text_1 vs tvoz_text_1.xlsx
# Processing file 579 of 672: tintin1107_text_3 vs tintin1107_text_5.xlsx
# Processing file 580 of 672: tintin1107_text_3 vs tvoz_text_1.xlsx
# Processing file 581 of 672: tintin1107_text_4 vs tintin1107_text_5.xlsx
# Processing file 582 of 672: tintin1107_text_4 vs tvoz_text_1.xlsx
# Processing file 583 of 672: tvoz_text_11 vs tvoz_text_1.xlsx
# Processing file 584 of 672: tvoz_text_11 vs u21980_text_5.xlsx
# Processing file 585 of 672: tvoz_text_2 vs tvoz_text_1.xlsx
# Processing file 586 of 672: tvoz_text_2 vs u21980_text_5.xlsx
# Processing file 587 of 672: tvoz_text_3 vs tvoz_text_1.xlsx
# Processing file 588 of 672: tvoz_text_3 vs u21980_text_5.xlsx
# Processing file 589 of 672: u21980_text_1 vs u21980_text_5.xlsx
# Processing file 590 of 672: u21980_text_1 vs updown_text_3.xlsx
# Processing file 591 of 672: u21980_text_3 vs u21980_text_5.xlsx
# Processing file 592 of 672: u21980_text_3 vs updown_text_3.xlsx
# Processing file 593 of 672: u21980_text_4 vs u21980_text_5.xlsx
# Processing file 594 of 672: u21980_text_4 vs updown_text_3.xlsx
# Processing file 595 of 672: updown_text_1 vs updown_text_3.xlsx
# Processing file 596 of 672: updown_text_1 vs vedant_text_4.xlsx
# Processing file 597 of 672: updown_text_2 vs updown_text_3.xlsx
# Processing file 598 of 672: updown_text_2 vs vedant_text_4.xlsx
# Processing file 599 of 672: updown_text_4 vs updown_text_3.xlsx
# Processing file 600 of 672: updown_text_4 vs vedant_text_4.xlsx
# Processing file 601 of 672: vedant_text_1 vs vedant_text_4.xlsx
# Processing file 602 of 672: vedant_text_1 vs viewfinder_text_4.xlsx
# Processing file 603 of 672: vedant_text_2 vs vedant_text_4.xlsx
# Processing file 604 of 672: vedant_text_2 vs viewfinder_text_4.xlsx
# Processing file 605 of 672: vedant_text_5 vs vedant_text_4.xlsx
# Processing file 606 of 672: vedant_text_5 vs viewfinder_text_4.xlsx
# Processing file 607 of 672: viewfinder_text_1 vs viewfinder_text_4.xlsx
# Processing file 608 of 672: viewfinder_text_1 vs volunteer_marek_text_4.xlsx
# Processing file 609 of 672: viewfinder_text_2 vs viewfinder_text_4.xlsx
# Processing file 610 of 672: viewfinder_text_2 vs volunteer_marek_text_4.xlsx
# Processing file 611 of 672: viewfinder_text_5 vs viewfinder_text_4.xlsx
# Processing file 612 of 672: viewfinder_text_5 vs volunteer_marek_text_4.xlsx
# Processing file 613 of 672: volunteer_marek_text_10 vs volunteer_marek_text_4.xlsx
# Processing file 614 of 672: volunteer_marek_text_10 vs vr_text_3.xlsx
# Processing file 615 of 672: volunteer_marek_text_2 vs volunteer_marek_text_4.xlsx
# Processing file 616 of 672: volunteer_marek_text_2 vs vr_text_3.xlsx
# Processing file 617 of 672: volunteer_marek_text_3 vs volunteer_marek_text_4.xlsx
# Processing file 618 of 672: volunteer_marek_text_3 vs vr_text_3.xlsx
# Processing file 619 of 672: vr_text_1 vs vr_text_3.xlsx
# Processing file 620 of 672: vr_text_1 vs vsevolodkrolikov_text_1.xlsx
# Processing file 621 of 672: vr_text_2 vs vr_text_3.xlsx
# Processing file 622 of 672: vr_text_2 vs vsevolodkrolikov_text_1.xlsx
# Processing file 623 of 672: vr_text_6 vs vr_text_3.xlsx
# Processing file 624 of 672: vr_text_6 vs vsevolodkrolikov_text_1.xlsx
# Processing file 625 of 672: vsevolodkrolikov_text_11 vs vsevolodkrolikov_text_1.xlsx
# Processing file 626 of 672: vsevolodkrolikov_text_11 vs wiki_guy_16_text_1.xlsx
# Processing file 627 of 672: vsevolodkrolikov_text_12 vs vsevolodkrolikov_text_1.xlsx
# Processing file 628 of 672: vsevolodkrolikov_text_12 vs wiki_guy_16_text_1.xlsx
# Processing file 629 of 672: vsevolodkrolikov_text_13 vs vsevolodkrolikov_text_1.xlsx
# Processing file 630 of 672: vsevolodkrolikov_text_13 vs wiki_guy_16_text_1.xlsx
# Processing file 631 of 672: wiki_guy_16_text_3 vs wiki_guy_16_text_1.xlsx
# Processing file 632 of 672: wiki_guy_16_text_3 vs williamh_text_1.xlsx
# Processing file 633 of 672: wiki_guy_16_text_5 vs wiki_guy_16_text_1.xlsx
# Processing file 634 of 672: wiki_guy_16_text_5 vs williamh_text_1.xlsx
# Processing file 635 of 672: wiki_guy_16_text_6 vs wiki_guy_16_text_1.xlsx
# Processing file 636 of 672: wiki_guy_16_text_6 vs williamh_text_1.xlsx
# Processing file 637 of 672: william_m_connolley_text_3 vs william_m_connolley_text_2.xlsx
# Processing file 638 of 672: william_m_connolley_text_3 vs wobble_text_13.xlsx
# Processing file 639 of 672: william_m_connolley_text_4 vs william_m_connolley_text_2.xlsx
# Processing file 640 of 672: william_m_connolley_text_4 vs wobble_text_13.xlsx
# Processing file 641 of 672: william_m_connolley_text_5 vs william_m_connolley_text_2.xlsx
# Processing file 642 of 672: william_m_connolley_text_5 vs wobble_text_13.xlsx
# Processing file 643 of 672: williamh_text_2 vs william_m_connolley_text_2.xlsx
# Processing file 644 of 672: williamh_text_2 vs williamh_text_1.xlsx
# Processing file 645 of 672: williamh_text_3 vs william_m_connolley_text_2.xlsx
# Processing file 646 of 672: williamh_text_3 vs williamh_text_1.xlsx
# Processing file 647 of 672: williamh_text_4 vs william_m_connolley_text_2.xlsx
# Processing file 648 of 672: williamh_text_4 vs williamh_text_1.xlsx
# Processing file 649 of 672: wobble_text_1 vs wobble_text_13.xlsx
# Processing file 650 of 672: wobble_text_1 vs xtv_text_4.xlsx
# Processing file 651 of 672: wobble_text_10 vs wobble_text_13.xlsx
# Processing file 652 of 672: wobble_text_10 vs xtv_text_4.xlsx
# Processing file 653 of 672: wobble_text_11 vs wobble_text_13.xlsx
# Processing file 654 of 672: wobble_text_11 vs xtv_text_4.xlsx
# Processing file 655 of 672: xtv_text_2 vs xtv_text_4.xlsx
# Processing file 656 of 672: xtv_text_2 vs yoenit_text_2.xlsx
# Processing file 657 of 672: xtv_text_3 vs xtv_text_4.xlsx
# Processing file 658 of 672: xtv_text_3 vs yoenit_text_2.xlsx
# Processing file 659 of 672: xtv_text_5 vs xtv_text_4.xlsx
# Processing file 660 of 672: xtv_text_5 vs yoenit_text_2.xlsx
# Processing file 661 of 672: yoenit_text_1 vs yoenit_text_2.xlsx
# Processing file 662 of 672: yoenit_text_1 vs zjarrirrethues_text_2.xlsx
# Processing file 663 of 672: yoenit_text_4 vs yoenit_text_2.xlsx
# Processing file 664 of 672: yoenit_text_4 vs zjarrirrethues_text_2.xlsx
# Processing file 665 of 672: yoenit_text_5 vs yoenit_text_2.xlsx
# Processing file 666 of 672: yoenit_text_5 vs zjarrirrethues_text_2.xlsx
# Processing file 667 of 672: zjarrirrethues_text_1 vs 142_196_88_228_text_2.xlsx
# Processing file 668 of 672: zjarrirrethues_text_1 vs zjarrirrethues_text_2.xlsx
# Processing file 669 of 672: zjarrirrethues_text_4 vs 142_196_88_228_text_2.xlsx
# Processing file 670 of 672: zjarrirrethues_text_4 vs zjarrirrethues_text_2.xlsx
# Processing file 671 of 672: zjarrirrethues_text_5 vs 142_196_88_228_text_2.xlsx
# Processing file 672 of 672: zjarrirrethues_text_5 vs zjarrirrethues_text_2.xlsx
#
# ✅ Final summary saved to: /Volumes/BCross/paraphrase examples slurm/Wiki-Test/ModernBERT-base/gpt2 results/token_level_results_inc_rank.xlsx
