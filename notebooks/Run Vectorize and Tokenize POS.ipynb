# %%
import os
import sys

# %%
sys.path.append(os.path.abspath('../src'))

from read_and_write_docs import read_jsonl, write_jsonl
from POSNoise import apply_posnoise
from tokenize_and_score import score_dataframe

# %%
base_loc = "/Volumes/BCross/datasets/author_verification"

data_type = "training"

corpus = 'Wiki'

known_data_loc = f"{base_loc}/{data_type}/{corpus}/known_processed.jsonl"
known_save_loc = f"{base_loc}/{data_type}/{corpus}/known_tokenized_pos.jsonl"
unknown_data_loc = f"{base_loc}/{data_type}/{corpus}/unknown_processed.jsonl"
unknown_save_loc = f"{base_loc}/{data_type}/{corpus}/unknown_tokenized_pos.jsonl"

model_loc = '/Volumes/BCross/models/Qwen 2.5/Qwen2.5-1.5B-Instruct'

# %%
df = read_jsonl(known_data_loc)

# %%
pos_df = apply_posnoise(df, 'sentence')

# %%
score_data = score_dataframe(pos_df, 'sentence_POSNoise', model_loc)
# Out:
# Scoring texts:   0%|          | 7/4174 [04:02<40:10:16, 34.71s/it]
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[9], line 1
#
# ----> 1 score_data = score_dataframe(pos_df, 'sentence_POSNoise', model_loc)
#
#
#
# File ~/Documents/GitHub/av_distributions/src/tokenize_and_score.py:123, in score_dataframe(df, text_column, model_loc)
#
#     121     toks, lps, meds = compute_log_probs_with_median(txt, tokenizer, model)
#
#     122     return pd.Series((toks, lps, meds))
#
# --> 123 df[['tokens', 'log_probs', 'med_log_prob']] = df[text_column].progress_apply(_score_row)
#
#     125 # differences
#
#     126 df['differences']     = df.apply(lambda r: [lp - m for lp, m in zip(r['log_probs'], r['med_log_prob'])], axis=1)
#
#
#
# ...
